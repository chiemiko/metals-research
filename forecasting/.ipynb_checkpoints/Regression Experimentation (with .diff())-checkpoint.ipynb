# %%
import pandas as pd
from matplotlib import pyplot as plt
import re

from statsmodels.tsa.stattools import adfuller

from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

import numpy as np
import fbprophet
from fbprophet import Prophet
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
from pylab import rcParams
import datetime

import logging

from sklearn.metrics import mean_absolute_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from sklearn.linear_model import LinearRegression

from sklearn import metrics

from sklearn.model_selection import ParameterGrid
from sklearn.linear_model import Ridge


logging.getLogger().setLevel(logging.ERROR)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.Series(timeseries).rolling(window=4).mean()
    #pd.rolling_mean(timeseries, window=12)
    rolstd =  pd.Series(timeseries).rolling(window=4).std()
#Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    # dftest = adfuller(timeseries, autolag='AIC')
    dftest = adfuller(timeseries)
    
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
LME_futures = pd.read_excel('forecasting_raw_data/LME Futures Price.xlsx')
LME_futures = LME_futures.iloc[3:, 1:]
#LME_futures['Unnamed: 1'] = pd.datetime(LME_futures['Unnamed: 1'])
LME_futures.index = LME_futures['Unnamed: 1']



LME_futures = LME_futures.iloc[:, 1:]
LME_futures = LME_futures[LME_futures.index.year>=2000]
LME_futures.isnull().sum()
LME = LME_futures.iloc[:, 0]
LME = LME.astype(float)
LME = LME.resample('W').mean()

# %%
plt.plot(LME)

# %% [markdown]
# ### Note About Preprocessing:
#
# #### For differenced data, to unscale, must concatenate the LAST VALUE OF THE ORIGINAL Y OF THE TRAINING SET, with the new PREDICTED SERIES OF SCALED_YHAT to use CUMSUM()

# %%
def preprocess(series):
    
    stationary = series.diff()
    return stationary
    
def unpreprocess(first, stationary_series):
    #first = training_y_series.last()
    '''With no gaps in time'''
    unscaled = np.r_[first ,stationary_series].cumsum()
    #unscaled = unscaled[1:]
    return unscaled

# %%
# TESTING UNSCALING 
'''
LME_stationary = preprocess(LME)
first = LME.first('D')
#LME_reversed = unpreprocess(first, LME_stationary)
LME_reversed = np.r_[first ,LME_stationary[1:]].cumsum()
LME_reversed = pd.DataFrame(LME_reversed)

#######################

y_test = LME_stationary['2018-10-14':]
original_y_test = LME['2018-10-14':]

# !!! NOTE MAKE SURE TO SET y_train as ONE WEEK BEFORE MANUALLY
original_y_train = LME[:'2018-10-07']

first = original_y_train.last('D')
LME_reversed = np.r_[first , y_test].cumsum()
LME_reversed = pd.DataFrame(LME_reversed)
LME_reversed = LME_reversed[1:]
LME_reversed.head()

#original_y
'''
# Out:
# "\nLME_stationary = preprocess(LME)\nfirst = LME.first('D')\n#LME_reversed = unpreprocess(first, LME_stationary)\nLME_reversed = np.r_[first ,LME_stationary[1:]].cumsum()\nLME_reversed = pd.DataFrame(LME_reversed)\n\n#######################\n\ny_test = LME_stationary['2018-10-14':]\noriginal_y_test = LME['2018-10-14':]\n\n# !!! NOTE MAKE SURE TO SET y_train as ONE WEEK BEFORE MANUALLY\noriginal_y_train = LME[:'2018-10-07']\n\nfirst = original_y_train.last('D')\nLME_reversed = np.r_[first , y_test].cumsum()\nLME_reversed = pd.DataFrame(LME_reversed)\nLME_reversed = LME_reversed[1:]\nLME_reversed.head()\n\n#original_y\n"

# %% [markdown]
# #### Take Out Trend
#
# Pandas time series resampling options
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html

# %%
LME_stationary = preprocess(LME)

#LME_log = np.log(LME)
LME_log = LME
rcParams['figure.figsize'] = 9, 6

#plt.plot(LME_log)
#plt.show()

window_setting=5
moving_avg = LME_log.rolling(window=window_setting).mean()
#plt.plot(LME_log)
#plt.plot(moving_avg, color='red')
#plt.axvline('2018-5-1', color='red', linestyle='--')
#plt.show()

moving_diff = LME_log-moving_avg.shift()
moving_diff = moving_diff.dropna()
#moving_diff = moving_diff.to_frame()

plt.plot(LME_stationary)

test_stationarity(LME_stationary.dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.137728e+00
# p-value                        2.904991e-15
# #Lags Used                     9.000000e+00
# Number of Observations Used    1.021000e+03
# Critical Value (1%)           -3.436771e+00
# Critical Value (5%)           -2.864375e+00
# Critical Value (10%)          -2.568279e+00
# dtype: float64

# %%
list_one = list(LME_stationary.index)
list_two = list(LME_stationary)
df = pd.DataFrame(list(zip(list_one, list_two)), columns = ['ds', 'y'])
df.head()


df['lag1'] = df.y.shift(periods=1)
df['lag2'] = df.y.shift(periods=2)
df['lag3'] = df.y.shift(periods=3)
df['lag4'] = df.y.shift(periods=4)
df['lag5'] = df.y.shift(periods=5)

df['lag6'] = df.y.shift(periods=6)
df['lag7'] = df.y.shift(periods=7)
df['lag8'] = df.y.shift(periods=8)
df['lag9'] = df.y.shift(periods=9)
df['lag10'] = df.y.shift(periods=10)

df.index = df['ds']
df = df.iloc[:, 1:]

df = df.dropna()

df.head(10)
# Out:
#                  y    lag1    lag2    lag3    lag4    lag5    lag6   lag7  \
# ds
# 2000-03-26  129.20 -268.40  296.20  -68.20  359.60  436.50  517.90  419.0
# 2000-04-02 -110.60  129.20 -268.40  296.20  -68.20  359.60  436.50  517.9
# 2000-04-09 -375.80 -110.60  129.20 -268.40  296.20  -68.20  359.60  436.5
# 2000-04-16  -38.25 -375.80 -110.60  129.20 -268.40  296.20  -68.20  359.6
# 2000-04-23 -170.35  -38.25 -375.80 -110.60  129.20 -268.40  296.20  -68.2
# 2000-04-30  247.00 -170.35  -38.25 -375.80 -110.60  129.20 -268.40  296.2
# 2000-05-07  120.80  247.00 -170.35  -38.25 -375.80 -110.60  129.20 -268.4
# 2000-05-14   11.80  120.80  247.00 -170.35  -38.25 -375.80 -110.60  129.2
# 2000-05-21  508.20   11.80  120.80  247.00 -170.35  -38.25 -375.80 -110.6
# 2000-05-28  -53.60  508.20   11.80  120.80  247.00 -170.35  -38.25 -375.8
#
#              lag8    lag9   lag10
# ds
# 2000-03-26  160.6  187.12 -173.42
# 2000-04-02  419.0  160.60  187.12
# 2000-04-09  517.9  419.00  160.60
# 2000-04-16  436.5  517.90  419.00
# 2000-04-23  359.6  436.50  517.90
# 2000-04-30  -68.2  359.60  436.50
# 2000-05-07  296.2  -68.20  359.60
# 2000-05-14 -268.4  296.20  -68.20
# 2000-05-21  129.2 -268.40  296.20
# 2000-05-28 -110.6  129.20 -268.40

# %% [markdown]
# ## Linear Regression
#
# IMPORTANT NOTE TO SELF:
# For smoothing using moving average, must RESCALE output predictions using inputs!!
#
# SECOND NOTE 2 SELF:
# for training/fitting/testing set...
#
# MODEL FOR DEPLOYMENT:
# Train a model that uses values from a year ago or OLDER to predict values and rescale according to moving averages...

# %%
X = df[['lag1', 'lag2', 'lag3', 'lag4', 'lag5', 'lag6', 'lag7', 'lag8', 'lag9', 'lag10']]
y= df['y']

# %%
X_test = X.loc['2018-10-14':  ,:]
y_test = y['2018-10-14':]

X_train = X.loc[:'2018-10-14', :]
X_train.tail()
# Out:
#              lag1   lag2   lag3   lag4    lag5    lag6    lag7    lag8  \
# ds
# 2018-09-16 -838.0 -135.3  154.4 -541.7  194.75   13.45  130.90 -554.10
# 2018-09-23    9.6 -838.0 -135.3  154.4 -541.70  194.75   13.45  130.90
# 2018-09-30   97.6    9.6 -838.0 -135.3  154.40 -541.70  194.75   13.45
# 2018-10-07  167.8   97.6    9.6 -838.0 -135.30  154.40 -541.70  194.75
# 2018-10-14 -198.3  167.8   97.6    9.6 -838.00 -135.30  154.40 -541.70
#
#               lag9   lag10
# ds
# 2018-09-16 -177.20 -572.00
# 2018-09-23 -554.10 -177.20
# 2018-09-30  130.90 -554.10
# 2018-10-07   13.45  130.90
# 2018-10-14  194.75   13.45

# %%
## Weekly train/test set dates
X_train = X.loc[:'2018-10-07', :]
y_train = y[:'2018-10-07']

## Daily training dates
#X_train = X.loc[:'2018-10-12', :]
#y_train = y[:'2018-10-12']

## Monthly training dates
#X_train = X.loc[:'2018-10-14', :]
#y_train = y[:'2018-10-14']

# %%
regressor = LinearRegression()

regressor.fit(X_train, y_train)
print(regressor.coef_)

y_pred = regressor.predict(X_test)
y_pred = pd.Series(y_pred)
y_pred.index = y_test.index
# y_pred = y_pred.reindex(X_test.index)
# Out:
# [ 0.27055819 -0.05730895  0.09159049 -0.03032833 -0.00128395  0.04870881
#   0.05155907  0.13880433 -0.08901912 -0.06075701]

# %% [markdown]
# ## Back to Scale before Performance Analysis

# %%
first = LME.loc[y_train.index[-1]]
unscaled = np.r_[first ,y_pred].cumsum()
#unscaled = unscaled[1:]
unscaled = pd.Series(unscaled)
unscaled = unscaled[1:]
unscaled.index = y_test.index

#original_y = unpreprocess(first, y_test)


original_y = np.r_[first ,y_test].cumsum()
original_y = pd.Series(original_y)
original_y = original_y[1:]
original_y.index = y_test.index
original_y.head()
# Out:
# ds
# 2018-10-14    12642.6
# 2018-10-21    12399.5
# 2018-10-28    12157.1
# 2018-11-04    11676.1
# 2018-11-11    11645.1
# dtype: float64

# %%
# Sanity check for unscaling! 

LME[LME.index=='2018-10-14']


#LME[LME.index=='2018-10-31']
# Out:
# Unnamed: 1
# 2018-10-14    12642.6
# Freq: W-SUN, Name: Cash Price ($/MT), dtype: float64

# %%
plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Linear Regression Prediction (weeks), ten lags', fontsize=15)

plt.show()

# %%
plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Linear Regression Prediction (business days) with NO GAP', fontsize=15)

plt.show()

# %%
plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Linear Regression Prediction with NO GAP', fontsize=15)

plt.show()

# %%
results = pd.DataFrame({'y_test': original_y, 'y_pred_unscaled': unscaled})
results['error'] = results['y_test'] - results['y_pred_unscaled']

results.head()
# Out:
#              y_test  y_pred_unscaled       error
# ds
# 2018-10-15  12534.5     12604.542763  -70.042763
# 2018-10-16  12516.5     12593.606584  -77.106584
# 2018-10-17  12298.5     12593.903442 -295.403442
# 2018-10-18  12276.0     12586.940450 -310.940450
# 2018-10-19  12372.0     12595.538589 -223.538589

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))
# Out:
# Mean Absolute Error: 1052.29939695051
# Mean Squared Error: 2370486.4222492315
# Root Mean Squared Error: 1539.6384063309254

# %% [markdown]
# # Other Kinds of Regression
#
# Grid Search for RIDGE Regression

# %%
from sklearn import linear_model

params1= ParameterGrid({'alpha' : [ .00001 ,.0001, .001, .01, .1, 1]
                            })

cv_results = {}

for params in params1:

    regressor = linear_model.Ridge(**params, random_state=1)

    print()
    print(params)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)

    first = LME.loc[y_train.index[-1]]
    unscaled = np.r_[first ,y_pred].cumsum()
    #unscaled = unscaled[1:]
    unscaled = pd.Series(unscaled)
    unscaled = unscaled[1:]
    unscaled.index = y_test.index


    original_y = np.r_[first ,y_test].cumsum()
    original_y = pd.Series(original_y)
    original_y = original_y[1:]
    original_y.index = y_test.index
    original_y.head()
    
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters

    '''Calculates maximum test accuracy value and parameters'''
    #min_test_accuracy, min_parameters = 0, 0
    min_test_accuracy = 3000
    for key, value in cv_results.items():
        if value < min_test_accuracy:
            min_test_accuracy = value
            min_parameters = key
            
print()
print('Ridge CV Results')
for key, value in cv_results.items():
    print(key, value)

print()
print('Best Results:')
if min_test_accuracy==3000:
    print('error')
else:
    print('Minimum Test Accuracy: ', min_test_accuracy)
print('Best Parameters: ', min_parameters)
print()

plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Ridge Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# {'alpha': 1e-05}
# Mean Absolute Error: 1052.2993969505155
# Mean Squared Error: 2370486.422249257
# Root Mean Squared Error: 1539.6384063309335
#
# {'alpha': 0.0001}
# Mean Absolute Error: 1052.2993969505649
# Mean Squared Error: 2370486.4222494643
# Root Mean Squared Error: 1539.6384063310009
#
# {'alpha': 0.001}
# Mean Absolute Error: 1052.2993969510549
# Mean Squared Error: 2370486.4222515603
# Root Mean Squared Error: 1539.6384063316816
#
# {'alpha': 0.01}
# Mean Absolute Error: 1052.299396955954
# Mean Squared Error: 2370486.4222724675
# Root Mean Squared Error: 1539.6384063384712
#
# {'alpha': 0.1}
# Mean Absolute Error: 1052.2993970049454
# Mean Squared Error: 2370486.4224815927
# Root Mean Squared Error: 1539.638406406385
#
# {'alpha': 1}
# Mean Absolute Error: 1052.299397494843
# Mean Squared Error: 2370486.4245727086
# Root Mean Squared Error: 1539.638407085478
#
# Ridge CV Results
# {'alpha': 1e-05} 1052.2993969505155
# {'alpha': 0.0001} 1052.2993969505649
# {'alpha': 0.001} 1052.2993969510549
# {'alpha': 0.01} 1052.299396955954
# {'alpha': 0.1} 1052.2993970049454
# {'alpha': 1} 1052.299397494843
#
# Best Results:
# Minimum Test Accuracy:  1052.2993969505155
# Best Parameters:  {'alpha': 1e-05}

# %%
from sklearn import linear_model

params1= ParameterGrid({'alpha' : [ .00001 ,.0001, .001, .01, .1, 1]
                            })

cv_results = {}

for params in params1:

    regressor = linear_model.Lasso(**params, random_state=1)

    print()
    print(params)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)

    first = LME.loc[y_train.index[-1]]
    unscaled = np.r_[first ,y_pred].cumsum()
    #unscaled = unscaled[1:]
    unscaled = pd.Series(unscaled)
    unscaled = unscaled[1:]
    unscaled.index = y_test.index


    original_y = np.r_[first ,y_test].cumsum()
    original_y = pd.Series(original_y)
    original_y = original_y[1:]
    original_y.index = y_test.index
    original_y.head()
    
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters

    '''Calculates maximum test accuracy value and parameters'''
    #min_test_accuracy, min_parameters = 0, 0
    min_test_accuracy = 3000
    for key, value in cv_results.items():
        if value < min_test_accuracy:
            min_test_accuracy = value
            min_parameters = key
            
print()
print('Ridge CV Results')
for key, value in cv_results.items():
    print(key, value)

print()
print('Best Results:')
if min_test_accuracy==3000:
    print('error')
else:
    print('Minimum Test Accuracy: ', min_test_accuracy)
print('Best Parameters: ', min_parameters)
print()

plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('LASSO Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# {'alpha': 1e-05}
# Mean Absolute Error: 1052.2993969680833
# Mean Squared Error: 2370486.422315655
# Root Mean Squared Error: 1539.6384063524963
#
# {'alpha': 0.0001}
# Mean Absolute Error: 1052.2993971259345
# Mean Squared Error: 2370486.4229121963
# Root Mean Squared Error: 1539.6384065462241
#
# {'alpha': 0.001}
# Mean Absolute Error: 1052.2993986927097
# Mean Squared Error: 2370486.4288306213
# Root Mean Squared Error: 1539.638408468242
#
# {'alpha': 0.01}
# Mean Absolute Error: 1052.2994142740197
# Mean Squared Error: 2370486.4876679564
# Root Mean Squared Error: 1539.6384275757591
#
# {'alpha': 0.1}
# Mean Absolute Error: 1052.2995639976043
# Mean Squared Error: 2370487.051640943
# Root Mean Squared Error: 1539.6386107268625
#
# {'alpha': 1}
# Mean Absolute Error: 1052.3010669461664
# Mean Squared Error: 2370492.712676831
# Root Mean Squared Error: 1539.6404491558512
#
# Ridge CV Results
# {'alpha': 1e-05} 1052.2993969680833
# {'alpha': 0.0001} 1052.2993971259345
# {'alpha': 0.001} 1052.2993986927097
# {'alpha': 0.01} 1052.2994142740197
# {'alpha': 0.1} 1052.2995639976043
# {'alpha': 1} 1052.3010669461664
#
# Best Results:
# Minimum Test Accuracy:  1052.2993969680833
# Best Parameters:  {'alpha': 1e-05}

# %%
from sklearn.ensemble import AdaBoostRegressor

params1= ParameterGrid({'n_estimators' : [50, 100, 150, 200, 250, 300, 350, 400, 450],
                            'learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3]})

cv_results = {}

for params in params1:

    regressor = AdaBoostRegressor(**params, random_state=1)

    print()
    print(params)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)

    first = LME.loc[y_train.index[-1]]
    unscaled = np.r_[first ,y_pred].cumsum()
    #unscaled = unscaled[1:]
    unscaled = pd.Series(unscaled)
    unscaled = unscaled[1:]
    unscaled.index = y_test.index


    original_y = np.r_[first ,y_test].cumsum()
    original_y = pd.Series(original_y)
    original_y = original_y[1:]
    original_y.index = y_test.index
    original_y.head()
    
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters

    '''Calculates maximum test accuracy value and parameters'''
    #min_test_accuracy, min_parameters = 0, 0
    min_test_accuracy = 3000
    for key, value in cv_results.items():
        if value < min_test_accuracy:
            min_test_accuracy = value
            min_parameters = key
            
print()
print('Adaboost CV Results')
for key, value in cv_results.items():
    print(key, value)

print()
print('Best Results:')
if min_test_accuracy==3000:
    print('error')
else:
    print('Minimum Test Accuracy: ', min_test_accuracy)
print('Best Parameters: ', min_parameters)
print()

plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Adaboost Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# {'learning_rate': 0.0001, 'n_estimators': 50}
# Mean Absolute Error: 1390.5061517640845
# Mean Squared Error: 3846104.780671628
# Root Mean Squared Error: 1961.148842049381
#
# {'learning_rate': 0.0001, 'n_estimators': 100}
# Mean Absolute Error: 1358.0365138630661
# Mean Squared Error: 3292784.8756465944
# Root Mean Squared Error: 1814.6032281594219
#
# {'learning_rate': 0.0001, 'n_estimators': 150}
# Mean Absolute Error: 1357.223476218421
# Mean Squared Error: 3170796.3339288095
# Root Mean Squared Error: 1780.6730002807392
#
# {'learning_rate': 0.0001, 'n_estimators': 200}
# Mean Absolute Error: 1360.0478391209379
# Mean Squared Error: 3167059.1377004213
# Root Mean Squared Error: 1779.6233134291147
#
# {'learning_rate': 0.0001, 'n_estimators': 250}
# Mean Absolute Error: 1361.1670895575037
# Mean Squared Error: 3228849.341387901
# Root Mean Squared Error: 1796.8999252568021
#
# {'learning_rate': 0.0001, 'n_estimators': 300}
# Mean Absolute Error: 1366.9164531291665
# Mean Squared Error: 3174112.3761854814
# Root Mean Squared Error: 1781.6038774613962
#
# {'learning_rate': 0.0001, 'n_estimators': 350}
# Mean Absolute Error: 1373.026166463784
# Mean Squared Error: 3106373.180859114
# Root Mean Squared Error: 1762.4906186584694
#
# {'learning_rate': 0.0001, 'n_estimators': 400}
# Mean Absolute Error: 1379.8889259005628
# Mean Squared Error: 3047678.18040769
# Root Mean Squared Error: 1745.7600580857868
#
# {'learning_rate': 0.0001, 'n_estimators': 450}
# Mean Absolute Error: 1375.8909480403804
# Mean Squared Error: 3040840.3510780297
# Root Mean Squared Error: 1743.8005479635651
#
# {'learning_rate': 0.001, 'n_estimators': 50}
# Mean Absolute Error: 1350.7171790115638
# Mean Squared Error: 3278494.5323980777
# Root Mean Squared Error: 1810.661352213074
#
# {'learning_rate': 0.001, 'n_estimators': 100}
# Mean Absolute Error: 1381.0394520913917
# Mean Squared Error: 3007477.536247345
# Root Mean Squared Error: 1734.208042954289
#
# {'learning_rate': 0.001, 'n_estimators': 150}
# Mean Absolute Error: 1361.8787705695217
# Mean Squared Error: 3169432.5208556335
# Root Mean Squared Error: 1780.2900103229342
#
# {'learning_rate': 0.001, 'n_estimators': 200}
# Mean Absolute Error: 1356.0549456251345
# Mean Squared Error: 3167984.8583381907
# Root Mean Squared Error: 1779.883383353581
#
# {'learning_rate': 0.001, 'n_estimators': 250}
# Mean Absolute Error: 1354.6180385290213
# Mean Squared Error: 3288077.124197676
# Root Mean Squared Error: 1813.305579376426
#
# {'learning_rate': 0.001, 'n_estimators': 300}
# Mean Absolute Error: 1355.0128730692413
# Mean Squared Error: 3250418.5131101734
# Root Mean Squared Error: 1802.8917086475753
#
# {'learning_rate': 0.001, 'n_estimators': 350}
# Mean Absolute Error: 1355.4425354768184
# Mean Squared Error: 3297737.554504624
# Root Mean Squared Error: 1815.967388061973
#
# {'learning_rate': 0.001, 'n_estimators': 400}
# Mean Absolute Error: 1355.4955689465185
# Mean Squared Error: 3249450.9024705235
# Root Mean Squared Error: 1802.623339045216
#
# {'learning_rate': 0.001, 'n_estimators': 450}
# Mean Absolute Error: 1354.098985145413
# Mean Squared Error: 3301617.346152268
# Root Mean Squared Error: 1817.0353178054268
#
# {'learning_rate': 0.01, 'n_estimators': 50}
# Mean Absolute Error: 1372.4060273549894
# Mean Squared Error: 3324582.0844781175
# Root Mean Squared Error: 1823.3436550683793
#
# {'learning_rate': 0.01, 'n_estimators': 100}
# Mean Absolute Error: 1374.4546523629353
# Mean Squared Error: 3610706.781230246
# Root Mean Squared Error: 1900.1859859577553
#
# {'learning_rate': 0.01, 'n_estimators': 150}
# Mean Absolute Error: 1356.826401657207
# Mean Squared Error: 3302621.631070712
# Root Mean Squared Error: 1817.3116494070885
#
# {'learning_rate': 0.01, 'n_estimators': 200}
# Mean Absolute Error: 1358.871040732776
# Mean Squared Error: 3379559.8230376616
# Root Mean Squared Error: 1838.357914835319
#
# {'learning_rate': 0.01, 'n_estimators': 250}
# Mean Absolute Error: 1364.7169300359478
# Mean Squared Error: 3510692.32347975
# Root Mean Squared Error: 1873.6841578771355
#
# {'learning_rate': 0.01, 'n_estimators': 300}
# Mean Absolute Error: 1370.6451935288853
# Mean Squared Error: 3628708.2585707433
# Root Mean Squared Error: 1904.9168639525303
#
# {'learning_rate': 0.01, 'n_estimators': 350}
# Mean Absolute Error: 1378.109031348247
# Mean Squared Error: 3769959.8713877928
# Root Mean Squared Error: 1941.6384502238807
#
# {'learning_rate': 0.01, 'n_estimators': 400}
# Mean Absolute Error: 1383.1420291642714
# Mean Squared Error: 3866012.199531072
# Root Mean Squared Error: 1966.217739603392
#
# {'learning_rate': 0.01, 'n_estimators': 450}
# Mean Absolute Error: 1396.7468186948422
# Mean Squared Error: 4039983.5234021377
# Root Mean Squared Error: 2009.9710255130888
#
# {'learning_rate': 0.1, 'n_estimators': 50}
# Mean Absolute Error: 1393.125925689955
# Mean Squared Error: 3999841.562014226
# Root Mean Squared Error: 1999.9603901113207
#
# {'learning_rate': 0.1, 'n_estimators': 100}
# Mean Absolute Error: 1373.699590300122
# Mean Squared Error: 4112968.116513356
# Root Mean Squared Error: 2028.04539310967
#
# {'learning_rate': 0.1, 'n_estimators': 150}
# Mean Absolute Error: 1418.7692105521653
# Mean Squared Error: 4484746.693187976
# Root Mean Squared Error: 2117.722052864345
#
# {'learning_rate': 0.1, 'n_estimators': 200}
# Mean Absolute Error: 1601.8562381285035
# Mean Squared Error: 5348788.546528811
# Root Mean Squared Error: 2312.7448079130586
#
# {'learning_rate': 0.1, 'n_estimators': 250}
# Mean Absolute Error: 1760.8326362487987
# Mean Squared Error: 6063366.219286365
# Root Mean Squared Error: 2462.390346652286
#
# {'learning_rate': 0.1, 'n_estimators': 300}
# Mean Absolute Error: 2211.4733613681724
# Mean Squared Error: 9038649.7631744
# Root Mean Squared Error: 3006.4347262454244
#
# {'learning_rate': 0.1, 'n_estimators': 350}
# Mean Absolute Error: 2211.4733613681724
# Mean Squared Error: 9038649.7631744
# Root Mean Squared Error: 3006.4347262454244
#
# {'learning_rate': 0.1, 'n_estimators': 400}
# Mean Absolute Error: 2211.4733613681724
# Mean Squared Error: 9038649.7631744
# Root Mean Squared Error: 3006.4347262454244
#
# {'learning_rate': 0.1, 'n_estimators': 450}
# Mean Absolute Error: 2211.4733613681724
# Mean Squared Error: 9038649.7631744
# Root Mean Squared Error: 3006.4347262454244
#
# {'learning_rate': 0.2, 'n_estimators': 50}
# Mean Absolute Error: 1447.090292658821
# Mean Squared Error: 4636033.940492143
# Root Mean Squared Error: 2153.145127596406
#
# {'learning_rate': 0.2, 'n_estimators': 100}
# Mean Absolute Error: 2015.9765174397328
# Mean Squared Error: 8016822.999399192
# Root Mean Squared Error: 2831.399477184241
#
# {'learning_rate': 0.2, 'n_estimators': 150}
# Mean Absolute Error: 2730.431305866706
# Mean Squared Error: 13443470.06653702
# Root Mean Squared Error: 3666.533794544518
#
# {'learning_rate': 0.2, 'n_estimators': 200}
# Mean Absolute Error: 2857.170215748293
# Mean Squared Error: 14314950.763887677
# Root Mean Squared Error: 3783.510375813403
#
# {'learning_rate': 0.2, 'n_estimators': 250}
# Mean Absolute Error: 2857.170215748293
# Mean Squared Error: 14314950.763887677
# Root Mean Squared Error: 3783.510375813403
#
# {'learning_rate': 0.2, 'n_estimators': 300}
# Mean Absolute Error: 2857.170215748293
# Mean Squared Error: 14314950.763887677
# Root Mean Squared Error: 3783.510375813403
#
# {'learning_rate': 0.2, 'n_estimators': 350}
# Mean Absolute Error: 2857.170215748293
# Mean Squared Error: 14314950.763887677
# Root Mean Squared Error: 3783.510375813403
#
# {'learning_rate': 0.2, 'n_estimators': 400}
# Mean Absolute Error: 2857.170215748293
# Mean Squared Error: 14314950.763887677
# Root Mean Squared Error: 3783.510375813403
#
# {'learning_rate': 0.2, 'n_estimators': 450}
# Mean Absolute Error: 2857.170215748293
# Mean Squared Error: 14314950.763887677
# Root Mean Squared Error: 3783.510375813403
#
# {'learning_rate': 0.3, 'n_estimators': 50}
# Mean Absolute Error: 2679.7493333570237
# Mean Squared Error: 13195023.104562176
# Root Mean Squared Error: 3632.495437651942
#
# {'learning_rate': 0.3, 'n_estimators': 100}
# Mean Absolute Error: 2927.9234250838986
# Mean Squared Error: 14926153.909236915
# Root Mean Squared Error: 3863.4380943968695
#
# {'learning_rate': 0.3, 'n_estimators': 150}
# Mean Absolute Error: 2927.9234250838986
# Mean Squared Error: 14926153.909236915
# Root Mean Squared Error: 3863.4380943968695
#
# {'learning_rate': 0.3, 'n_estimators': 200}
# Mean Absolute Error: 2927.9234250838986
# Mean Squared Error: 14926153.909236915
# Root Mean Squared Error: 3863.4380943968695
#
# {'learning_rate': 0.3, 'n_estimators': 250}
# Mean Absolute Error: 2927.9234250838986
# Mean Squared Error: 14926153.909236915
# Root Mean Squared Error: 3863.4380943968695
#
# {'learning_rate': 0.3, 'n_estimators': 300}
# Mean Absolute Error: 2927.9234250838986
# Mean Squared Error: 14926153.909236915
# Root Mean Squared Error: 3863.4380943968695
#
# {'learning_rate': 0.3, 'n_estimators': 350}
# Mean Absolute Error: 2927.9234250838986
# Mean Squared Error: 14926153.909236915
# Root Mean Squared Error: 3863.4380943968695
#
# {'learning_rate': 0.3, 'n_estimators': 400}
# Mean Absolute Error: 2927.9234250838986
# Mean Squared Error: 14926153.909236915
# Root Mean Squared Error: 3863.4380943968695
#
# {'learning_rate': 0.3, 'n_estimators': 450}
# Mean Absolute Error: 2927.9234250838986
# Mean Squared Error: 14926153.909236915
# Root Mean Squared Error: 3863.4380943968695
#
# Adaboost CV Results
# {'learning_rate': 0.0001, 'n_estimators': 50} 1390.5061517640845
# {'learning_rate': 0.0001, 'n_estimators': 100} 1358.0365138630661
# {'learning_rate': 0.0001, 'n_estimators': 150} 1357.223476218421
# {'learning_rate': 0.0001, 'n_estimators': 200} 1360.0478391209379
# {'learning_rate': 0.0001, 'n_estimators': 250} 1361.1670895575037
# {'learning_rate': 0.0001, 'n_estimators': 300} 1366.9164531291665
# {'learning_rate': 0.0001, 'n_estimators': 350} 1373.026166463784
# {'learning_rate': 0.0001, 'n_estimators': 400} 1379.8889259005628
# {'learning_rate': 0.0001, 'n_estimators': 450} 1375.8909480403804
# {'learning_rate': 0.001, 'n_estimators': 50} 1350.7171790115638
# {'learning_rate': 0.001, 'n_estimators': 100} 1381.0394520913917
# {'learning_rate': 0.001, 'n_estimators': 150} 1361.8787705695217
# {'learning_rate': 0.001, 'n_estimators': 200} 1356.0549456251345
# {'learning_rate': 0.001, 'n_estimators': 250} 1354.6180385290213
# {'learning_rate': 0.001, 'n_estimators': 300} 1355.0128730692413
# {'learning_rate': 0.001, 'n_estimators': 350} 1355.4425354768184
# {'learning_rate': 0.001, 'n_estimators': 400} 1355.4955689465185
# {'learning_rate': 0.001, 'n_estimators': 450} 1354.098985145413
# {'learning_rate': 0.01, 'n_estimators': 50} 1372.4060273549894
# {'learning_rate': 0.01, 'n_estimators': 100} 1374.4546523629353
# {'learning_rate': 0.01, 'n_estimators': 150} 1356.826401657207
# {'learning_rate': 0.01, 'n_estimators': 200} 1358.871040732776
# {'learning_rate': 0.01, 'n_estimators': 250} 1364.7169300359478
# {'learning_rate': 0.01, 'n_estimators': 300} 1370.6451935288853
# {'learning_rate': 0.01, 'n_estimators': 350} 1378.109031348247
# {'learning_rate': 0.01, 'n_estimators': 400} 1383.1420291642714
# {'learning_rate': 0.01, 'n_estimators': 450} 1396.7468186948422
# {'learning_rate': 0.1, 'n_estimators': 50} 1393.125925689955
# {'learning_rate': 0.1, 'n_estimators': 100} 1373.699590300122
# {'learning_rate': 0.1, 'n_estimators': 150} 1418.7692105521653
# {'learning_rate': 0.1, 'n_estimators': 200} 1601.8562381285035
# {'learning_rate': 0.1, 'n_estimators': 250} 1760.8326362487987
# {'learning_rate': 0.1, 'n_estimators': 300} 2211.4733613681724
# {'learning_rate': 0.1, 'n_estimators': 350} 2211.4733613681724
# {'learning_rate': 0.1, 'n_estimators': 400} 2211.4733613681724
# {'learning_rate': 0.1, 'n_estimators': 450} 2211.4733613681724
# {'learning_rate': 0.2, 'n_estimators': 50} 1447.090292658821
# {'learning_rate': 0.2, 'n_estimators': 100} 2015.9765174397328
# {'learning_rate': 0.2, 'n_estimators': 150} 2730.431305866706
# {'learning_rate': 0.2, 'n_estimators': 200} 2857.170215748293
# {'learning_rate': 0.2, 'n_estimators': 250} 2857.170215748293
# {'learning_rate': 0.2, 'n_estimators': 300} 2857.170215748293
# {'learning_rate': 0.2, 'n_estimators': 350} 2857.170215748293
# {'learning_rate': 0.2, 'n_estimators': 400} 2857.170215748293
# {'learning_rate': 0.2, 'n_estimators': 450} 2857.170215748293
# {'learning_rate': 0.3, 'n_estimators': 50} 2679.7493333570237
# {'learning_rate': 0.3, 'n_estimators': 100} 2927.9234250838986
# {'learning_rate': 0.3, 'n_estimators': 150} 2927.9234250838986
# {'learning_rate': 0.3, 'n_estimators': 200} 2927.9234250838986
# {'learning_rate': 0.3, 'n_estimators': 250} 2927.9234250838986
# {'learning_rate': 0.3, 'n_estimators': 300} 2927.9234250838986
# {'learning_rate': 0.3, 'n_estimators': 350} 2927.9234250838986
# {'learning_rate': 0.3, 'n_estimators': 400} 2927.9234250838986
# {'learning_rate': 0.3, 'n_estimators': 450} 2927.9234250838986
#
# Best Results:
# Minimum Test Accuracy:  1350.7171790115638
# Best Parameters:  {'learning_rate': 0.001, 'n_estimators': 50}

# %%
from sklearn.ensemble import RandomForestRegressor

params1= ParameterGrid({'n_estimators' : [50, 100, 150, 200, 250, 300, 350, 400, 450],
                            'min_samples_leaf': [ .15,  .25, .35, .45]})

cv_results = {}

for params in params1:

    regressor = RandomForestRegressor(**params, random_state=1)

    print()
    print(params)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)

    first = LME.loc[y_train.index[-1]]
    unscaled = np.r_[first ,y_pred].cumsum()
    #unscaled = unscaled[1:]
    unscaled = pd.Series(unscaled)
    unscaled = unscaled[1:]
    unscaled.index = y_test.index


    original_y = np.r_[first ,y_test].cumsum()
    original_y = pd.Series(original_y)
    original_y = original_y[1:]
    original_y.index = y_test.index
    original_y.head()
    
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters

    '''Calculates maximum test accuracy value and parameters'''
    #min_test_accuracy, min_parameters = 0, 0
    min_test_accuracy = 3000
    for key, value in cv_results.items():
        if value < min_test_accuracy:
            min_test_accuracy = value
            min_parameters = key
            
print()
print('Random Forest CV Results')
for key, value in cv_results.items():
    print(key, value)

print()
print('Best Results:')
if min_test_accuracy==3000:
    print('error')
else:
    print('Minimum Test Accuracy: ', min_test_accuracy)
print('Best Parameters: ', min_parameters)
print()

plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Random Forest Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# {'min_samples_leaf': 0.15, 'n_estimators': 50}
# Mean Absolute Error: 1053.203249990752
# Mean Squared Error: 2883582.9742621854
# Root Mean Squared Error: 1698.111590638903
#
# {'min_samples_leaf': 0.15, 'n_estimators': 100}
# Mean Absolute Error: 1065.9974547361617
# Mean Squared Error: 3006054.0987048494
# Root Mean Squared Error: 1733.7975945031328
#
# {'min_samples_leaf': 0.15, 'n_estimators': 150}
# Mean Absolute Error: 1078.3864098283561
# Mean Squared Error: 3082010.333613978
# Root Mean Squared Error: 1755.5655309939239
#
# {'min_samples_leaf': 0.15, 'n_estimators': 200}
# Mean Absolute Error: 1059.9161129101437
# Mean Squared Error: 2969642.7256504833
# Root Mean Squared Error: 1723.2651350417566
#
# {'min_samples_leaf': 0.15, 'n_estimators': 250}
# Mean Absolute Error: 1079.1158740556912
# Mean Squared Error: 3094842.118842713
# Root Mean Squared Error: 1759.2163365665729
#
# {'min_samples_leaf': 0.15, 'n_estimators': 300}
# Mean Absolute Error: 1074.0054051068118
# Mean Squared Error: 3065189.219670786
# Root Mean Squared Error: 1750.7681798772749
#
# {'min_samples_leaf': 0.15, 'n_estimators': 350}
# Mean Absolute Error: 1085.8811777483747
# Mean Squared Error: 3126605.96006723
# Root Mean Squared Error: 1768.2211287243545
#
# {'min_samples_leaf': 0.15, 'n_estimators': 400}
# Mean Absolute Error: 1075.9831326990784
# Mean Squared Error: 3073415.5878403806
# Root Mean Squared Error: 1753.11596531444
#
# {'min_samples_leaf': 0.15, 'n_estimators': 450}
# Mean Absolute Error: 1075.6238703980514
# Mean Squared Error: 3076650.941867664
# Root Mean Squared Error: 1754.0384664732026
#
# {'min_samples_leaf': 0.25, 'n_estimators': 50}
# Mean Absolute Error: 1097.613334722593
# Mean Squared Error: 2764702.7365244552
# Root Mean Squared Error: 1662.739527564211
#
# {'min_samples_leaf': 0.25, 'n_estimators': 100}
# Mean Absolute Error: 1118.7530835374953
# Mean Squared Error: 3018292.05446276
# Root Mean Squared Error: 1737.3232440921179
#
# {'min_samples_leaf': 0.25, 'n_estimators': 150}
# Mean Absolute Error: 1126.1992230980684
# Mean Squared Error: 3118949.1493613725
# Root Mean Squared Error: 1766.0546847029887
#
# {'min_samples_leaf': 0.25, 'n_estimators': 200}
# Mean Absolute Error: 1113.9096049849468
# Mean Squared Error: 2989594.4436116633
# Root Mean Squared Error: 1729.0443729446804
#
# {'min_samples_leaf': 0.25, 'n_estimators': 250}
# Mean Absolute Error: 1119.7100276888864
# Mean Squared Error: 3054638.8647161666
# Root Mean Squared Error: 1747.7525181547205
#
# {'min_samples_leaf': 0.25, 'n_estimators': 300}
# Mean Absolute Error: 1112.1338142185582
# Mean Squared Error: 2983162.4579414367
# Root Mean Squared Error: 1727.183388624797
#
# {'min_samples_leaf': 0.25, 'n_estimators': 350}
# Mean Absolute Error: 1118.5253929618295
# Mean Squared Error: 3045783.211922538
# Root Mean Squared Error: 1745.217239177558
#
# {'min_samples_leaf': 0.25, 'n_estimators': 400}
# Mean Absolute Error: 1114.268966528716
# Mean Squared Error: 2986078.5372752068
# Root Mean Squared Error: 1728.02735431914
#
# {'min_samples_leaf': 0.25, 'n_estimators': 450}
# Mean Absolute Error: 1112.5312571097309
# Mean Squared Error: 2975913.2844490325
# Root Mean Squared Error: 1725.0835586860808
#
# {'min_samples_leaf': 0.35, 'n_estimators': 50}
# Mean Absolute Error: 1431.5097905060022
# Mean Squared Error: 4150346.948029513
# Root Mean Squared Error: 2037.240032011327
#
# {'min_samples_leaf': 0.35, 'n_estimators': 100}
# Mean Absolute Error: 1460.9295846483687
# Mean Squared Error: 4486739.246951677
# Root Mean Squared Error: 2118.1924480442462
#
# {'min_samples_leaf': 0.35, 'n_estimators': 150}
# Mean Absolute Error: 1467.7878221469432
# Mean Squared Error: 4570945.779864748
# Root Mean Squared Error: 2137.977029779494
#
# {'min_samples_leaf': 0.35, 'n_estimators': 200}
# Mean Absolute Error: 1461.3766448606357
# Mean Squared Error: 4492161.64693689
# Root Mean Squared Error: 2119.4720207959554
#
# {'min_samples_leaf': 0.35, 'n_estimators': 250}
# Mean Absolute Error: 1468.296177286446
# Mean Squared Error: 4577274.562323499
# Root Mean Squared Error: 2139.4566044497137
#
# {'min_samples_leaf': 0.35, 'n_estimators': 300}
# Mean Absolute Error: 1461.9630558333326
# Mean Squared Error: 4499288.332771389
# Root Mean Squared Error: 2121.152595352675
#
# {'min_samples_leaf': 0.35, 'n_estimators': 350}
# Mean Absolute Error: 1468.906690412894
# Mean Squared Error: 4584891.054392534
# Root Mean Squared Error: 2141.2358707981084
#
# {'min_samples_leaf': 0.35, 'n_estimators': 400}
# Mean Absolute Error: 1463.9922682986657
# Mean Squared Error: 4524072.94003875
# Root Mean Squared Error: 2126.9868217830476
#
# {'min_samples_leaf': 0.35, 'n_estimators': 450}
# Mean Absolute Error: 1462.5970069411046
# Mean Squared Error: 4507010.7741301935
# Root Mean Squared Error: 2122.972155759513
#
# {'min_samples_leaf': 0.45, 'n_estimators': 50}
# Mean Absolute Error: 1431.5097905060022
# Mean Squared Error: 4150346.948029513
# Root Mean Squared Error: 2037.240032011327
#
# {'min_samples_leaf': 0.45, 'n_estimators': 100}
# Mean Absolute Error: 1460.9295846483687
# Mean Squared Error: 4486739.246951677
# Root Mean Squared Error: 2118.1924480442462
#
# {'min_samples_leaf': 0.45, 'n_estimators': 150}
# Mean Absolute Error: 1467.7878221469432
# Mean Squared Error: 4570945.779864748
# Root Mean Squared Error: 2137.977029779494
#
# {'min_samples_leaf': 0.45, 'n_estimators': 200}
# Mean Absolute Error: 1461.3766448606357
# Mean Squared Error: 4492161.64693689
# Root Mean Squared Error: 2119.4720207959554
#
# {'min_samples_leaf': 0.45, 'n_estimators': 250}
# Mean Absolute Error: 1468.296177286446
# Mean Squared Error: 4577274.562323499
# Root Mean Squared Error: 2139.4566044497137
#
# {'min_samples_leaf': 0.45, 'n_estimators': 300}
# Mean Absolute Error: 1461.9630558333326
# Mean Squared Error: 4499288.332771389
# Root Mean Squared Error: 2121.152595352675
#
# {'min_samples_leaf': 0.45, 'n_estimators': 350}
# Mean Absolute Error: 1468.906690412894
# Mean Squared Error: 4584891.054392534
# Root Mean Squared Error: 2141.2358707981084
#
# {'min_samples_leaf': 0.45, 'n_estimators': 400}
# Mean Absolute Error: 1463.9922682986657
# Mean Squared Error: 4524072.94003875
# Root Mean Squared Error: 2126.9868217830476
#
# {'min_samples_leaf': 0.45, 'n_estimators': 450}
# Mean Absolute Error: 1462.5970069411046
# Mean Squared Error: 4507010.7741301935
# Root Mean Squared Error: 2122.972155759513
#
# Adaboost CV Results
# {'min_samples_leaf': 0.15, 'n_estimators': 50} 1053.203249990752
# {'min_samples_leaf': 0.15, 'n_estimators': 100} 1065.9974547361617
# {'min_samples_leaf': 0.15, 'n_estimators': 150} 1078.3864098283561
# {'min_samples_leaf': 0.15, 'n_estimators': 200} 1059.9161129101437
# {'min_samples_leaf': 0.15, 'n_estimators': 250} 1079.1158740556912
# {'min_samples_leaf': 0.15, 'n_estimators': 300} 1074.0054051068118
# {'min_samples_leaf': 0.15, 'n_estimators': 350} 1085.8811777483747
# {'min_samples_leaf': 0.15, 'n_estimators': 400} 1075.9831326990784
# {'min_samples_leaf': 0.15, 'n_estimators': 450} 1075.6238703980514
# {'min_samples_leaf': 0.25, 'n_estimators': 50} 1097.613334722593
# {'min_samples_leaf': 0.25, 'n_estimators': 100} 1118.7530835374953
# {'min_samples_leaf': 0.25, 'n_estimators': 150} 1126.1992230980684
# {'min_samples_leaf': 0.25, 'n_estimators': 200} 1113.9096049849468
# {'min_samples_leaf': 0.25, 'n_estimators': 250} 1119.7100276888864
# {'min_samples_leaf': 0.25, 'n_estimators': 300} 1112.1338142185582
# {'min_samples_leaf': 0.25, 'n_estimators': 350} 1118.5253929618295
# {'min_samples_leaf': 0.25, 'n_estimators': 400} 1114.268966528716
# {'min_samples_leaf': 0.25, 'n_estimators': 450} 1112.5312571097309
# {'min_samples_leaf': 0.35, 'n_estimators': 50} 1431.5097905060022
# {'min_samples_leaf': 0.35, 'n_estimators': 100} 1460.9295846483687
# {'min_samples_leaf': 0.35, 'n_estimators': 150} 1467.7878221469432
# {'min_samples_leaf': 0.35, 'n_estimators': 200} 1461.3766448606357
# {'min_samples_leaf': 0.35, 'n_estimators': 250} 1468.296177286446
# {'min_samples_leaf': 0.35, 'n_estimators': 300} 1461.9630558333326
# {'min_samples_leaf': 0.35, 'n_estimators': 350} 1468.906690412894
# {'min_samples_leaf': 0.35, 'n_estimators': 400} 1463.9922682986657
# {'min_samples_leaf': 0.35, 'n_estimators': 450} 1462.5970069411046
# {'min_samples_leaf': 0.45, 'n_estimators': 50} 1431.5097905060022
# {'min_samples_leaf': 0.45, 'n_estimators': 100} 1460.9295846483687
# {'min_samples_leaf': 0.45, 'n_estimators': 150} 1467.7878221469432
# {'min_samples_leaf': 0.45, 'n_estimators': 200} 1461.3766448606357
# {'min_samples_leaf': 0.45, 'n_estimators': 250} 1468.296177286446
# {'min_samples_leaf': 0.45, 'n_estimators': 300} 1461.9630558333326
# {'min_samples_leaf': 0.45, 'n_estimators': 350} 1468.906690412894
# {'min_samples_leaf': 0.45, 'n_estimators': 400} 1463.9922682986657
# {'min_samples_leaf': 0.45, 'n_estimators': 450} 1462.5970069411046
#
# Best Results:
# Minimum Test Accuracy:  1053.203249990752
# Best Parameters:  {'min_samples_leaf': 0.15, 'n_estimators': 50}

# %%
from sklearn import neighbors

cv_results = {}

for K in range(7):
    K = K+1
    regressor = neighbors.KNeighborsRegressor(n_neighbors=K)

    print()
    print('K: ', K)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)

    first = LME.loc[y_train.index[-1]]
    unscaled = np.r_[first ,y_pred].cumsum()
    #unscaled = unscaled[1:]
    unscaled = pd.Series(unscaled)
    unscaled = unscaled[1:]
    unscaled.index = y_test.index


    original_y = np.r_[first ,y_test].cumsum()
    original_y = pd.Series(original_y)
    original_y = original_y[1:]
    original_y.index = y_test.index
    original_y.head()
    
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Random Forest Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()

print(cv_results)
# Out:
# K:  1
# Mean Absolute Error: 1860.8900000000006
# Mean Squared Error: 4859533.400198116
# Root Mean Squared Error: 2204.434938980535
#
# K:  2
# Mean Absolute Error: 1362.5923584905663
# Mean Squared Error: 3762909.163205189
# Root Mean Squared Error: 1939.8219411083041
#
# K:  3
# Mean Absolute Error: 1316.2533962264147
# Mean Squared Error: 3520981.252653458
# Root Mean Squared Error: 1876.427790418128
#
# K:  4
# Mean Absolute Error: 1266.1191509433963
# Mean Squared Error: 3374854.0210646233
# Root Mean Squared Error: 1837.0775762238848
#
# K:  5
# Mean Absolute Error: 1539.9027547169803
# Mean Squared Error: 5156003.596233432
# Root Mean Squared Error: 2270.6835086011947
#
# K:  6
# Mean Absolute Error: 1366.9717610062892
# Mean Squared Error: 4347898.717354716
# Root Mean Squared Error: 2085.1615566556748
#
# K:  7
# Mean Absolute Error: 1257.882803234501
# Mean Squared Error: 3482268.161344008
# Root Mean Squared Error: 1866.0836426441363
# {"{'min_samples_leaf': 0.45, 'n_estimators': 450}": 1257.882803234501}

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=2)

X_poly = polynomial_features.fit_transform(X_train)

regressor = LinearRegression()
regressor.fit(X_poly, y_train)

X_poly_test = polynomial_features.fit_transform(X_test)
y_poly_pred = regressor.predict(X_poly_test)
y_poly_pred = pd.Series(y_poly_pred)
y_poly_pred.index = y_test.index

mae = np.sqrt(metrics.mean_absolute_error(y_test,y_poly_pred))
print('MAE for scaled results: ', mae)
print()

first = LME.loc[y_train.index[-1]]
unscaled = np.r_[first ,y_poly_pred].cumsum()
#unscaled = unscaled[1:]
unscaled = pd.Series(unscaled)
unscaled = unscaled[1:]
unscaled.index = y_test.index


original_y = np.r_[first ,y_test].cumsum()
original_y = pd.Series(original_y)
original_y = original_y[1:]
original_y.index = y_test.index
original_y.head()


print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))


mae = metrics.mean_absolute_error(original_y, unscaled)
print('Polynomial MAE of Degree = 2: ', mae)
#print('kfold test accuracy =', kfold_test_accuracy)

# To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Polynomial Regression (deg=2) Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# MAE for scaled results:  18.04193657071033
#
# Mean Absolute Error: 1056.1740496518855
# Mean Squared Error: 2131620.8899500538
# Root Mean Squared Error: 1460.0071540749566
# Polynomial MAE of Degree = 2:  1056.1740496518855

# %%
polynomial_features= PolynomialFeatures(degree=3)

X_poly = polynomial_features.fit_transform(X_train)

regressor = LinearRegression()
regressor.fit(X_poly, y_train)

X_poly_test = polynomial_features.fit_transform(X_test)
y_poly_pred = regressor.predict(X_poly_test)
y_poly_pred = pd.Series(y_poly_pred)
y_poly_pred.index = y_test.index

mae = np.sqrt(metrics.mean_absolute_error(y_test,y_poly_pred))
print('MAE for scaled results: ', mae)
print()

first = LME.loc[y_train.index[-1]]
unscaled = np.r_[first ,y_poly_pred].cumsum()
#unscaled = unscaled[1:]
unscaled = pd.Series(unscaled)
unscaled = unscaled[1:]
unscaled.index = y_test.index


original_y = np.r_[first ,y_test].cumsum()
original_y = pd.Series(original_y)
original_y = original_y[1:]
original_y.index = y_test.index
original_y.head()


print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))


mae = metrics.mean_absolute_error(original_y, unscaled)
print('Polynomial MAE of Degree = 3: ', mae)
#print('kfold test accuracy =', kfold_test_accuracy)

# To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Polynomial Regression Prediction (deg=3) - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# MAE for scaled results:  18.85891762615875
#
# Mean Absolute Error: 1051.6959968650451
# Mean Squared Error: 2359961.1817646585
# Root Mean Squared Error: 1536.2165152623047
# Polynomial MAE of Degree = 3:  1051.6959968650451

# %%
polynomial_features= PolynomialFeatures(degree=4)

X_poly = polynomial_features.fit_transform(X_train)

regressor = LinearRegression()
regressor.fit(X_poly, y_train)

X_poly_test = polynomial_features.fit_transform(X_test)
y_poly_pred = regressor.predict(X_poly_test)
y_poly_pred = pd.Series(y_poly_pred)
y_poly_pred.index = y_test.index

mae = np.sqrt(metrics.mean_absolute_error(y_test,y_poly_pred))
print('MAE for scaled results: ', mae)
print()

first = LME.loc[y_train.index[-1]]
unscaled = np.r_[first ,y_poly_pred].cumsum()
#unscaled = unscaled[1:]
unscaled = pd.Series(unscaled)
unscaled = unscaled[1:]
unscaled.index = y_test.index


original_y = np.r_[first ,y_test].cumsum()
original_y = pd.Series(original_y)
original_y = original_y[1:]
original_y.index = y_test.index
original_y.head()


print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))


mae = metrics.mean_absolute_error(original_y, unscaled)
print('Polynomial MAE of Degree = 2: ', mae)
#print('kfold test accuracy =', kfold_test_accuracy)

# To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Polynomial Regression (deg = 4) Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# MAE for scaled results:  175.6742828636506
#
# Mean Absolute Error: 121252.37682852542
# Mean Squared Error: 75171100600.5853
# Root Mean Squared Error: 274173.48631949315
# Polynomial MAE of Degree = 2:  121252.37682852542

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true))*100

def root_mean_squared_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.sqrt(((y_pred - y_true) **2).mean())
    #return np.mean(np.abs((y_true - y_pred) / y_true))*100

# %%
print('mape', mean_absolute_percentage_error(cmp_df['y'], cmp_df['yhat']))

print('rmse', root_mean_squared_error(cmp_df['y'], cmp_df['yhat']))
# Out:
# mape 219.83967767924054
# rmse 0.05529372373011725

# %%
pd.DataFrame({'mean':tester.rolling(window=3).mean(), 'original': tester})
# Out:
#        mean  original
# 0       NaN       1.0
# 1       NaN       2.0
# 2  2.000000       3.0
# 3  3.000000       4.0
# 4  6.000000      11.0
# 5  7.000000       6.0
# 6  8.000000       7.0
# 7  7.000000       8.0
# 8  8.000000       9.0
# 9  5.833333       0.5
