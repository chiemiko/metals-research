# %%
import pandas as pd
from matplotlib import pyplot as plt
import re

from statsmodels.tsa.stattools import adfuller

from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

import numpy as np
import fbprophet
from fbprophet import Prophet
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
from pylab import rcParams
import datetime

import logging

from sklearn.metrics import mean_absolute_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from sklearn.linear_model import LinearRegression

from sklearn import metrics

from sklearn.model_selection import ParameterGrid
from sklearn.linear_model import Ridge


logging.getLogger().setLevel(logging.ERROR)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.Series(timeseries).rolling(window=4).mean()
    #pd.rolling_mean(timeseries, window=12)
    rolstd =  pd.Series(timeseries).rolling(window=4).std()
#Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    # dftest = adfuller(timeseries, autolag='AIC')
    dftest = adfuller(timeseries)
    
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
LME_futures = pd.read_excel('forecasting_raw_data/LME Futures Price.xlsx')
LME_futures = LME_futures.iloc[3:, 1:]
#LME_futures['Unnamed: 1'] = pd.datetime(LME_futures['Unnamed: 1'])
LME_futures.index = LME_futures['Unnamed: 1']



LME_futures = LME_futures.iloc[:, 1:]
LME_futures = LME_futures[LME_futures.index.year>=2000]
LME_futures.isnull().sum()
LME = LME_futures.iloc[:, 0]
LME = LME.astype(float)
LME = LME.resample('B').mean()

# %%
#plt.plot(LME)

# %% [markdown]
# ### Note About Preprocessing:
#
# #### For differenced data, to unscale, must concatenate the LAST VALUE OF THE ORIGINAL Y OF THE TRAINING SET, with the new PREDICTED SERIES OF SCALED_YHAT to use CUMSUM()

# %%
def preprocess(series, window_setting):
    moving_avg =series.ewm(span=4, min_periods=4, adjust=True).mean().shift()
    moving_avg_diff = series - moving_avg
    return moving_avg_diff
    
def unpreprocess(first, stationary_series):
    #first = training_y_series.last()
    '''With no gaps in time'''
    unscaled = np.r_[first ,stationary_series].cumsum()
    #unscaled = unscaled[1:]
    return unscaled

# %%
# TESTING UNSCALING 
'''
LME_stationary = preprocess(LME)
first = LME.first('D')
#LME_reversed = unpreprocess(first, LME_stationary)
LME_reversed = np.r_[first ,LME_stationary[1:]].cumsum()
LME_reversed = pd.DataFrame(LME_reversed)

#######################

y_test = LME_stationary['2018-10-14':]
original_y_test = LME['2018-10-14':]

# !!! NOTE MAKE SURE TO SET y_train as ONE WEEK BEFORE MANUALLY
original_y_train = LME[:'2018-10-07']

first = original_y_train.last('D')
LME_reversed = np.r_[first , y_test].cumsum()
LME_reversed = pd.DataFrame(LME_reversed)
LME_reversed = LME_reversed[1:]
LME_reversed.head()

#original_y
'''
# Out:
# "\nLME_stationary = preprocess(LME)\nfirst = LME.first('D')\n#LME_reversed = unpreprocess(first, LME_stationary)\nLME_reversed = np.r_[first ,LME_stationary[1:]].cumsum()\nLME_reversed = pd.DataFrame(LME_reversed)\n\n#######################\n\ny_test = LME_stationary['2018-10-14':]\noriginal_y_test = LME['2018-10-14':]\n\n# !!! NOTE MAKE SURE TO SET y_train as ONE WEEK BEFORE MANUALLY\noriginal_y_train = LME[:'2018-10-07']\n\nfirst = original_y_train.last('D')\nLME_reversed = np.r_[first , y_test].cumsum()\nLME_reversed = pd.DataFrame(LME_reversed)\nLME_reversed = LME_reversed[1:]\nLME_reversed.head()\n\n#original_y\n"

# %% [markdown]
# #### Take Out Trend
#
# Pandas time series resampling options
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html

# %%
LME_stationary = preprocess(LME, 4)

#LME_log = np.log(LME)
LME_log = LME
rcParams['figure.figsize'] = 9, 6

#plt.plot(LME_log)
#plt.show()

window_setting= 4

plt.plot(LME_stationary)

test_stationarity(LME_stationary.dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -25.320119
# p-value                           0.000000
# #Lags Used                        4.000000
# Number of Observations Used    5147.000000
# Critical Value (1%)              -3.431621
# Critical Value (5%)              -2.862102
# Critical Value (10%)             -2.567069
# dtype: float64

# %%
LME_stationary = preprocess(LME, window_setting)

list_one = list(LME_stationary.index)
list_two = list(LME_stationary)
df = pd.DataFrame(list(zip(list_one, list_two)), columns = ['ds', 'lag0'])
                



df['lag1'] = df.lag0.shift(periods=20)
df['lag2'] = df.lag0.shift(periods=40)
df['lag3'] = df.lag0.shift(periods=60)
df['lag4'] = df.lag0.shift(periods=80)
df['lag5'] = df.lag0.shift(periods=100)

df['lag6'] = df.lag0.shift(periods=120)
df['lag7'] = df.lag0.shift(periods=140)
df['lag8'] = df.lag0.shift(periods=160)
df['lag9'] = df.lag0.shift(periods=180)
df['lag10'] = df.lag0.shift(periods=200)


'''
original_tail = train_set['A'].tail(window_setting)


for item in test_set:
    ewm_rolling_avg = original_tail.ewm(span=4, min_periods=4, adjust=True).mean()
    ewm_rolling_avg = ewm_rolling_avg.reset_index().iloc[:,1]
    ewm_rolling_avg = ewm_rolling_avg[len(original_tail)-1]
    
    # original_tail.tail(4).ewm(span=4, adjust=False).mean()[window_setting-1]
    #print(original_tail.tail(4))
    print('rolling avg', ewm_rolling_avg)
    #print(item)
    #print('sum', item + ewm_rolling_avg)
    
    unscaled_result = item + ewm_rolling_avg
    original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
'''



df.index = df['ds']
df = df.iloc[:, 1:]

df = df.dropna()
df
# Out:
#                    lag0         lag1         lag2        lag3        lag4  \
# ds
# 2000-10-13   -94.880326   -36.225694   146.999311  -94.737877 -223.531696
# 2000-10-16  -536.928195   -75.235417    18.199586   66.157274  -29.119018
# 2000-10-17  -422.156917  -255.141250   415.919752  -35.305636   12.528589
# 2000-10-18  -238.294150   -13.084750   374.551851 -383.183381   97.517154
# 2000-10-19    -8.976490   122.149150   199.731111 -166.910029  193.510292
# 2000-10-20   105.614106   263.289490   214.838666 -286.146017  231.106175
# 2000-10-23     8.368464   217.973694   128.903200  -38.687610  163.663705
# 2000-10-24   -39.978922   143.784216   192.341920 -193.212566  -16.801777
# 2000-10-25   -88.987353    43.270530   170.405152 -127.927540  159.918934
# 2000-10-26  -358.392412  -224.037682   -22.756909 -202.756524   85.951360
# 2000-10-27     9.964553  -199.422609  -178.654145 -167.653914   61.570816
# 2000-10-30    15.978732  -434.653566  -216.192487  -89.592349   76.942490
# 2000-10-31   124.587239   -80.792139    14.284508   -3.755409  116.165494
# 2019-09-10   26.642122
# 2019-09-11   91.485273
# 2019-09-12 -320.608836
# 2019-09-13 -127.365302
# 2019-09-16 -192.419181
# 2019-09-17 -148.451509
# 2019-09-18  -58.570905
# 2019-09-19   18.357457
# 2019-09-20  240.014474
# 2019-09-23   42.008684
# 2019-09-24 -129.794789
# 2019-09-25   37.623126
# 2019-09-26  -13.426124
# 2019-09-27  -44.055674
# 2019-09-30  -21.433405
# 2019-10-01  -12.860043
# 2019-10-02   -7.716026
# 2019-10-03 -132.629615
# 2019-10-04 -105.577769
# 2019-10-07 -105.846662
#
# [4952 rows x 11 columns]

# %%
# NOTE SHIFT BACK!!! PRACTICE TO TROUBLE SHOOT EWM TRANSFORMER

df['y'] = df['lag0'].shift(-261)
df = df.dropna()
df.head()
# Out:
#                   lag0        lag1        lag2        lag3        lag4  \
# ds
# 2000-10-13  -94.880326  -36.225694  146.999311  -94.737877 -223.531696
# 2000-10-16 -536.928195  -75.235417   18.199586   66.157274  -29.119018
# 2000-10-17 -422.156917 -255.141250  415.919752  -35.305636   12.528589
# 2000-10-18 -238.294150  -13.084750  374.551851 -383.183381   97.517154
# 2000-10-19   -8.976490  122.149150  199.731111 -166.910029  193.510292
#
#                    lag5        lag6        lag7        lag8        lag9  \
# ds
# 2000-10-13  -144.206151  224.969655  -29.932127   70.210199  242.770797
# 2000-10-16    33.476310  134.981793 -192.959276  157.126119  289.162202
# 2000-10-17 -1259.914214   60.989076 -190.775566   39.275671    6.997124
# 2000-10-18  -820.948529  -98.406554  -93.465340  -16.434597  187.198271
# 2000-10-19  -157.569117 -142.043933 -127.079204  155.139242  522.318917
#
#                  lag10           y
# ds
# 2000-10-13 -121.759191  -12.275743
# 2000-10-16 -110.948994 -156.365446
# 2000-10-17 -140.397489 -113.819268
# 2000-10-18   57.378875 -347.291561
# 2000-10-19  -44.264758 -432.374936

# %%
# Sanity check
df[df.index=='2001-05-28']
# Out:
#                  lag0       lag1       lag2       lag3       lag4       lag5  \
# ds
# 2001-05-28  39.934012  44.866161  80.868034 -97.114547 -62.247629  73.007052
#
#                  lag6        lag7        lag8       lag9      lag10  \
# ds
# 2001-05-28 -151.13941 -374.385292 -536.928195 -75.235417  18.199586
#
#                      y
# ds
# 2001-05-28  114.811105

# %% [markdown]
# ## Linear Regression
#
# IMPORTANT NOTE TO SELF:
# For smoothing using moving average, must RESCALE output predictions using inputs!!
#
# SECOND NOTE 2 SELF:
# for training/fitting/testing set...
#
# MODEL FOR DEPLOYMENT:
# Train a model that uses values from a year ago or OLDER to predict values and rescale according to moving averages...

# %%
X = df[['lag0', 'lag1', 'lag2', 'lag3', 'lag4', 'lag5', 'lag6', 'lag7', 'lag8', 'lag9', 'lag10']]
#'lag11', 'lag12', 'lag13', 'lag14', 'lag15']]
y= df['y']

# %%
X_test = X.loc['2017-10-31':  ,:]
y_test = y['2017-10-31':]

y_train = y[:'2017-10-30']
X_train = X.loc[:'2017-10-30', :]
X_test
# Out:
#                   lag0        lag1        lag2        lag3        lag4  \
# 2017-11-09  447.547864
# 2017-11-10   98.528719
# 2017-11-13  284.617231
# 2017-11-14   74.020339
# 2017-11-15  187.662203
# 2017-11-16  -97.902678
# 2017-11-17  323.508393
# 2017-11-20  259.355036
# 2017-11-21  190.613022
# 2017-11-22  272.867813
# 2017-11-23  301.970688
# 2017-11-24  163.182413
# 2017-11-27  198.409448
# 2017-11-28 -176.704331
# 2017-11-29 -151.022599
# 2017-11-30 -318.113559
# 2017-12-01   91.631864
# 2017-12-04  239.479119
# 2017-12-05   77.187471
# 2017-12-06   94.312483
# 2017-12-07 -192.662510
# 2017-12-08   95.152494
# 2017-12-11  160.841496
# ...                ...
# 2018-08-27   -6.453519
# 2018-08-28  205.627889
# 2018-08-29   93.876733
# 2018-08-30  147.826040
# 2018-08-31  195.195624
# 2018-09-03 -348.882626
# 2018-09-04 -432.329575
# 2018-09-05  -89.397745
# 2018-09-06 -463.638647
# 2018-09-07  -98.683188
# 2018-09-10   31.790087
# 2018-09-11 -500.425948
# 2018-09-12 -352.255569
# 2018-09-13   26.146659
# 2018-09-14  -80.312005
# 2018-09-17  237.812797
# 2018-09-18  -24.812322
# 2018-09-19   15.112607
# 2018-09-20   69.567564
# 2018-09-21  464.240539
# 2018-09-24  534.544323
# 2018-09-25  240.226594
# 2018-09-26  422.635956
# 2018-09-27  288.581574
# 2018-09-28  234.648944
# 2018-10-01  140.789367
# 2018-10-02   84.473620
# 2018-10-03   26.684172
# 2018-10-04  262.510503
# 2018-10-05  568.006302
#
# [244 rows x 11 columns]

# %%
## Weekly train/test set dates

#X_train = X.loc[:'2018-10-07', :]
#y_train = y[:'2018-10-07']

## Daily training dates
#X_train = X.loc[:'2018-10-12', :]
#y_train = y[:'2018-10-12']

## Monthly training dates
#X_train = X.loc[:'2018-10-14', :]
#y_train = y[:'2018-10-14']

# %%
regressor = LinearRegression()

regressor.fit(X_train, y_train)
print(regressor.coef_)

y_pred = regressor.predict(X_test)
y_pred = pd.Series(y_pred)
y_pred.index = y_test.index
# y_pred = y_pred.reindex(X_test.index)
y_pred_linear = y_pred
# Out:
# [-0.03312735 -0.02085571 -0.02711968  0.00520548  0.00607901 -0.01015061
#  -0.0006128   0.02197421 -0.03042019 -0.01016831 -0.00314304]

# %%
from sklearn import neighbors
regressor = neighbors.KNeighborsRegressor(n_neighbors=3)


regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
y_pred = pd.Series(y_pred)
y_pred.index = y_test.index

y_pred_knn3 = y_pred

# %%
from sklearn.ensemble import RandomForestRegressor

params1= ParameterGrid({'n_estimators' : [50, 100, 150, 200, 250, 300, 350, 400, 450],
                            'min_samples_leaf': [ .15,  .25, .35, .45]})

cv_results = {}



regressor = RandomForestRegressor(random_state=1)


regressor.fit(X_train, y_train)
#print(regressor.coef_)

y_pred = regressor.predict(X_test)
y_pred = pd.Series(y_pred)
y_pred.index = y_test.index
# y_pred = y_pred.reindex(X_test.index)
y_pred_rf = y_pred
# Out:
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning:
#
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22
# 2018-10-03          -22.005778   409.240439     165.881824
# 2018-10-04           -7.338555    84.050649     372.592610
# 2018-10-05          -11.271255   -54.034710      51.289122
#
# [244 rows x 3 columns]

# %% [markdown]
# ## Back to Scale before Performance Analysis

# %%
# NOTE/IMPORTANT: MUST SHIFT BACK

LME_shifted = LME.shift(-261).dropna()
LME_shifted.tail()
# Out:
# Unnamed: 1
# 2018-10-01    17434.0
# 2018-10-02    17640.0
# 2018-10-03    17775.0
# 2018-10-04    17906.0
# 2018-10-05    17810.0
# Freq: B, Name: Cash Price ($/MT), dtype: float64

# %% [markdown]
# y_train range:
# #### 2000 to 2017-10-30
#
#
# y_pred and y_test range:
# #### 2017-10-31 to 2018-10-13

# %%
# Extracts last few values from the original unscaled y values

original_tail = LME_shifted.loc[:'2017-10-30']

y_pred_unscaled = []

for key, item in y_pred.items():
    rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
    unscaled_result = item + rolling_avg
    
    original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
    y_pred_unscaled.append(float(unscaled_result))

y_pred_unscaled = pd.Series(y_pred_unscaled)
y_pred_unscaled.index = y_test.index

unscaled = pd.Series(y_pred_unscaled)

# %%
original_tail = LME_shifted.loc[:'2017-10-30']

original_ys = []

for key, item in y_test.items():
    rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
    original_y = item + rolling_avg
    original_tail = original_tail.append(pd.Series([original_y]))
    
    original_ys.append(float(original_y))


original_ys = pd.Series(original_ys)
original_ys.index = y_test.index

original_y = original_ys

# %%
original_y.head()
# Out:
# ds
# 2017-10-31    11425.5
# 2017-11-01    11718.5
# 2017-11-02    11860.5
# 2017-11-03    11675.5
# 2017-11-06    11699.5
# dtype: float64

# %%
# Sanity check for unscaling! 

LME_shifted[LME_shifted.index=='2017-10-31']
# Out:
# Unnamed: 1
# 2017-10-31    11425.5
# Freq: B, Name: Cash Price ($/MT), dtype: float64

# %%
plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('EWM Linear Regression Prediction (weeks), ten lags', fontsize=15)

plt.show()

# %%
results = pd.DataFrame({'y_test': original_y, 'y_pred_unscaled': unscaled})
results['error'] = results['y_test'] - results['y_pred_unscaled']

results.head()
# Out:
#              y_test  y_pred_unscaled       error
# ds
# 2017-10-31  11425.5     11792.188058 -366.688058
# 2017-11-01  11718.5     11780.432169  -61.932169
# 2017-11-02  11860.5     11798.498526   62.001474
# 2017-11-03  11675.5     11808.293714 -132.793714
# 2017-11-06  11699.5     11787.454939  -87.954939

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))
# Out:
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092

# %%
y_pred.head() # Linear regression
# Out:
# ds
# 2017-10-31   -26.065183
# 2017-11-01   -27.394998
# 2017-11-02     1.629357
# 2017-11-03    10.772803
# 2017-11-06   -14.375093
# dtype: float64

# %% [markdown]
# # Other Kinds of Regression
#
# Grid Search for RIDGE Regression

# %%
y_pred # RIDGE
# Out:
# ds
# 2017-10-31   -26.065183
# 2017-11-01   -27.394998
# 2017-11-02     1.629357
# 2017-11-03    10.772803
# 2017-11-06   -14.375093
# 2017-11-07    -8.136624
# 2017-11-08     5.167875
# 2017-11-09    16.450576
# 2017-11-10    20.326496
# 2017-11-13     0.530158
# 2017-11-14    31.893233
# 2017-11-15     9.088905
# 2017-11-16    30.509886
# 2017-11-17    27.725835
# 2017-11-20     6.067560
# 2017-11-21    12.482666
# 2017-11-22    19.723713
# 2017-11-23    12.833417
# 2017-11-24     8.954543
# 2017-11-27    23.456399
# 2017-11-28    14.893983
# 2017-11-29    -2.088197
# 2017-11-30    16.498242
# 2017-12-01     1.809664
# 2017-12-04   -12.482536
# 2017-12-05     9.147225
# 2017-12-06     2.643390
# 2017-12-07    -7.991116
# 2017-12-08    -4.972354
# 2017-12-11   -22.314424
#                 ...
# 2018-08-27    -0.980112
# 2018-08-28     7.369188
# 2018-08-29    42.628058
# 2018-08-30    37.359164
# 2018-08-31    26.812323
# 2018-09-03    -1.378123
# 2018-09-04     8.224322
# 2018-09-05   -15.135236
# 2018-09-06   -16.543491
# 2018-09-07     0.011209
# 2018-09-10    16.578118
# 2018-09-11    42.091979
# 2018-09-12    14.912273
# 2018-09-13   -13.926331
# 2018-09-14     5.948152
# 2018-09-17     9.702589
# 2018-09-18    13.107534
# 2018-09-19     4.881881
# 2018-09-20     1.764821
# 2018-09-21    -8.149245
# 2018-09-24    -5.086610
# 2018-09-25   -11.496481
# 2018-09-26    -8.384863
# 2018-09-27     9.700469
# 2018-09-28    10.971577
# 2018-10-01    10.278863
# 2018-10-02     7.438754
# 2018-10-03   -22.005778
# 2018-10-04    -7.338555
# 2018-10-05   -11.271255
# Length: 244, dtype: float64

# %%
from sklearn import linear_model

params1= ParameterGrid({'alpha' : [ .00001 ,.0001, .001, .01, .1, 1]
                            })

cv_results = {}

for params in params1:

    regressor = linear_model.Ridge(**params, random_state=1)

    print()
    print(params)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index

    original_tail = LME_shifted.loc[:'2017-10-30']

    y_pred_unscaled = []

    for key, item in y_pred.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        unscaled_result = item + rolling_avg

        original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
        y_pred_unscaled.append(float(unscaled_result))

    y_pred_unscaled = pd.Series(y_pred_unscaled)
    y_pred_unscaled.index = y_test.index


    original_tail = LME_shifted.loc[:'2017-10-30']

    original_ys = []

    for key, item in y_test.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        original_y = item + rolling_avg
        original_tail = original_tail.append(pd.Series([original_y]))

        original_ys.append(float(original_y))


    original_ys = pd.Series(original_ys)
    original_ys.index = y_test.index

    original_y = original_ys

    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters

    '''Calculates maximum test accuracy value and parameters'''
    #min_test_accuracy, min_parameters = 0, 0
    min_test_accuracy = 3000
    for key, value in cv_results.items():
        if value < min_test_accuracy:
            min_test_accuracy = value
            min_parameters = key
            
print()
print('Ridge CV Results')
for key, value in cv_results.items():
    print(key, value)

print()
print('Best Results:')
if min_test_accuracy==3000:
    print('error')
else:
    print('Minimum Test Accuracy: ', min_test_accuracy)
print('Best Parameters: ', min_parameters)
print()

plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Ridge Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# {'alpha': 1e-05}
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# {'alpha': 0.0001}
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# {'alpha': 0.001}
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# {'alpha': 0.01}
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# {'alpha': 0.1}
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# {'alpha': 1}
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# Ridge CV Results
# {'alpha': 1e-05} 1588.3954738334596
# {'alpha': 0.0001} 1588.3954738334596
# {'alpha': 0.001} 1588.3954738334596
# {'alpha': 0.01} 1588.3954738334596
# {'alpha': 0.1} 1588.3954738334596
# {'alpha': 1} 1588.3954738334596
#
# Best Results:
# Minimum Test Accuracy:  1588.3954738334596
# Best Parameters:  {'alpha': 1e-05}

# %%
from sklearn import linear_model

params1= ParameterGrid({'alpha' : [ .00001 ,.0001, .001, .01, .1, 1]
                            })

cv_results = {}

for params in params1:

    regressor = linear_model.Lasso(**params, random_state=1)

    print()
    print(params)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)

    original_tail = LME.loc[y_train.index[-window_setting:]]

    for key, item in y_pred.items():
        rolling_avg = original_tail.tail(window_setting).mean()
        unscaled_result = item + rolling_avg
        original_tail = original_tail.append(pd.Series([unscaled_result]))

    unscaled = pd.Series(original_tail)
    unscaled = unscaled[window_setting:]
    unscaled.index = y_test.index


    original_tail = LME.loc[y_train.index[-window_setting:]]

    for key, item in y_test.items():
        rolling_avg = original_tail.tail(window_setting).mean()
        original_y = item + rolling_avg
        original_tail = original_tail.append(pd.Series([original_y]))


    original_y = pd.Series(original_tail)
    original_y = original_y[window_setting:]
    original_y.index = y_test.index
    
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters

    '''Calculates maximum test accuracy value and parameters'''
    #min_test_accuracy, min_parameters = 0, 0
    min_test_accuracy = 3000
    for key, value in cv_results.items():
        if value < min_test_accuracy:
            min_test_accuracy = value
            min_parameters = key
            
print()
print('Ridge CV Results')
for key, value in cv_results.items():
    print(key, value)

print()
print('Best Results:')
if min_test_accuracy==3000:
    print('error')
else:
    print('Minimum Test Accuracy: ', min_test_accuracy)
print('Best Parameters: ', min_parameters)
print()

plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('LASSO Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# {'alpha': 1e-05}
# Mean Absolute Error: 1667.6962784144234
# Mean Squared Error: 5903163.451816334
# Root Mean Squared Error: 2429.642659284763
#
# {'alpha': 0.0001}
# Mean Absolute Error: 1667.6962781625614
# Mean Squared Error: 5903163.450891234
# Root Mean Squared Error: 2429.642659094385
#
# {'alpha': 0.001}
# Mean Absolute Error: 1667.6962756468463
# Mean Squared Error: 5903163.441650484
# Root Mean Squared Error: 2429.6426571927163
#
# {'alpha': 0.01}
# Mean Absolute Error: 1667.696250517561
# Mean Squared Error: 5903163.349338862
# Root Mean Squared Error: 2429.6426381957617
#
# {'alpha': 0.1}
# Mean Absolute Error: 1667.6959992456489
# Mean Squared Error: 5903162.426404282
# Root Mean Squared Error: 2429.642448263588
#
# {'alpha': 1}
# Mean Absolute Error: 1667.6935243007763
# Mean Squared Error: 5903153.326935157
# Root Mean Squared Error: 2429.6405756685817
#
# Ridge CV Results
# {'alpha': 1e-05} 1667.6962784144234
# {'alpha': 0.0001} 1667.6962781625614
# {'alpha': 0.001} 1667.6962756468463
# {'alpha': 0.01} 1667.696250517561
# {'alpha': 0.1} 1667.6959992456489
# {'alpha': 1} 1667.6935243007763
#
# Best Results:
# Minimum Test Accuracy:  1667.6935243007763
# Best Parameters:  {'alpha': 1}

# %%
from sklearn.ensemble import AdaBoostRegressor

params1= ParameterGrid({'n_estimators' : [50, 100, 150, 200, 250, 300, 350, 400, 450],
                            'learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3]})

cv_results = {}

for params in params1:

    regressor = AdaBoostRegressor(**params, random_state=1)

    print()
    print(params)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)


    original_tail = LME_shifted.loc[y_train.index[-window_setting:]]

    for key, item in y_pred.items():
        rolling_avg = original_tail.tail(window_setting).mean()
        unscaled_result = item + rolling_avg
        original_tail = original_tail.append(pd.Series([unscaled_result]))

    unscaled = pd.Series(original_tail)
    unscaled = unscaled[window_setting:]
    unscaled.index = y_test.index


    original_tail = LME_shifted.loc[y_train.index[-window_setting:]]

    for key, item in y_test.items():
        rolling_avg = original_tail.tail(window_setting).mean()
        original_y = item + rolling_avg
        original_tail = original_tail.append(pd.Series([original_y]))


    original_y = pd.Series(original_tail)
    original_y = original_y[window_setting:]
    original_y.index = y_test.index
    
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters

    '''Calculates maximum test accuracy value and parameters'''
    #min_test_accuracy, min_parameters = 0, 0
    min_test_accuracy = 3000
    for key, value in cv_results.items():
        if value < min_test_accuracy:
            min_test_accuracy = value
            min_parameters = key
            
print()
print('Adaboost CV Results')
for key, value in cv_results.items():
    print(key, value)

print()
print('Best Results:')
if min_test_accuracy==3000:
    print('error')
else:
    print('Minimum Test Accuracy: ', min_test_accuracy)
print('Best Parameters: ', min_parameters)
print()

plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Adaboost Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# {'learning_rate': 0.0001, 'n_estimators': 50}
# Mean Absolute Error: 1264.8402763407419
# Mean Squared Error: 2819179.663218457
# Root Mean Squared Error: 1679.0412928866451
#
# {'learning_rate': 0.0001, 'n_estimators': 100}
# Mean Absolute Error: 1267.8557024095005
# Mean Squared Error: 2710420.8527700957
# Root Mean Squared Error: 1646.3355832788452
#
# {'learning_rate': 0.0001, 'n_estimators': 150}
# Mean Absolute Error: 1267.8451018658247
# Mean Squared Error: 2707819.4529832895
# Root Mean Squared Error: 1645.545336046166
#
# {'learning_rate': 0.0001, 'n_estimators': 200}
# Mean Absolute Error: 1267.9242538416054
# Mean Squared Error: 2703484.00788065
# Root Mean Squared Error: 1644.2274805758022
#
# {'learning_rate': 0.0001, 'n_estimators': 250}
# Mean Absolute Error: 1267.7503568960963
# Mean Squared Error: 2713477.482647213
# Root Mean Squared Error: 1647.2636348342098
#
# {'learning_rate': 0.0001, 'n_estimators': 300}
# Mean Absolute Error: 1268.236598284802
# Mean Squared Error: 2693654.735893238
# Root Mean Squared Error: 1641.2357344066202
#
# {'learning_rate': 0.0001, 'n_estimators': 350}
# Mean Absolute Error: 1267.4666740716514
# Mean Squared Error: 2695633.524568928
# Root Mean Squared Error: 1641.8384587312262
#
# {'learning_rate': 0.0001, 'n_estimators': 400}
# Mean Absolute Error: 1265.0455421637614
# Mean Squared Error: 2667730.8630917133
# Root Mean Squared Error: 1633.3189716316017
#
# {'learning_rate': 0.0001, 'n_estimators': 450}
# Mean Absolute Error: 1265.9148338518662
# Mean Squared Error: 2673846.568839398
# Root Mean Squared Error: 1635.1900711658564
#
# {'learning_rate': 0.001, 'n_estimators': 50}
# Mean Absolute Error: 1249.7730785711672
# Mean Squared Error: 2647647.947381173
# Root Mean Squared Error: 1627.1594720190067
#
# {'learning_rate': 0.001, 'n_estimators': 100}
# Mean Absolute Error: 1262.1485826083456
# Mean Squared Error: 2683106.3481391296
# Root Mean Squared Error: 1638.019031677938
#
# {'learning_rate': 0.001, 'n_estimators': 150}
# Mean Absolute Error: 1264.7656261939278
# Mean Squared Error: 2663822.915841944
# Root Mean Squared Error: 1632.1222122874083
#
# {'learning_rate': 0.001, 'n_estimators': 200}
# Mean Absolute Error: 1263.2724803386893
# Mean Squared Error: 2639399.1328186924
# Root Mean Squared Error: 1624.6227663118268
#
# {'learning_rate': 0.001, 'n_estimators': 250}
# Mean Absolute Error: 1261.2231402054704
# Mean Squared Error: 2612953.5763278133
# Root Mean Squared Error: 1616.4632926014167
#
# {'learning_rate': 0.001, 'n_estimators': 300}
# Mean Absolute Error: 1260.967853319869
# Mean Squared Error: 2587344.501412076
# Root Mean Squared Error: 1608.5224590947048
#
# {'learning_rate': 0.001, 'n_estimators': 350}
# Mean Absolute Error: 1261.7638625175593
# Mean Squared Error: 2607677.792417027
# Root Mean Squared Error: 1614.83057700089
#
# {'learning_rate': 0.001, 'n_estimators': 400}
# Mean Absolute Error: 1261.9251111874432
# Mean Squared Error: 2594339.1570883333
# Root Mean Squared Error: 1610.6952402885945
#
# {'learning_rate': 0.001, 'n_estimators': 450}
# Mean Absolute Error: 1264.643534332377
# Mean Squared Error: 2609699.7416603966
# Root Mean Squared Error: 1615.4565118443754
#
# {'learning_rate': 0.01, 'n_estimators': 50}
# Mean Absolute Error: 1271.8470675971573
# Mean Squared Error: 2606752.0081796586
# Root Mean Squared Error: 1614.543900976266
#
# {'learning_rate': 0.01, 'n_estimators': 100}
# Mean Absolute Error: 1281.8068441193243
# Mean Squared Error: 2489599.283155052
# Root Mean Squared Error: 1577.8464067060052
#
# {'learning_rate': 0.01, 'n_estimators': 150}
# Mean Absolute Error: 1300.929478499546
# Mean Squared Error: 2431327.61878099
# Root Mean Squared Error: 1559.2715025873429
#
# {'learning_rate': 0.01, 'n_estimators': 200}
# Mean Absolute Error: 1321.9182797533977
# Mean Squared Error: 2425402.660749264
# Root Mean Squared Error: 1557.3704314482359
#
# {'learning_rate': 0.01, 'n_estimators': 250}
# Mean Absolute Error: 1365.3016711136863
# Mean Squared Error: 2462105.8584393086
# Root Mean Squared Error: 1569.1098936783583
#
# {'learning_rate': 0.01, 'n_estimators': 300}
# Mean Absolute Error: 1402.7925727605304
# Mean Squared Error: 2542253.991238285
# Root Mean Squared Error: 1594.4447281854223
#
# {'learning_rate': 0.01, 'n_estimators': 350}
# Mean Absolute Error: 1430.4258403425285
# Mean Squared Error: 2626261.26922233
# Root Mean Squared Error: 1620.5743639902273
#
# {'learning_rate': 0.01, 'n_estimators': 400}
# Mean Absolute Error: 1458.7743224881588
# Mean Squared Error: 2737955.0644316953
# Root Mean Squared Error: 1654.6767250528712
#
# {'learning_rate': 0.01, 'n_estimators': 450}
# Mean Absolute Error: 1490.3382274756361
# Mean Squared Error: 2873435.1484078197
# Root Mean Squared Error: 1695.1209834132253
#
# {'learning_rate': 0.1, 'n_estimators': 50}
# Mean Absolute Error: 1485.0967904021686
# Mean Squared Error: 2862337.5814782986
# Root Mean Squared Error: 1691.8444318193972
#
# {'learning_rate': 0.1, 'n_estimators': 100}
# Mean Absolute Error: 1857.838573877565
# Mean Squared Error: 4618335.848243092
# Root Mean Squared Error: 2149.0313744203672
#
# {'learning_rate': 0.1, 'n_estimators': 150}
# Mean Absolute Error: 2718.234844125915
# Mean Squared Error: 9169102.44348764
# Root Mean Squared Error: 3028.052582682084
#
# {'learning_rate': 0.1, 'n_estimators': 200}
# Mean Absolute Error: 3480.707085107229
# Mean Squared Error: 14624169.802740844
# Root Mean Squared Error: 3824.156090268916
#
# {'learning_rate': 0.1, 'n_estimators': 250}
# Mean Absolute Error: 4087.3996363614547
# Mean Squared Error: 20129195.928165797
# Root Mean Squared Error: 4486.557246727807
#
# {'learning_rate': 0.1, 'n_estimators': 300}
# Mean Absolute Error: 4307.443553423636
# Mean Squared Error: 22362915.12058945
# Root Mean Squared Error: 4728.944398128345
#
# {'learning_rate': 0.1, 'n_estimators': 350}
# Mean Absolute Error: 4307.443553423636
# Mean Squared Error: 22362915.12058945
# Root Mean Squared Error: 4728.944398128345
#
# {'learning_rate': 0.1, 'n_estimators': 400}
# Mean Absolute Error: 4307.443553423636
# Mean Squared Error: 22362915.12058945
# Root Mean Squared Error: 4728.944398128345
#
# {'learning_rate': 0.1, 'n_estimators': 450}
# Mean Absolute Error: 4307.443553423636
# Mean Squared Error: 22362915.12058945
# Root Mean Squared Error: 4728.944398128345
#
# {'learning_rate': 0.2, 'n_estimators': 50}
# Mean Absolute Error: 2061.9859914948133
# Mean Squared Error: 5575527.583550307
# Root Mean Squared Error: 2361.2555100095174
#
# {'learning_rate': 0.2, 'n_estimators': 100}
# Mean Absolute Error: 3560.5854008829047
# Mean Squared Error: 15364416.352503303
# Root Mean Squared Error: 3919.746975571676
#
# {'learning_rate': 0.2, 'n_estimators': 150}
# Mean Absolute Error: 4270.0964738367065
# Mean Squared Error: 21980649.922800276
# Root Mean Squared Error: 4688.35258089665
#
# {'learning_rate': 0.2, 'n_estimators': 200}
# Mean Absolute Error: 4270.0964738367065
# Mean Squared Error: 21980649.922800276
# Root Mean Squared Error: 4688.35258089665
#
# {'learning_rate': 0.2, 'n_estimators': 250}
# Mean Absolute Error: 4270.0964738367065
# Mean Squared Error: 21980649.922800276
# Root Mean Squared Error: 4688.35258089665
#
# {'learning_rate': 0.2, 'n_estimators': 300}
# Mean Absolute Error: 4270.0964738367065
# Mean Squared Error: 21980649.922800276
# Root Mean Squared Error: 4688.35258089665
#
# {'learning_rate': 0.2, 'n_estimators': 350}
# Mean Absolute Error: 4270.0964738367065
# Mean Squared Error: 21980649.922800276
# Root Mean Squared Error: 4688.35258089665
#
# {'learning_rate': 0.2, 'n_estimators': 400}
# Mean Absolute Error: 4270.0964738367065
# Mean Squared Error: 21980649.922800276
# Root Mean Squared Error: 4688.35258089665
#
# {'learning_rate': 0.2, 'n_estimators': 450}
# Mean Absolute Error: 4270.0964738367065
# Mean Squared Error: 21980649.922800276
# Root Mean Squared Error: 4688.35258089665
#
# {'learning_rate': 0.3, 'n_estimators': 50}
# Mean Absolute Error: 2582.436415620612
# Mean Squared Error: 8327672.124024059
# Root Mean Squared Error: 2885.770629142943
#
# {'learning_rate': 0.3, 'n_estimators': 100}
# Mean Absolute Error: 3088.43438631184
# Mean Squared Error: 11614279.61356594
# Root Mean Squared Error: 3407.9729478923305
#
# {'learning_rate': 0.3, 'n_estimators': 150}
# Mean Absolute Error: 3088.43438631184
# Mean Squared Error: 11614279.61356594
# Root Mean Squared Error: 3407.9729478923305
#
# {'learning_rate': 0.3, 'n_estimators': 200}
# Mean Absolute Error: 3088.43438631184
# Mean Squared Error: 11614279.61356594
# Root Mean Squared Error: 3407.9729478923305
#
# {'learning_rate': 0.3, 'n_estimators': 250}
# Mean Absolute Error: 3088.43438631184
# Mean Squared Error: 11614279.61356594
# Root Mean Squared Error: 3407.9729478923305
#
# {'learning_rate': 0.3, 'n_estimators': 300}
# Mean Absolute Error: 3088.43438631184
# Mean Squared Error: 11614279.61356594
# Root Mean Squared Error: 3407.9729478923305
#
# {'learning_rate': 0.3, 'n_estimators': 350}
# Mean Absolute Error: 3088.43438631184
# Mean Squared Error: 11614279.61356594
# Root Mean Squared Error: 3407.9729478923305
#
# {'learning_rate': 0.3, 'n_estimators': 400}
# Mean Absolute Error: 3088.43438631184
# Mean Squared Error: 11614279.61356594
# Root Mean Squared Error: 3407.9729478923305
#
# {'learning_rate': 0.3, 'n_estimators': 450}
# Mean Absolute Error: 3088.43438631184
# Mean Squared Error: 11614279.61356594
# Root Mean Squared Error: 3407.9729478923305
#
# Adaboost CV Results
# {'learning_rate': 0.0001, 'n_estimators': 50} 1264.8402763407419
# {'learning_rate': 0.0001, 'n_estimators': 100} 1267.8557024095005
# {'learning_rate': 0.0001, 'n_estimators': 150} 1267.8451018658247
# {'learning_rate': 0.0001, 'n_estimators': 200} 1267.9242538416054
# {'learning_rate': 0.0001, 'n_estimators': 250} 1267.7503568960963
# {'learning_rate': 0.0001, 'n_estimators': 300} 1268.236598284802
# {'learning_rate': 0.0001, 'n_estimators': 350} 1267.4666740716514
# {'learning_rate': 0.0001, 'n_estimators': 400} 1265.0455421637614
# {'learning_rate': 0.0001, 'n_estimators': 450} 1265.9148338518662
# {'learning_rate': 0.3, 'n_estimators': 450} 3088.43438631184
#
# Best Results:
# Minimum Test Accuracy:  1249.7730785711672
# Best Parameters:  {'learning_rate': 0.001, 'n_estimators': 50}

# %%
from sklearn.ensemble import RandomForestRegressor

params1= ParameterGrid({'n_estimators' : [50, 100, 150, 200, 250, 300, 350, 400, 450],
                            'min_samples_leaf': [ .15,  .25, .35, .45]})

cv_results = {}

for params in params1:

    regressor = RandomForestRegressor(**params, random_state=1)

    print()
    print(params)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)

    
    original_tail = LME_shifted.loc[y_train.index[-window_setting:]]

    for key, item in y_pred.items():
        rolling_avg = original_tail.tail(window_setting).mean()
        unscaled_result = item + rolling_avg
        original_tail = original_tail.append(pd.Series([unscaled_result]))

    unscaled = pd.Series(original_tail)
    unscaled = unscaled[window_setting:]
    unscaled.index = y_test.index


    original_tail = LME_shifted.loc[y_train.index[-window_setting:]]

    for key, item in y_test.items():
        rolling_avg = original_tail.tail(window_setting).mean()
        original_y = item + rolling_avg
        original_tail = original_tail.append(pd.Series([original_y]))


    original_y = pd.Series(original_tail)
    original_y = original_y[window_setting:]
    original_y.index = y_test.index
    
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters

    '''Calculates maximum test accuracy value and parameters'''
    #min_test_accuracy, min_parameters = 0, 0
    min_test_accuracy = 3000
    for key, value in cv_results.items():
        if value < min_test_accuracy:
            min_test_accuracy = value
            min_parameters = key
            
print()
print('Random Forest CV Results')
for key, value in cv_results.items():
    print(key, value)

print()
print('Best Results:')
if min_test_accuracy==3000:
    print('error')
else:
    print('Minimum Test Accuracy: ', min_test_accuracy)
print('Best Parameters: ', min_parameters)
print()

plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Random Forest Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# {'min_samples_leaf': 0.15, 'n_estimators': 50}
# Mean Absolute Error: 1627.5112805910514
# Mean Squared Error: 5238992.09874858
# Root Mean Squared Error: 2288.884466011463
#
# {'min_samples_leaf': 0.15, 'n_estimators': 100}
# Mean Absolute Error: 1625.6433638637989
# Mean Squared Error: 5221691.143116066
# Root Mean Squared Error: 2285.1019984053373
#
# {'min_samples_leaf': 0.15, 'n_estimators': 150}
# Mean Absolute Error: 1623.901279356371
# Mean Squared Error: 5209476.976198935
# Root Mean Squared Error: 2282.4278687833566
#
# {'min_samples_leaf': 0.15, 'n_estimators': 200}
# Mean Absolute Error: 1611.8839872790625
# Mean Squared Error: 5150938.790186452
# Root Mean Squared Error: 2269.567974348081
#
# {'min_samples_leaf': 0.15, 'n_estimators': 250}
# Mean Absolute Error: 1618.6113490344712
# Mean Squared Error: 5177729.052020402
# Root Mean Squared Error: 2275.462382027091
#
# {'min_samples_leaf': 0.15, 'n_estimators': 300}
# Mean Absolute Error: 1618.3711771025805
# Mean Squared Error: 5172284.39962028
# Root Mean Squared Error: 2274.265683604332
#
# {'min_samples_leaf': 0.15, 'n_estimators': 350}
# Mean Absolute Error: 1624.8625526074989
# Mean Squared Error: 5200623.423063999
# Root Mean Squared Error: 2280.487540650902
#
# {'min_samples_leaf': 0.15, 'n_estimators': 400}
# Mean Absolute Error: 1620.7614784598616
# Mean Squared Error: 5181942.247162062
# Root Mean Squared Error: 2276.387982564058
#
# {'min_samples_leaf': 0.15, 'n_estimators': 450}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-419-6b5e1ef226b6> in <module>
#      13     print(params)
#      14
# ---> 15     regressor.fit(X_train, y_train)
#      16     #print(regressor.coef_)
#      17
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     328                     t, self, X, y, sample_weight, i, len(trees),
#     329                     verbose=self.verbose, class_weight=self.class_weight)
# --> 330                 for i, t in enumerate(trees))
#     331
#     332             # Collect newly grown trees
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     116             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     117
# --> 118         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     119     else:
#     120         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1155             sample_weight=sample_weight,
#    1156             check_input=check_input,
# -> 1157             X_idx_sorted=X_idx_sorted)
#    1158         return self
#    1159
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     378                                            min_impurity_split)
#     379
# --> 380         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     381
#     382         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
from sklearn import neighbors

cv_results = {}

for K in range(7):
    K = K+1
    regressor = neighbors.KNeighborsRegressor(n_neighbors=K)

    print()
    print('K: ', K)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)

    original_tail = LME_shifted.loc[:'2017-10-30']

    y_pred_unscaled = []

    for key, item in y_pred.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        unscaled_result = item + rolling_avg

        original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
        y_pred_unscaled.append(float(unscaled_result))

    y_pred_unscaled = pd.Series(y_pred_unscaled)
    y_pred_unscaled.index = y_test.index


    original_tail = LME_shifted.loc[:'2017-10-30']

    original_ys = []

    for key, item in y_test.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        original_y = item + rolling_avg
        original_tail = original_tail.append(pd.Series([original_y]))

        original_ys.append(float(original_y))


    original_ys = pd.Series(original_ys)
    original_ys.index = y_test.index

    original_y = original_ys

    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('KNN Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()

print(cv_results)
# Out:
# K:  1
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# K:  2
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# K:  3
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# K:  4
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# K:  5
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# K:  6
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
#
# K:  7
# Mean Absolute Error: 1588.3954738334596
# Mean Squared Error: 5586855.75835559
# Root Mean Squared Error: 2363.653053719092
# {"{'alpha': 1}": 1588.3954738334596}

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=2)

X_poly = polynomial_features.fit_transform(X_train)

regressor = LinearRegression()
regressor.fit(X_poly, y_train)

X_poly_test = polynomial_features.fit_transform(X_test)
y_poly_pred = regressor.predict(X_poly_test)
y_poly_pred = pd.Series(y_poly_pred)
y_poly_pred.index = y_test.index

mae = np.sqrt(metrics.mean_absolute_error(y_test,y_poly_pred))
print('MAE for scaled results: ', mae)
print()

original_tail = LME_shifted.loc[y_train.index[-window_setting:]]

for key, item in y_poly_pred.items():
    rolling_avg = original_tail.tail(window_setting).mean()
    unscaled_result = item + rolling_avg
    original_tail = original_tail.append(pd.Series([unscaled_result]))

unscaled = pd.Series(original_tail)
unscaled = unscaled[window_setting:]
unscaled.index = y_test.index


original_tail = LME_shifted.loc[y_train.index[-window_setting:]]

for key, item in y_test.items():
    rolling_avg = original_tail.tail(window_setting).mean()
    original_y = item + rolling_avg
    original_tail = original_tail.append(pd.Series([original_y]))


original_y = pd.Series(original_tail)
original_y = original_y[window_setting:]
original_y.index = y_test.index



print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))


mae = metrics.mean_absolute_error(original_y, unscaled)
print('Polynomial MAE of Degree = 2: ', mae)
#print('kfold test accuracy =', kfold_test_accuracy)

# To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Polynomial Regression (deg=2) Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# MAE for scaled results:  19.403679287574136
#
# Mean Absolute Error: 1168.7412668590496
# Mean Squared Error: 2335749.047995431
# Root Mean Squared Error: 1528.3157553318067
# Polynomial MAE of Degree = 2:  1168.7412668590496

# %%
polynomial_features= PolynomialFeatures(degree=3)

X_poly = polynomial_features.fit_transform(X_train)

regressor = LinearRegression()
regressor.fit(X_poly, y_train)

X_poly_test = polynomial_features.fit_transform(X_test)
y_poly_pred = regressor.predict(X_poly_test)
y_poly_pred = pd.Series(y_poly_pred)
y_poly_pred.index = y_test.index

mae = np.sqrt(metrics.mean_absolute_error(y_test,y_poly_pred))
print('MAE for scaled results: ', mae)
print()

original_tail = LME_shifted.loc[y_train.index[-window_setting:]]

for key, item in y_poly_pred.items():
    rolling_avg = original_tail.tail(window_setting).mean()
    unscaled_result = item + rolling_avg
    original_tail = original_tail.append(pd.Series([unscaled_result]))

unscaled = pd.Series(original_tail)
unscaled = unscaled[window_setting:]
unscaled.index = y_test.index


original_tail = LME_shifted.loc[y_train.index[-window_setting:]]

for key, item in y_test.items():
    rolling_avg = original_tail.tail(window_setting).mean()
    original_y = item + rolling_avg
    original_tail = original_tail.append(pd.Series([original_y]))


original_y = pd.Series(original_tail)
original_y = original_y[window_setting:]
original_y.index = y_test.index




print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))


mae = metrics.mean_absolute_error(original_y, unscaled)
print('Polynomial MAE of Degree = 3: ', mae)
#print('kfold test accuracy =', kfold_test_accuracy)

# To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Polynomial Regression Prediction (deg=3) - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# MAE for scaled results:  20.614156523267358
#
# Mean Absolute Error: 1223.3308019269723
# Mean Squared Error: 2534602.819099644
# Root Mean Squared Error: 1592.0435983664656
# Polynomial MAE of Degree = 3:  1223.3308019269723

# %%
plt.plot(y_poly_pred)
plt.plot(y_test)
plt.title('Scaled Values', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Scaled Values')

# %%
X_test
# Out:
#                    lag0         lag1         lag2        lag3        lag4  \
# ds
# 2017-10-31   620.892857  -206.107143   580.482143  587.714286  -16.410714
# 2017-11-01  1037.000000  -163.928571   568.660714  643.000000   46.482143
# 2017-11-02   745.571429  -194.928571   450.660714  772.607143   39.767857
# 2017-11-03   791.178571   -87.821429  -194.285714  345.178571  393.089286
# 2017-11-06   916.571429   373.035714   -44.392857   73.142857  378.375000
# 2017-11-07   562.178571   434.035714   144.107143  -67.642857  532.446429
# 2017-11-08   541.321429   538.071429  -511.678571  318.642857  364.696429
# 2017-11-09    68.178571   805.750000  -627.750000  238.428571  183.196429
# 2017-11-10  -164.500000  1007.107143  -720.678571  459.642857  200.196429
# 2017-11-13   193.428571  1122.142857  -536.428571  740.357143  448.410714
# 2017-11-14  -554.714286   918.392857  -596.428571  767.321429  635.625000
# 2017-11-15  -632.928571   691.500000  -323.750000  934.678571  615.589286
# 2017-11-16  -966.535714   693.285714  -672.535714  926.357143  640.196429
# 2017-11-17  -724.035714   598.285714 -1186.589286  557.678571  621.928571
# 2017-11-20  -633.535714   625.714286  -905.339286  481.571429  549.642857
# 2018-09-14  -498.321429
# 2018-09-17  -161.571429
# 2018-09-18  -283.785714
# 2018-09-19  -198.642857
# 2018-09-20   -78.607143
# 2018-09-21   406.714286
# 2018-09-24   662.071429
# 2018-09-25   546.714286
# 2018-09-26   808.250000
# 2018-09-27   777.107143
# 2018-09-28   782.785714
# 2018-10-01   729.071429
# 2018-10-02   638.250000
# 2018-10-03   519.714286
# 2018-10-04   690.357143
# 2018-10-05  1000.535714
#
# [244 rows x 11 columns]

# %%
polynomial_features= PolynomialFeatures(degree=4)

X_poly = polynomial_features.fit_transform(X_train)

regressor = LinearRegression()
regressor.fit(X_poly, y_train)

X_poly_test = polynomial_features.fit_transform(X_test)
y_poly_pred = regressor.predict(X_poly_test)
y_poly_pred = pd.Series(y_poly_pred)
y_poly_pred.index = y_test.index

mae = np.sqrt(metrics.mean_absolute_error(y_test,y_poly_pred))
print('MAE for scaled results: ', mae)
print()

original_tail = LME_shifted.loc[y_train.index[-window_setting:]]

for key, item in y_poly_pred.items():
    rolling_avg = original_tail.tail(window_setting).mean()
    unscaled_result = item + rolling_avg
    original_tail = original_tail.append(pd.Series([unscaled_result]))

unscaled = pd.Series(original_tail)
unscaled = unscaled[window_setting:]
unscaled.index = y_test.index


original_tail = LME_shifted.loc[y_train.index[-window_setting:]]

for key, item in y_test.items():
    rolling_avg = original_tail.tail(window_setting).mean()
    original_y = item + rolling_avg
    original_tail = original_tail.append(pd.Series([original_y]))


original_y = pd.Series(original_tail)
original_y = original_y[window_setting:]
original_y.index = y_test.index


print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))


mae = metrics.mean_absolute_error(original_y, unscaled)
print('Polynomial MAE of Degree = 2: ', mae)
#print('kfold test accuracy =', kfold_test_accuracy)

# To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Polynomial Regression (deg = 4) Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# MAE for scaled results:  232.46297598862787
#
# Mean Absolute Error: 100889.0564233236
# Mean Squared Error: 17939615694.53373
# Root Mean Squared Error: 133938.8505794108
# Polynomial MAE of Degree = 2:  100889.0564233236

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true))*100

def root_mean_squared_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.sqrt(((y_pred - y_true) **2).mean())
    #return np.mean(np.abs((y_true - y_pred) / y_true))*100

# %%
print('mape', mean_absolute_percentage_error(cmp_df['y'], cmp_df['yhat']))

print('rmse', root_mean_squared_error(cmp_df['y'], cmp_df['yhat']))
# Out:
# mape 219.83967767924054
# rmse 0.05529372373011725

# %%
pd.DataFrame({'mean':tester.rolling(window=3).mean(), 'original': tester})
# Out:
#        mean  original
# 0       NaN       1.0
# 1       NaN       2.0
# 2  2.000000       3.0
# 3  3.000000       4.0
# 4  6.000000      11.0
# 5  7.000000       6.0
# 6  8.000000       7.0
# 7  7.000000       8.0
# 8  8.000000       9.0
# 9  5.833333       0.5
