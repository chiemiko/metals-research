# %% [markdown]
# ## Preprocessing Stage
#
# **Serially correlated.** Best for situations where outcomes of previous days can be used to help determine the outcome of the next day
#
# https://towardsdatascience.com/time-series-in-python-part-2-dealing-with-seasonal-data-397a65b74051
#
# https://medium.com/@stallonejacob/time-series-forecast-a-basic-introduction-using-python-414fcb963000
#
# #### Standard TEN Models
# https://towardsdatascience.com/an-overview-of-time-series-forecasting-models-a2fa7a358fcb
#
# #### Stationarity
# https://campus.datacamp.com/courses/machine-learning-for-time-series-data-in-python/validating-and-inspecting-time-series-models?ex=10
# #### Predictions
# https://www.datacamp.com/courses/machine-learning-for-time-series-data-in-python
#
# #### Benchmarking?

# %%
import pandas as pd
from matplotlib import pyplot as plt
import re

from statsmodels.tsa.stattools import adfuller

from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

import numpy as np
import fbprophet
from fbprophet import Prophet
import statsmodels.api as sm
import matplotlib.pyplot as plt
from pylab import rcParams

import logging

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.Series(timeseries).rolling(window=12).mean()
    #pd.rolling_mean(timeseries, window=12)
    rolstd =  pd.Series(timeseries).rolling(window=12).std()
#Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    # dftest = adfuller(timeseries, autolag='AIC')
    dftest = adfuller(timeseries)
    
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %% [markdown]
# ## Reading in the Data

# %%
df_orig = pd.read_csv('forecasting_raw_data/DashboardComm2.csv')
df_orig = df_orig.iloc[:, 0:len(df_orig.columns)-5]

df_orig.columns = df_orig.iloc[0]
#df_orig.head(10)

df = df_orig.iloc[6: ,:]
df = df.rename(columns={"Column1": "Date"})
df.head()

df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')

filename = '../raw_data_finals\MetalsDashboard(Aug)LATEST.xlsx'
test_df = pd.read_excel(filename, sheet_name="Commodities Data")

# %%
LME_futures = pd.read_excel('forecasting_raw_data/LME Futures Price.xlsx')
LME_futures = LME_futures.iloc[3:, 1:]
#LME_futures['Unnamed: 1'] = pd.datetime(LME_futures['Unnamed: 1'])
LME_futures.index = LME_futures['Unnamed: 1']



LME_futures = LME_futures.iloc[:, 1:]
#LME_futures = df_orig.iloc[:, 0:len(df_orig.columns)-

#LME_futures = LME_futures.resample('B').sum()

# %%
LME_futures = LME_futures[LME_futures.index.year>=2009]

# %%
LME_futures.isnull().sum()
# Out:
# Cash Price ($/MT)    0
# Inventory (MT)       0
# dtype: int64

# %% [markdown]
# ### Null Values

# %%
df = df.dropna(subset=["LME Ni cash price"])
df.isnull().sum()
# Out:
# 0
# LME Ni cash price                   0
# LME Ni inventory (total)            0
# LME Ni inventory (briquette)        0
# LME Ni inventory (other forms)      0
# Critical Inventory                 22
# LME Co cash price                   0
# LME Cu cash price                   0
# Comex Cu future                     0
# Comex Cu future2                    0
# LME Al cash price                   0
# Fastmarkets- Cobalt LOW           458
# Fastmarkets - Cobalt High           0
# Column2                             0
# dtype: int64

# %% [markdown]
# ### Conversion of Ni price from string to number

# %%
'''Converts string price to just numbers in string format'''
def convert_price(price_string):
    
    # substitutes any character that is not a numeric digit
    non_digits = re.compile(r'[^\d.]+')
    only_digits = non_digits.sub('', price_string)
    return only_digits

df['LME Ni cash price'] = df['LME Ni cash price'].apply(convert_price)
df['LME Ni cash price'] = pd.to_numeric(df['LME Ni cash price'],errors='coerce')


# Example conversion below
print(convert_price('$5,053 round trip'))
# Out:
# 5053

# %%
nickel = df.iloc[:, 0]
nickel.head()
# Out:
# Date
# 2015-01-02    14756
# 2015-01-05    15126
# 2015-01-06    15191
# 2015-01-07    15483
# 2015-01-08    15486
# Name: LME Ni cash price, dtype: int64

# %%
for key,item in nickel.items():
    nickel[key] = float(item)
    #print(key, item)
# Out:
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for item in nickel:
    print(type(item))

# %%
for item in df:
    print(type(item))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
nickel_weekly = nickel.resample('B').sum()
#nickel_weekly.plot()

# %% [markdown]
# ## Time Series Decomposition
#
# There are some methods to model the trends and then remove them from the series
#
# Methods include - smoothing, aggression

# %%
nickel_log = np.log(nickel_weekly)
nickel_log
nickel_square = (nickel_weekly**2)
plt.plot((nickel_weekly))

# %%
rolmean = pd.Series(nickel_log).rolling(window=12).mean()

plt.plot(nickel_log)
plt.plot(rolmean, color='red')
plt.show()

# %% [markdown]
# #### Subtracting the Trend

# %%
diff = nickel_log - rolmean
diff.dropna(inplace=True)
plt.plot(diff)

# %%
test_stationarity(diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.895077e+00
# p-value                        3.475263e-17
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.184000e+03
# Critical Value (1%)           -3.435885e+00
# Critical Value (5%)           -2.863984e+00
# Critical Value (10%)          -2.568071e+00
# dtype: float64

# %% [markdown]
# The test statistic iss maller than 5% critical/alpha value, so we can be 95% confident that this series is stationary.
#
# Can use exponentially weighted rolling averages for more complex data like stock prices

# %%
exponential_weight = pd.ewma(nickel_log,halflife=12 )
plt.plot(nickel_log)

plt.plot(exponential_weight, color='red')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-3f09e3e2da23> in <module>
# ----> 1 exponential_weight = pd.ewma(nickel_log,halflife=12 )
#       2 plt.plot(nickel_log)
#       3
#       4 plt.plot(exponential_weight, color='red')
#
# AttributeError: module 'pandas' has no attribute 'ewma'

# %%
exponential_diff = nickel_log-exponential_weight
test_stationarity(exponential_diff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-dda885bffd9c> in <module>
# ----> 1 exponential_diff = nickel_log-exponential_weight
#       2 test_stationarity(exponential_diff)
#
# NameError: name 'exponential_weight' is not defined

# %%
test_stationarity(LME_futures['Cash Price ($/MT)'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -1.937046
# p-value                           0.314839
# #Lags Used                       20.000000
# Number of Observations Used    2787.000000
# Critical Value (1%)              -3.432699
# Critical Value (5%)              -2.862578
# Critical Value (10%)             -2.567322
# dtype: float64

# %%
futures = LME_futures['Cash Price ($/MT)']

# %% [markdown]
# ## Differencing

# %%
nickel_diff = nickel_log.shift()
plt.plot(nickel_diff)
plt.title('First Difference Stationarity', fontsize=20)

plt.show()

# %%
test_stationarity(nickel_diff)
# Out:
# Results of Dickey-Fuller Test:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-20-d8df7f01e86c> in <module>
# ----> 1 test_stationarity(nickel_diff)
#
# <ipython-input-2-e7bad7654ddd> in test_stationarity(timeseries)
#      16     print('Results of Dickey-Fuller Test:')
#      17     # dftest = adfuller(timeseries, autolag='AIC')
# ---> 18     dftest = adfuller(timeseries)
#      19
#      20     dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     255         if not regresults:
#     256             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# --> 257                                        maxlag, autolag)
#     258         else:
#     259             icbest, bestlag, alres = _autolag(OLS, xdshort, fullRHS, startlag,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in _autolag(mod, endog, exog, startlag, maxlag, method, modargs, fitargs, regresults)
#      90     method = method.lower()
#      91     for lag in range(startlag, startlag + maxlag + 1):
# ---> 92         mod_instance = mod(endog, exog[:, :lag], *modargs)
#      93         results[lag] = mod_instance.fit()
#      94
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     836                  **kwargs):
#     837         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 838                                   hasconst=hasconst, **kwargs)
#     839         if "weights" in self._init_keys:
#     840             self._init_keys.remove("weights")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     682             weights = weights.squeeze()
#     683         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 684                                   weights=weights, hasconst=hasconst, **kwargs)
#     685         nobs = self.exog.shape[0]
#     686         weights = self.weights
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     194     """
#     195     def __init__(self, endog, exog, **kwargs):
# --> 196         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     197         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     198
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     214
#     215     def __init__(self, endog, exog=None, **kwargs):
# --> 216         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     217         self.initialize()
#     218
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      66         hasconst = kwargs.pop('hasconst', None)
#      67         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 68                                       **kwargs)
#      69         self.k_constant = self.data.k_constant
#      70         self.exog = self.data.exog
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      89
#      90     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 91         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      92         # kwargs arrays could have changed, easier to just attach here
#      93         for key in kwargs:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     633     klass = handle_data_class_factory(endog, exog)
#     634     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 635                  **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      78         self.const_idx = None
#      79         self.k_constant = 0
# ---> 80         self._handle_constant(hasconst)
#      81         self._check_integrity()
#      82         self._cache = {}
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     124             ptp_ = np.ptp(self.exog, axis=0)
#     125             if not np.isfinite(ptp_).all():
# --> 126                 raise MissingDataError('exog contains inf or nans')
#     127             const_idx = np.where(ptp_ == 0)[0].squeeze()
#     128             self.k_constant = const_idx.size
#
# MissingDataError: exog contains inf or nans

# %% [markdown]
# ## Time Series Decomposition

# %%
# Debugging

rcParams['figure.figsize'] = 11, 9
decomposition = sm.tsa.seasonal_decompose(nickel_log)
fig = decomposition.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-f604b8b3ced6> in <module>
#       3 rcParams['figure.figsize'] = 11, 9
#       4 decomposition = sm.tsa.seasonal_decompose(nickel_log)
# ----> 5 fig = decomposition.plot()
#       6 plt.show()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py in plot(self)
#     179         fig, axes = plt.subplots(4, 1, sharex=True)
#     180         if hasattr(self.observed, 'plot'):  # got pandas use it
# --> 181             self.observed.plot(ax=axes[0], legend=False)
#     182             axes[0].set_ylabel('Observed')
#     183             self.trend.plot(ax=axes[1], legend=False)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#    2744
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1996                  yerr=yerr, xerr=xerr,
#    1997                  label=label, secondary_y=secondary_y,
# -> 1998                  **kwds)
#    1999
#    2000
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     249         self._compute_plot_data()
#     250         self._setup_subplots()
# --> 251         self._make_plot()
#     252         self._add_table()
#     253         self._make_legend()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in _make_plot(self)
#     994                              stacking_id=stacking_id,
#     995                              is_errorbar=is_errorbar,
# --> 996                              **kwds)
#     997             self._add_legend_handle(newlines[0], label, index=i)
#     998
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in _ts_plot(cls, ax, x, data, style, **kwds)
#    1032         ax._plot_data.append((data, cls._kind, kwds))
#    1033
# -> 1034         lines = cls._plot(ax, data.index, data.values, style=style, **kwds)
#    1035         # set date formatter, locators and rescale limits
#    1036         format_dateaxis(ax, ax.freq, data.index)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1009             cls._initialize_stacker(ax, stacking_id, len(y))
#    1010         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds['label'])
# -> 1011         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1012         cls._update_stacker(ax, stacking_id, y)
#    1013         return lines
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     599             else:
#     600                 args = (x, y)
# --> 601             return ax.plot(*args, **kwds)
#     602
#     603     def _get_index_name(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
# -> 1668             self.add_line(line)
#    1669         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1670         return lines
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1898             line.set_clip_path(self.patch)
#    1899
# -> 1900         self._update_line_limits(line)
#    1901         if not line.get_label():
#    1902             line.set_label('_line%d' % len(self.lines))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1920         Figures out the data limit of the given line, updating self.dataLim.
#    1921         """
# -> 1922         path = line.get_path()
#    1923         if path.vertices.size == 0:
#    1924             return
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1025         """
#    1026         if self._invalidy or self._invalidx:
# -> 1027             self.recache()
#    1028         return self._path
#    1029
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     668         if always or self._invalidx:
#     669             xconv = self.convert_xunits(self._xorig)
# --> 670             x = _to_unmasked_float_array(xconv).ravel()
#     671         else:
#     672             x = self._x
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1388         return np.ma.asarray(x, float).filled(np.nan)
#    1389     else:
# -> 1390         return np.asarray(x, float)
#    1391
#    1392
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# TypeError: float() argument must be a string or a number, not 'Period'

# %%
rcParams['figure.figsize'] = 11, 9
decomposition = sm.tsa.seasonal_decompose(nickel_weekly)
fig = decomposition.plot()
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposition = sm.tsa.seasonal_decompose(futures)
fig = decomposition.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-23b77288d698> in <module>
#       1 rcParams['figure.figsize'] = 11, 9
# ----> 2 decomposition = sm.tsa.seasonal_decompose(futures)
#       3 fig = decomposition.plot()
#       4 plt.show()
#       5
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py in seasonal_decompose(x, model, filt, freq, two_sided, extrapolate_trend)
#     113     nobs = len(x)
#     114
# --> 115     if not np.all(np.isfinite(x)):
#     116         raise ValueError("This function does not handle missing values")
#     117     if model.startswith('m'):
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
futures

# %%
print(dir(decomposition))
print(decomposition.resid)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'nobs', 'observed', 'plot', 'resid', 'seasonal', 'trend']
# Date
# 2015-01-02           NaN
# 2015-01-05           NaN
# 2015-01-06      0.012711
# 2015-01-07    164.792627
# 2015-01-08    204.929313
# 2015-01-09     69.283935
# 2015-01-12    108.981414
# 2015-01-13    -98.587289
# 2015-01-14   -371.007373
# 2015-01-15    -57.870687
# 2015-01-16    216.083935
# 2015-01-19   -236.818586
# 2015-01-20     13.612711
# 2015-01-21    319.192627
# 2015-01-22    101.929313
# 2015-01-23   -405.916065
# 2015-01-26    -12.818586
# 2015-01-27     37.412711
# 2015-01-28    104.992627
# 2015-01-29   -140.670687
# 2015-01-30     10.483935
# 2015-02-02    158.381414
# 2015-02-03    107.012711
# 2015-02-04   -124.207373
# 2015-02-05    -18.470687
# 2015-02-06    128.883935
# 2015-02-09    122.981414
# 2015-02-10    -93.987289
# 2015-02-11    -81.207373
# 2015-02-12      4.929313
#                  ...
# 2019-06-24   -130.018586
# 2019-06-25    -29.587289
# 2019-06-26      9.592627
# 2019-06-27    222.129313
# 2019-06-28    220.083935
# 2019-07-01   -102.218586
# 2019-07-02   -263.587289
# 2019-07-03     11.992627
# 2019-07-04    -54.270687
# 2019-07-05    -41.516065
# 2019-07-08     83.581414
# 2019-07-09    -83.987289
# 2019-07-10    -32.607373
# 2019-07-11    -53.670687
# 2019-07-12      5.083935
# 2019-07-15   -109.818586
# 2019-07-16    -27.587289
# 2019-07-17    102.192627
# 2019-07-18    385.729313
# 2019-07-19    216.483935
# 2019-07-22   -227.018586
# 2019-07-23   -172.987289
# 2019-07-24    296.192627
# 2019-07-25   -175.870687
# 2019-07-26   -189.516065
# 2019-07-29     81.981414
# 2019-07-30    -10.187289
# 2019-07-31    -12.407373
# 2019-08-01           NaN
# 2019-08-02           NaN
# Freq: B, Name: LME Ni cash price, Length: 1196, dtype: float64

# %%
decomp_resid = decomposition.resid
ax = decomp_resid.plot(figsize=(14,2))

ax.set_xlabel('Date')
ax.set_ylabel('Residuals of Time Series')
ax.set_title('Residual/White Noise Values of the Time Series')
plt.show()

# %%
decomp_resid.dropna(inplace=True)

# %%
test_stationarity(decomp_resid)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.405554e+01
# p-value                        3.122129e-26
# #Lags Used                     1.700000e+01
# Number of Observations Used    1.174000e+03
# Critical Value (1%)           -3.435932e+00
# Critical Value (5%)           -2.864005e+00
# Critical Value (10%)          -2.568082e+00
# dtype: float64

# %%
test_stationarity(nickel_weekly)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -1.971200
# p-value                           0.299342
# #Lags Used                        0.000000
# Number of Observations Used    1195.000000
# Critical Value (1%)              -3.435834
# Critical Value (5%)              -2.863962
# Critical Value (10%)             -2.568059
# dtype: float64

# %% [markdown]
# ## Using That

# %%
decomposition = seasonal_decompose(diff)

# %%
rcParams['figure.figsize'] = 11, 9
decomposition = sm.tsa.seasonal_decompose(diff)
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ### Remove the trend and seasonality from the Time series and now we have the residual values. Let's check stationarity.

# %%
decomp_resid = decomposition.resid
decomp_resid.dropna(inplace=True)
test_stationarity(decomp_resid)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.345055e+01
# p-value                        3.691342e-25
# #Lags Used                     2.100000e+01
# Number of Observations Used    1.159000e+03
# Critical Value (1%)           -3.436005e+00
# Critical Value (5%)           -2.864037e+00
# Critical Value (10%)          -2.568099e+00
# dtype: float64

# %% [markdown]
# ## Making Time Series Stationary
# As seen on:
# https://campus.datacamp.com/courses/forecasting-using-arima-models-in-python/chapter-1-arma-models?ex=5
#
# The most common test for identifying if time series data is stationary is the Dicky-Fuller Test - (Null hypothesis is that time series data is non-stationary on

# %%
results = adfuller(nickel)

print(results)
# Out:
# (-1.9711999348352705, 0.2993419051235137, 0, 1195, {'1%': -3.4358340188169882, '5%': -2.8639616494853217, '10%': -2.5680593310691338}, 15853.188858095957)

# %% [markdown]
# ### Results Analysis - Does Not Pass the Dicky Fuller Test:
#
# First number is the **test statistic**:
# - The more negative it is means the more likely it is to be stationary
#
# Second number is the p-value
# - If p-value is small, then we can reject the null hypothesis that the data is non-stationary and accept the alternative hypothesis that the data is stationary
#
# Last values (dictionary values)
# - If we wanted a p-value of 0.05 or below, we would need a test statistic of less than -2.86396

# %%
nickel.plot()
plt.style.use('seaborn')
plt.title("Hello")
plt.show()

# %% [markdown]
# ## Transforming the Data into Stationary Form Before Modeling
#
# Common way is to take it's difference (subtract the previous value)
#
#
# Other methods for reshaping into stationary are:
# - Taking the log (np.log(nickel))
# - Taking the square root (np.sqrt(nickel))
# - Taking the proportional change (nickel.shift(1)/nickel)

# %%
nickel_stationary = nickel.diff().dropna()

# %%
nickel_stationary.plot(figsize=(15,6))
plt.style.use('seaborn')
plt.title("Normalized Ni", fontsize=20)
plt.show()

# %%
nickel_stationary.hist(bins=30)
plt.show()

# %%
results = adfuller(nickel_stationary)

print(results)
# Out:
# (-35.76480686193036, 0.0, 0, 1194, {'1%': -3.4358386217286885, '5%': -2.8639636801920956, '10%': -2.5680604125597277}, 15843.385342382324)

# %% [markdown]
# ## Modeling
# AR, MA, and ARMA Models
# https://campus.datacamp.com/courses/forecasting-using-arima-models-in-python/chapter-1-arma-models?ex=9
#
# Using p lags

# %%
p = 2
q = 2


ar_model = ARMA(nickel_stationary, order = (1,0))
ma_model = ARMA(nickel_stationary, order = (0, 1))

# %%
ar_results = ar_model.fit()
print(ar_results.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:      LME Ni cash price   No. Observations:                 1196
# Model:                     ARMA(1, 0)   Log Likelihood               -8097.643
# Method:                       css-mle   S.D. of innovations            210.552
# Date:                Mon, 07 Oct 2019   AIC                          16201.286
# Time:                        18:41:12   BIC                          16216.546
# Sample:                    01-02-2015   HQIC                         16207.035
#                          - 08-02-2019
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    1.222e+04   1121.664     10.891      0.000       1e+04    1.44e+04
# ar.L1.LME Ni cash price     0.9951      0.003    346.818      0.000       0.989       1.001
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0050           +0.0000j            1.0050            0.0000
# -----------------------------------------------------------------------------

# %%
ma_results = ma_model.fit()

print(ma_results.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:      LME Ni cash price   No. Observations:                 1195
# Model:                     ARMA(0, 1)   Log Likelihood               -8089.239
# Method:                       css-mle   S.D. of innovations            210.671
# Date:                Sun, 22 Sep 2019   AIC                          16184.478
# Time:                        13:53:38   BIC                          16199.736
# Sample:                    01-05-2015   HQIC                         16190.227
#                          - 08-02-2019
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.1536      5.879     -0.026      0.979     -11.676      11.369
# ma.L1.LME Ni cash price    -0.0354      0.029     -1.199      0.231      -0.093       0.022
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           28.2806           +0.0000j           28.2806            0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# ### SARIMAX models can do everything ARMA models can do
#
# https://campus.datacamp.com/courses/forecasting-using-arima-models-in-python/chapter-2-fitting-the-future?ex=5

# %%
sar_model = SARIMAX(y, order=(p,0,q), trend='c')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-3f5170905933> in <module>
# ----> 1 sar_model = SARIMAX(y, order=(p,0,q), trend='c')
#
# NameError: name 'y' is not defined

# %%
# Make predictions for the last 25 values
results = sar_model.fit()

# Makes in-sample prediction
# start defines how many steps back to begin the forecast 
forecast = results.get_prediction(start = -25)

# Forecast mean
mean_forecast = forecast.predicted_mean

# %%
mean_forecast
# Out:
# 2019-07-01    12613.287086
# 2019-07-02    12279.971012
# 2019-07-03    12022.028690
# 2019-07-04    12267.302145
# 2019-07-05    12263.006882
# 2019-07-08    12416.449900
# 2019-07-09    12661.016268
# 2019-07-10    12643.045592
# 2019-07-11    12918.605083
# 2019-07-12    13057.610140
# 2019-07-15    13394.813471
# 2019-07-16    13575.355132
# 2019-07-17    13983.288749
# 2019-07-18    14387.112634
# 2019-07-19    14788.246578
# 2019-07-22    14666.840813
# 2019-07-23    14267.791072
# 2019-07-24    14134.665922
# 2019-07-25    14487.416012
# 2019-07-26    14031.255252
# 2019-07-29    14070.108690
# 2019-07-30    14300.692502
# 2019-07-31    14309.841588
# 2019-08-01    14439.505422
# 2019-08-02    14561.194787
# Freq: B, dtype: float64

# %%
confidence_intervals = forecast.conf_int()
print(confidence_intervals)
# Out:
#             lower LME Ni cash price  upper LME Ni cash price
# 2019-07-01             12201.986708             13024.587463
# 2019-07-02             11868.670634             12691.271389
# 2019-07-03             11610.728312             12433.329067
# 2019-07-04             11856.001767             12678.602522
# 2019-07-05             11851.706504             12674.307259
# 2019-07-08             12005.149523             12827.750277
# 2019-07-09             12249.715891             13072.316646
# 2019-07-10             12231.745215             13054.345970
# 2019-07-11             12507.304705             13329.905460
# 2019-07-12             12646.309762             13468.910517
# 2019-07-15             12983.513094             13806.113848
# 2019-07-16             13164.054755             13986.655510
# 2019-07-17             13571.988372             14394.589127
# 2019-07-18             13975.812257             14798.413012
# 2019-07-19             14376.946200             15199.546955
# 2019-07-22             14255.540436             15078.141190
# 2019-07-23             13856.490695             14679.091449
# 2019-07-24             13723.365544             14545.966299
# 2019-07-25             14076.115634             14898.716389
# 2019-07-26             13619.954875             14442.555629
# 2019-07-29             13658.808313             14481.409067
# 2019-07-30             13889.392125             14711.992880
# 2019-07-31             13898.541210             14721.141965
# 2019-08-01             14028.205045             14850.805799
# 2019-08-02             14149.894409             14972.495164

# %% [markdown]
# ## Plotting Results

# %%
ax = nickel.plot()
ax.set_title("Ni Price Original")

ax.set_xlabel("Date")
ax.set_ylabel("Ni Price")

ax.axvline('2018-5-1', color='red', linestyle='--')


ax.axvspan('2017-1-1', '2018-1-1', color='pink', alpha=.5)
plt.show()

# %%
dates = mean_forecast.index
lower_limits = confidence_intervals.iloc[:,0]
upper_limits = confidence_intervals.iloc[:,1]



nickel.plot()
plt.title("Ni Price Original")

plt.figure()

# Plot prediction

plt.plot(dates, mean_forecast.values, 
        color = 'red',
        label='forecast')
plt.xticks(rotation=45)
# Share uncertainty area
plt.fill_between(dates,lower_limits, upper_limits, color='pink')

plt.show()

# %%
len(mean_forecast.values)
# Out:
# 25

# %% [markdown]
# ## Making Dynamic Predictions (ie, one or more steps ahead predictions)

# %% [markdown]
# ## Interpolation
# https://campus.datacamp.com/courses/machine-learning-for-time-series-data-in-python/predicting-time-series-data?ex=5

# %%
missing = nickel.isna()

# %%
nickel_interp = nickel.interpolate('linear')

ax = nickel_interp.plot(c='r')
nickel.plot(c='k', ax=ax, lw=2)

# %%
# Standardizing variance of data

# %%
# from https://campus.datacamp.com/courses/machine-learning-for-time-series-data-in-python/predicting-time-series-data?ex=5

def percent_change(values):
    previous_values = values[:-1]
    last_value = values[-1]
    
    percent_change = (last_value - np.mean(previous_values)) / np.mean(previous_values)
    return percent_change

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))
ax = nickel.plot(ax=axs[0])

ax = nickel.rolling(window=20).aggregate(percent_change).plot(ax=axs[1])
ax.legend_.set_visable(False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-9c0931c799fe> in <module>
#       3
#       4 ax = nickel.rolling(window=20).aggregate(percent_change).plot(ax=axs[1])
# ----> 5 ax.legend_.set_visable(False)
#       6 ax.title('Hello')
#       7 ax.show()
#
# AttributeError: 'NoneType' object has no attribute 'set_visable'

# %%
# https://campus.datacamp.com/courses/machine-learning-for-time-series-data-in-python/predicting-time-series-data?ex=5

# %%
nickel_perc_change = percent_change(nickel)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
for data, ax in zip([nickel, nickel_perc_change], axs):
    
    this_mean = data.mean()
    this_std = data.std()
    
    data.plot(ax=ax)
    ax.axhline(this_mean + this_std*3, ls='--', c='r')
    ax.axhline(this_mean - this_std*3, ls='--', c='r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-94c1c97ada44> in <module>
#       5     this_std = data.std()
#       6
# ----> 7     data.plot(ax=ax)
#       8     ax.axhline(this_mean + this_std*3, ls='--', c='r')
#       9     ax.axhline(this_mean - this_std*3, ls='--', c='r')
#
# AttributeError: 'numpy.float64' object has no attribute 'plot'

# %%
## BACK TO ARIMA MODELING: 

for p in range(3):
    for q in range(3):
        try:
            
            model = SARIMAX(nickel, order=(p, 0, q))
            results = model.fit()
            
            print(p, q, results.aic, results.bic)
        except:
            print(p, q, None, None)
# Out:
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 0 0 25773.525875394622 25778.612613329133
# 0 1 24242.326750385317 24252.50022625434
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 0 2 23087.938813038134 23103.199026841667
# 1 0 16205.859853400863 16216.033329269885
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 1 1 16206.845745659597 16222.105959463128
# 1 2 16208.437387685744 16228.784339423786
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 2 0 16206.853394723097 16222.113608526628
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 2 1 16207.783184620905 16228.130136358946
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 2 2 16209.447359754195 16234.881049426747

# %%
nickel_log.describe()
# Out:
# count    1196.000000
# mean        9.327631
# std         0.167409
# min         8.930891
# 25%         9.205478
# 50%         9.329323
# 75%         9.465370
# max         9.660651
# Name: LME Ni cash price, dtype: float64

# %%
plt.plot(nickel_log)

# %% [markdown]
# ## Using Prophet
# https://towardsdatascience.com/time-series-forecasting-with-prophet-54f2ac5e722e

# %%
logging.getLogger().setLevel(logging.ERROR)

# %%
list_one = list(futures.index)
list_two = list(futures)
df = pd.DataFrame(list(zip(list_one, list_two)), columns = ['ds', 'y'])

# %%
list_one = list(nickel_log.index)
list_two = list(nickel_log)
df = pd.DataFrame(list(zip(list_one, list_two)), columns = ['ds', 'y'])

# %%
df.shape
# Out:
# (2808, 2)

# %%
prediction_size = 300
train_df = df[:-prediction_size]

# %%
m = Prophet()
m.fit(train_df)

future = m.make_future_dataframe(periods = prediction_size)
forecast = m.predict(future)
forecast.head()
# Out:
#           ds        trend   yhat_lower    yhat_upper  trend_lower  \
# 0 2009-01-01  9264.060933  7324.511411  10360.381822  9264.060933
# 1 2009-01-02  9299.037004  7239.385922  10434.902848  9299.037004
# 2 2009-01-05  9403.965214  7443.919674  10505.862584  9403.965214
# 3 2009-01-06  9438.941284  7424.410032  10559.991569  9438.941284
# 4 2009-01-07  9473.917355  7580.722945  10534.344773  9473.917355
#
#    trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  9264.060933     -509.771067           -509.771067           -509.771067
# 1  9299.037004     -479.800395           -479.800395           -479.800395
# 2  9403.965214     -438.219486           -438.219486           -438.219486
# 3  9438.941284     -443.045285           -443.045285           -443.045285
# 4  9473.917355     -414.936299           -414.936299           -414.936299
#
#        weekly  weekly_lower  weekly_upper     yearly  yearly_lower  \
# 0 -452.538253   -452.538253   -452.538253 -57.232814    -57.232814
# 1 -435.160372   -435.160372   -435.160372 -44.640023    -44.640023
# 2 -434.941019   -434.941019   -434.941019  -3.278466     -3.278466
# 3 -455.143324   -455.143324   -455.143324  12.098039     12.098039
# 4 -443.371866   -443.371866   -443.371866  28.435567     28.435567
#
#    yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0    -57.232814                   0.0                         0.0
# 1    -44.640023                   0.0                         0.0
# 2     -3.278466                   0.0                         0.0
# 3     12.098039                   0.0                         0.0
# 4     28.435567                   0.0                         0.0
#
#    multiplicative_terms_upper         yhat
# 0                         0.0  8754.289866
# 1                         0.0  8819.236608
# 2                         0.0  8965.745728
# 3                         0.0  8995.895999
# 4                         0.0  9058.981056

# %%
m.plot(forecast)

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %% [markdown]
# #### From Three Time Components Above:
#
# 1. Overall trend (measured in??) for yearly movements and fluctuations in Nickel prices can see the general direction is is at
#
# 2. Weekly -- not useful
#
# 3. Yearly - Ask Sarah about yearly seasonality (and figure out units)

# %% [markdown]
# ### Model Performance

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))

cmp_df = make_comparison_dataframe(df, forecast)

# %%
def calculate_forecast_errors(df, prediction_size):
    df = df.copy()
    df['e'] = df['y'] - df['yhat']
    df['p'] = 100*df['e']/df['y']
    
    predicted_part = df[-prediction_size:]
    error_mean = lambda error_name: np.mean(np.abs(predicted_part[error_name]))
    return {'MAPE': error_mean('p'), 'MAE': error_mean('e')}

for err_name, err_value in calculate_forecast_errors(cmp_df, prediction_size).items():
    print(err_name, err_value)
# Out:
# MAPE 21.80576814427684
# MAE 2600.8200863330576

# %%
plt.figure(figsize = (17, 8))
plt.plot(cmp_df['yhat'])

plt.plot(cmp_df['yhat_lower'])
plt.plot(cmp_df['yhat_upper'])
plt.plot(cmp_df['y'])
plt.title('Forecast with Upper and Lower Bounds', fontsize = 20)
plt.xlabel('Time', fontsize = 15)
plt.ylabel('Average Weekly NOx Concentration', fontsize=15)
plt.grid(False)
plt.show()

# %% [markdown]
# ### ACF and PACF
#
# Start to Finish - Super Comprehensive:
# https://machinelearningmastery.com/time-series-forecast-case-study-python-monthly-armed-robberies-boston/

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
#from matplotlib import pyplot

# %%
series = nickel_log
pyplot.figure(figsize = (10, 10))
#pyplot.figsize(10, 10)
pyplot.subplot(211)
plot_acf(series, ax=pyplot.gca())
pyplot.subplot(212)
plot_pacf(series, ax=pyplot.gca())
pyplot.show()

# %%
df
# Out:
#              ds         y
# 0    2015-01-02  9.599405
# 1    2015-01-05  9.624170
# 2    2015-01-06  9.628458
# 3    2015-01-07  9.647498
# 4    2015-01-08  9.647692
# 5    2015-01-09  9.631416
# 6    2015-01-12  9.617737
# 7    2015-01-13  9.587749
# 8    2015-01-14  9.563880
# 9    2015-01-15  9.575955
# 10   2015-01-16  9.597098
# 11   2015-01-19  9.576163
# 12   2015-01-20  9.597030
# 13   2015-01-21  9.613937
# 14   2015-01-22  9.601842
# 15   2015-01-23  9.567525
# 16   2015-01-26  9.595058
# 17   2015-01-27  9.597709
# 18   2015-01-28  9.615339
# 19   2015-01-29  9.605486
# 20   2015-01-30  9.623046
# 21   2015-02-02  9.633907
# 22   2015-02-03  9.632728
# 23   2015-02-04  9.620461
# 24   2015-02-05  9.623972
# 25   2015-02-06  9.627668
# 26   2015-02-09  9.622384
# 27   2015-02-10  9.600015
# 28   2015-02-11  9.594990
# 29   2015-02-12  9.592059
# ...         ...       ...
# 1166 2019-06-24  9.398478
# 1167 2019-06-25  9.411974
# 1168 2019-06-26  9.427385
# 1169 2019-06-27  9.446045
# 1170 2019-06-28  9.442800
# 1171 2019-07-01  9.414586
# 1172 2019-07-02  9.393079
# 1173 2019-07-03  9.415076
# 1174 2019-07-04  9.414913
# 1175 2019-07-05  9.426902
# 1176 2019-07-08  9.447466
# 1177 2019-07-09  9.445175
# 1178 2019-07-10  9.467151
# 1179 2019-07-11  9.478304
# 1180 2019-07-12  9.503756
# 1181 2019-07-15  9.517457
# 1182 2019-07-16  9.547098
# 1183 2019-07-17  9.576302
# 1184 2019-07-18  9.603530
# 1185 2019-07-19  9.594241
# 1186 2019-07-22  9.564933
# 1187 2019-07-23  9.556126
# 1188 2019-07-24  9.582456
# 1189 2019-07-25  9.549096
# 1190 2019-07-26  9.551303
# 1191 2019-07-29  9.569762
# 1192 2019-07-30  9.569412
# 1193 2019-07-31  9.578588
# 1194 2019-08-01  9.587269
# 1195 2019-08-02  9.587269
#
# [1196 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
from math import sqrt
from matplotlib import pyplot

# %%
X = nickel_log
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]

# %%
# walk-foward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    # predict
    model = ARIMA(history, order=(0,1,2))
    model_fit = model.fit(disp=0)
    yhat = model_fit.forecast()[0]
    predictions.append(yhat)
    # observation
    obs = test[i]
    history.append(obs)
# errors
residuals = [test[i] -predictions[i] for i in range(len(test))]
residuals = pd.DataFrame(residuals)
pyplot.figure()
pyplot.subplot(211)
residuals.hist(ax=pyplot.gca())
pyplot.subplot(212)
residuals.plot(kind='kde', ax=pyplot.gca())
pyplot.show()
# Out:
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
X = nickel_log


train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]
# walk-foward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
# predict
    model = ARIMA(history, order=(0,1,2))
    model_fit = model.fit(disp=0)
    yhat = model_fit.forecast()[0]
    predictions.append(yhat)
    # observation
    obs = test[i]
    history.append(obs)
# errors
residuals = [test[i]-predictions[i] for i in range(len(test))]
residuals = pd.DataFrame(residuals)
pyplot.figure()
pyplot.subplot(211)
plot_acf(residuals, ax=pyplot.gca())
pyplot.subplot(212)
plot_pacf(residuals, ax=pyplot.gca())
pyplot.show()
# Out:
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
range(len(test))
# Out:
# range(0, 598)
