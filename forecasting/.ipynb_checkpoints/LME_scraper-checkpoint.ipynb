# %% [markdown]
# ### Make sure to install ChromeDriver here (May need to update which chromedriver is saved in current working python directory):
# https://sites.google.com/a/chromium.org/chromedriver/downloads
#
# https://towardsdatascience.com/web-scraping-using-selenium-python-8a60f4cf40ab

# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup


from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait 
from selenium.webdriver.support import expected_conditions
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
from datetime import datetime
#from datetime import date
#import datetime

from requests import get
from requests.exceptions import RequestException
from contextlib import closing

# %%
time_of_search = str(datetime.now())

# %%
import datetime

# Will need to change aug_days_num to 31 and sep_days_num to 30

aug_days_num = 1
sep_days_num = 0

date_list = []

for dayofmonth in range(1,aug_days_num+1):
    date = datetime.date(2019, 8, dayofmonth)
    date = str(date)
    date_list.append(date)
    
for dayofmonth in range(1,sep_days_num+1):
    date = datetime.date(2019, 9, dayofmonth)
    date = str(date)
    date_list.append(date)

# %%
def get_from_divs(soup, driver, city, origin):
    """
    Accepts a soup object and returns the various features of flights as a dataframe.    
    """
    soup = BeautifulSoup(driver.page_source, 'lxml')
    """Extract flight times"""
    time_divs = soup.find_all('div', attrs={'class': 'gws-flights-results__times'})
    if time_divs is not None:
        deptimes = []
        for time_div in time_divs:
            #print(time_div)
            deptimes.append(time_div.getText().split('–')[0].strip())
        
        arrtimes = []
        for time_div in time_divs:
            arrtimes.append(time_div.getText().split('–')[1].strip())
    else:
        raise Exception('No flight times were found.')
    
    
    """Extract carrier"""
    carrier_divs = soup.find_all('div', attrs={'class': 'gws-flights-results__carriers'})
    if carrier_divs is not None:
        carriers = []
        for carrier_div in carrier_divs:
            carriers.append(carrier_div.getText().strip())
    else:
        raise Exception('No flight carriers were found.')
    
    
    """Extract duration of flights"""
    duration_divs = soup.find_all('div', attrs={'class': 'gws-flights-results__duration'})
    if duration_divs is not None:
        durations = []
        for duration_div in duration_divs:
            durations.append(duration_div.getText().strip())
    
    else:
        raise Exception('No flight durations were found.')
    
    """Extract price of flights"""
    price_divs = soup.find_all('div', attrs={'class': 'gws-flights-results__itinerary-price'})
    if price_divs is not None:
        prices = []
        for price_div in price_divs:
            prices.append(price_div.getText().strip())
            #prices = prices[1::2]
    else:
        raise Exception('No flight prices were found')  
    prices = prices[1::2]
    
    df = pd.DataFrame({
    "time_of_search": time_of_search,
    "origin" : origin,
    "destination" : city,
    "date" : date,
    "price": prices,
    "currency": "USD",
    "deptime": deptimes,
    "arrtime": arrtimes,
    "duration": durations,
    "carrier": carriers
    })
    
    return df

# %%
'''Setting up parameters'''
origin = 'SFO'
destination_list = ['MIA', 'LAX'] 
airlines = 'AA,DL,UA'

# %%
# First make empty dataframe objects // or else clear flight dataframes
for city in destination_list:
    df_city = 'df_' + city
    vars()[df_city] = pd.DataFrame()
    
    df_city_yest = 'df_'+city+'_yest'
    vars()[df_city_yest] = pd.DataFrame()

# %%
url = f'https://www.lme.com/en-GB/Metals/Non-ferrous/Nickel#tabIndex=0'
soup, driver = simple_get(url)

print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0a998139ba26> in <module>
#       1 url = f'https://www.lme.com/en-GB/Metals/Non-ferrous/Nickel#tabIndex=0'
#       2 soup, driver = simple_get(url)
# ----> 3 df = get_from_divs(soup, driver, city, origin)
#       4 print(df)
#
# NameError: name 'get_from_divs' is not defined

# %%
print(soup)
# Out:
# <html class="chrome chrome78 windows" lang="en-GB"><head>
# <meta content="width=device-width" name="viewport"/>
# <meta charset="utf-8"/>
# <title>London Metal Exchange: LME Nickel</title>
# <!--<![endif]-->
# <!--[if (lte IE 8)&!(IEMobile)]>
#     <script src="/assets/script/libs/armature/vendors/html5shiv.js"></script>
#     <script src="/assets/script/libs/armature/vendors/css3-mediaqueries.js"></script><![endif]-->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Current and historical Nickel prices, stocks and monthly averages." name="Description"/>
# <meta content="LME Nickel official prices, LME Nickel official prices curve, LME Nickel official opening stocks in tonnes, LME Nickel settlement exchange rates,LME Nickel current year summary, LME Nickel price graph, LME Nickel average prices, LME Nickel contract specs" name="Keywords"/>
# <meta content="index, follow" name="robots"/>
# <link href="https://www.lme.com/en-GB/Metals/Non-ferrous/Nickel" rel="canonical"/>
# <link href="/-/media/Images/Sitewide/Assets/Favicons/favicon.png" rel="shortcut icon"/>
# <meta content="637103723349170220" name="VIcurrentDateTime"/>
# <script src="/layouts/system/VisitorIdentification.js" type="text/javascript"></script>
# <link href="/bundles/css?v=HRKgV5yp4thJNvS82Hqlt6FOsb_A4t0Wv1L6BiMc-TY1" rel="stylesheet"/>
# <script>
#         (function () {
#             var html = document.getElementsByTagName('html')[0];
#             html.className = html.className.replace('no-js', '');
#         })();
#     </script>
# </head>
# <body>
# <div class="page-container">
# <div class="cookie-policy" data-arm-module="app/widget/CookieBanner" data-arm-options="cookiename: 'Cookieconsent', trackingScripts:[]" role="alertdialog">
# <div class="content-container">
# <h2>Cookie Policy</h2>
# <p>We use cookies for statistical and measurement purposes, to help improve our website and provide you with a better online experience. By clicking I accept you agree to such purposes. You can find out <a href="/en-GB/About/Legal/Cookie-policy">more</a> and <a href="/en-GB/About/Legal/Cookie-policy">withdraw</a> your consent at any time.</p>
# <button class="btn-secondary" role="button">I accept</button>
# </div>
# </div>
# <header class="masthead" data-arm-module="app/controllers/NavigationController" role="banner">
# <div class="content-container">
# <div class="grid-row">
# <div class="col-sm-6 col-md-12">
# <a class="company-logo" href="/"><img alt="LME" src="/-/media/Images/Sitewide/Assets/Logos/lme-logo.gif?h=70&amp;w=162&amp;la=en-GB&amp;hash=370A8AAD438C0A7591F76EF3F259F70490983F3D"/></a>
# <div class="utilities">
# <div class="top-menu">
# <ul class="desktop-only">
# <li><a href="/en-GB/Registration-page">Register</a></li>
# </ul>
# </div>
# <button aria-expanded="false" class="search-button handheld-only" type="button"><span class="icon-search"></span>Search</button>
# <div class="search-input" role="search">
# <form action="/Lme/SearchMvc/SearchResult" method="post"> <label class="accessible" for="headerSearch">Search</label>
# <input id="keywords" name="keywords" placeholder="Search" type="text"/>
# <input id="searchResultsUrl" name="searchResultsUrl" type="hidden" value="/en-GB/Search"/> <button data-outbound-input="Search Form - Search Button" role="button" type="submit"><span class="accessible">Search submit</span></button>
# </form> </div>
# <a class="login-button" href="/en-GB/Login"><span class="icon-padlock"></span> <span class="log-in-title">Logout</span> <span class="log-out-title">Login</span> </a>
# <button aria-expanded="false" class="nav-toggle handheld-only" type="button"><span class="icon-burger"></span>Menu</button>
# <div class="login-panel handheld-only">
# <a aria-expanded="true" class="btn-primary" href="/en-GB/Login">Login</a> <span>or</span>
# <a class="btn-secondary" href="/en-GB/Registration-page">Register</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <n
a></li>
# </ul>
# </li>
# <li class="sub-menu-link" data-arm-module="app/widget/NavMenu">
# <a aria-expanded="false" href="/en-GB/About/Contact-us">Contact us</a>
# <ul aria-hidden="true" class="tertiary-nav">
# <li class="back-link"><a href="/en-GB/About">About</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/About/Contact-us">Contact us</a></li>
# <li><a href="/en-GB/About/Contact-us/Offices">Offices</a></li>
# <li><a href="/en-GB/About/Contact-us/IT-Service-Desk">IT Service Desk</a></li>
# <li><a href="/en-GB/About/Contact-us/Visits">Visits</a></li>
# <li></li>
# </ul>
# </li>
# <li class="sub-menu-link" data-arm-module="app/widget/NavMenu">
# <a aria-expanded="false" href="/en-GB/About/Legal">Legal</a>
# <ul aria-hidden="true" class="tertiary-nav">
# <li class="back-link"><a href="/en-GB/About">About</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/About/Legal">Legal</a></li>
# <li><a href="/en-GB/About/Legal/Applicant-privacy-notice">Applicant privacy notice</a></li>
# <li><a href="/en-GB/About/Legal/Cookie-policy">Cookie policy</a></li>
# <li><a href="/en-GB/About/Legal/Email">Email</a></li>
# <li><a href="/en-GB/About/Legal/Online-store-terms">Online store terms</a></li>
# <li><a href="/en-GB/About/Legal/Privacy-statement">Privacy statement</a></li>
# <li><a href="/en-GB/About/Legal/Website-terms-and-conditions">Website terms and conditions</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="nav-item" data-arm-module="app/widget/NavMenu" data-arm-options="hasSubMenu: true">
# <a aria-expanded="false" class="parent-link" href="/en-GB/CN">中文</a>
# <ul aria-hidden="true" class="sub-nav">
# <li class="back-link"><a href="/en-GB/CN">中文</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/CN">中文</a></li>
# <li class="sub-menu-link" data-arm-module="app/widget/NavMenu">
# <a aria-expanded="false" href="/en-GB/CN/Access-the-market">进入市场交易</a>
# <ul aria-hidden="true" class="tertiary-nav">
# <li class="back-link"><a href="/en-GB/CN">中文</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/CN/Access-the-market">进入市场交易</a></li>
# </ul>
# </li>
# <li class="sub-menu-link" data-arm-module="app/widget/NavMenu">
# <a aria-expanded="false" href="/en-GB/CN/The-metals">金属</a>
# <ul aria-hidden="true" class="tertiary-nav">
# <li class="back-link"><a href="/en-GB/CN">中文</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/CN/The-metals">金属</a></li>
# </ul>
# </li>
# <li class="sub-menu-link" data-arm-module="app/widget/NavMenu">
# <a aria-expanded="false" href="/en-GB/CN/New-initiatives">新计划</a>
# <ul aria-hidden="true" class="tertiary-nav">
# <li class="back-link"><a href="/en-GB/CN">中文</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/CN/New-initiatives">新计划</a></li>
# </ul>
# </li>
# <li class="sub-menu-link" data-arm-module="app/widget/NavMenu">
# <a aria-expanded="false" href="/en-GB/CN/Physical-Market-Services">实物市场服务</a>
# <ul aria-hidden="true" class="tertiary-nav">
# <li class="back-link"><a href="/en-GB/CN">中文</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/CN/Physical-Market-Services">实物市场服务</a></li>
# </ul>
# </li>
# <li class="sub-menu-link" data-arm-module="app/widget/NavMenu">
# <a aria-expanded="false" href="/en-GB/CN/Reports-and-data">市场数据</a>
# <ul aria-hidden="true" class="tertiary-nav">
# <li class="back-link"><a href="/en-GB/CN">中文</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/CN/Reports-and-data">市场数据</a></li>
# </ul>
# </li>
# <li class="sub-menu-link" data-arm-module="app/widget/NavMenu">
# <a aria-expanded="false" href="/en-GB/CN/LME-Clear">LME Clear</a>
# <ul aria-hidden="true" class="tertiary-nav">
# <li class="back-link"><a href="/en-GB/CN">中文</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/CN/LME-Clear">LME Clear</a></li>
# </ul>
# </li>
# <li class="sub-menu-link" data-arm-module="app/widget/NavMenu">
# <a aria-expanded="false" href="/en-GB/CN/LME-Strategic-Pathway">LME业务发展战略路徑</a>
# <ul aria-hidden="true" class="tertiary-nav">
# <li class="back-link"><a href="/en-GB/CN">中文</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/CN/LME-Strategic-Pathway">LME业务发展战略路徑</a></li>
# </ul>
# </li>
# <li class="sub-menu-link" data-arm-module="app/widget/NavMenu">
# <a aria-expanded="false" href="/en-GB/CN/Training-and-events">中国相关培训及活动</a>
# <ul aria-hidden="true" class="tertiary-nav">
# <li class="back-link"><a href="/en-GB/CN">中文</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/CN/Training-and-events">中国相关培训及活动</a></li>
# </ul>
# </li>
# <li class="sub-menu-link" data-arm-module="app/widget/NavMenu">
# <a aria-expanded="false" href="/en-GB/CN/Chinese-resources">中文资源</a>
# <ul aria-hidden="true" class="tertiary-nav">
# <li class="back-link"><a href="/en-GB/CN">中文</a></li>
# <li class="sub-menu-heading"><a href="/en-GB/CN/Chinese-resources">中文资源</a></li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </nav>
# </header>
# <div class="content-container">
# <div class="grid-row">
# <div class="col-sm-6 col-md-6">
# <nav class="breadcrumb" role="navigation">
# <ul>
# <li>
# <a href="/en-GB" title="Home">Home</a>
# </li>
# <li>
# <a href="/en-GB/Metals" title="Metals">Metals</a>
# </li>
# <li>
# <a href="/en-GB/Metals/Non-ferrous" title="Non-ferrous">Non-ferrous</a>
# </li>
# <li>
#                                 Nickel
#                             </li>
# </ul>
# </nav>
# </div>
# <div class="col-sm-6 col-md-6">
# <div class="toggler shareToggler" data-arm-module="widget/core/Toggler">
# <a class="toggleButton" href="#"><span>Share</span></a>
# <div class="togglerContent">
# <div class="share" data-arm-module="widget/core/Share" data-arm-options="emailSubject:'Nickel', emailBody:'I thought you might find this interesting:  %0Dhttps://www.lme.com:443/en-GB/Metals/Non-ferrous/Nickel'">
# <ul>
# <li>
# <a class="icon-social-linkedin" data-arm-share="LinkedIn" href="https://www.linkedin.com/company/london-metal-exchange" title=""><span class="accessible"></span></a>
# </li>
# <li>
# <a class="icon-social-twitter" data-arm-share="Twitter" href="https://twitter.com/LME_news?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor" title=""><span class="accessible"></span></a>
# </li>
# <li>
# <a class="icon-social-google" data-arm-share="GooglePlus" href="https://plus.google.com/+LMEServicesHoffmanEstates" title=""><span class="accessible"></span></a>
# </li>
# <li>
# <a class="icon-social-facebook" data-arm-share="Facebook" href="https://www.facebook.com/pages/London-Metal-Exchange/103107189729466" title=""><span class="accessible"></span></a>
# </li>
# <li>
# <a class="icon-email-in-circle" data-arm-share="Email" href="mailto:support@lme.com" title=""><span class="accessible">support@lme.com</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-row">
# <div class="col-sm-6 col-md-12 col-lg-4">
# <nav class="subnav" role="navigation">
# <h2>Metals</h2>
# <ul>
# <li class="open section">
# <a aria-expanded="true" class="sectionTitle" href="/en-GB/Metals/Non-ferrous" title="London Metal Exchange: Non-ferrous">Non-ferrous</a>
# <ul aria-hidden="true" class="sectionContent">
# <li><a href="/en-GB/Metals/Non-ferrous/Aluminium">LME Aluminium</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Copper">LME Copper</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Zinc"> LME Zinc</a></li>
# <li><a class="selected" href="/en-GB/Metals/Non-ferrous/Nickel">LME Nickel</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Lead">LME Lead</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Tin">LME Tin</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Aluminium-Alloy">LME Aluminium Alloy</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/NASAAC">LME NASAAC</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Aluminium-Premiums">LME Aluminium Premiums</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Alumina">LME Alumina (CRU/Fastmarkets MB)</a></li>
# </ul>
# </li>
# <li><a href="/en-GB/Metals/Ferrous">Ferrous</a></li>
# <li><a href="/en-GB/Metals/Minor-metals">Minor metals</a></li>
# <li><a href="/en-GB/Metals/Precious-metals">Precious metals</a></li>
# </ul>
# </nav><div class="rich-text">
# <a href="/-/media/Files/Trading/New-initiatives/TAS/LME-Nickel-TAS-Factsheet.pdf?la=en-GB"><img alt="" src="/-/media/Images/Pages/Metals/Non-ferrous/LME-Nickel-TAS-banner.jpg?h=135&amp;w=360&amp;la=en-GB&amp;hash=69C58ED70841C02238748823CEABE6F59B7D0A8F" style="width: 360px; height: 135px;"/></a>
# </div>
# </div>
# <div class="col-sm-6 col-md-12 col-lg-8">
# <div class="content-row">
# <div class="rich-text">
# <h1>LME Nickel</h1>
# </div>
# </div>
# <div class="content-row">
# <div class="tabs" data-arm-module="app/widget/Tabs" data-arm-options="hashBang: true">
# <nav class="tabsNav">
# <ul role="tablist">
# <li class="tab" role="presentation">
# <a aria-controls="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-0" href="#50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-0" id="link-50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-0" role="tab" title="Trading &lt;br&gt;summary">Trading <br/>summary</a>
# </li>
# <li class="tab" role="presentation">
# <a aria-controls="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-1" href="#50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-1" id="link-50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-1" role="tab" title="Current year &lt;br&gt;summary">Current year <br/>summary</a>
# </li>
# <li class="tab" role="presentation">
# <a aria-controls="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-2" href="#50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-2" id="link-50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-3" role="tab" title="Price &lt;br&gt;graph">Price <br/>graph</a>
# </li>
# <li class="tab" role="presentation">
# <a aria-controls="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-3" href="#50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-3" id="link-50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-3" role="tab" title="Average&lt;br&gt; prices">Average<br/> prices</a>
# </li>
# <li class="tab" role="presentation">
# <a aria-controls="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-4" href="#50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-4" id="link-50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-4" role="tab" title="Contract &lt;br&gt;specs">Contract <br/>specs</a>
# </li>
# <li class="tab" role="presentation">
# <a aria-controls="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-5" href="#50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-5" id="link-50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-5" role="tab" title="Useful &lt;br&gt;links">Useful <br/>links</a>
# </li>
# <li class="tab" role="presentation">
# <a aria-controls="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-6" href="#50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-6" id="link-50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-6" role="tab" title="Trading &lt;br&gt;times">Trading <br/>times</a>
# </li>
# </ul>
# <div class="more" data-arm-module="widget/core/Toggler" data-arm-options="selectors: {button: 'button'}">
# <button><span class="accessible">Close</span></button>
# <ul></ul>
# </div>
# </nav>
# <script>
#                 function tabSetTabIndex(tabId, tabValue)
#                 {
#                     var tabSection = document.getElementById(tabId);
#                     if (tabSection.getElementsByClassName('tabIndex')[0] != undefined) {
#                         if (tabSection.getElementsByClassName('tabIndex')[0].type === "hidden") {
#                             tabSection.getElementsByClassName('tabIndex')[0].value = tabValue;
#                         }
#                     }
#                 }
#             </script>
# <section aria-labelledby="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-0" class="tabSection" id="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-0" role="tabpanel">
# <div class="tabContent">
# <div class="content-row grid-row">
# <div class="col-sm-6 col-md-12">
# <div class="delayed-date left">Data valid for  25 November 2019</div>
# </div>
# </div>
# <div class="content-row grid-row">
# <div class="col-sm-6 col-md-12">
# <h2>LME NICKEL OFFICIAL PRICES, US$ PER TONNE</h2>
# <div class="table-wrapper" data-arm-module="app/widget/ScrollableTable">
# <table>
# <thead>
# <tr>
# <th>Contract</th>
# <th>Bid (US$ / Tonne)</th>
# <th>Offer (US$ / Tonne)*</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Cash</td>
# <td>14560.00</td>
# <td>14570.00</td>
# </tr>
# <tr>
# <td>3-months</td>
# <td>14565.00</td>
# <td>14570.00</td>
# </tr>
# <tr>
# <td>Dec 20</td>
# <td>14625.00</td>
# <td>14675.00</td>
# </tr>
# <tr>
# <td>Dec 21</td>
# <td>14790.00</td>
# <td>14840.00</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="rich-text">
# <span style="font-size: 13px;">* LME Official Settlement Price = cash offer</span><p><br/>
# </p>
# </div><div class="rich-text">
# <h2>LME NICKEL OFFICIAL PRICES CURVE</h2>
# </div>
# <div class="content-row grid-row">
# <div class="col-sm-6 col-md-12">
# <h2></h2>
# <div data-arm-module="app/widget/Chart" data-arm-options="
#              selectors: {
# 					dataElement: '#b7875938-fea6-4779-9ffe-921358a565ed-chart'
# 				},
# 				chartOptions: {
# 					xAxis: {
# 						categories: [ 'Cash' ,'3' ,'D1' ,'D2' , ],
# 						title: {
# 							text: 'Contract Length'
# 						},
# 					},
# 					yAxis: {
# 	                    title: {
# 	                        text: 'US$ per tonne'
# 	                    },
# 	                    gridLineColor: '#E1E1E1'
# 	                },
# 					legend: {
# 						enabled: true
# 					}
#              }">
# <script id="b7875938-fea6-4779-9ffe-921358a565ed-chart" type="x">
#                     [{ 'name': 'Bid', 'data': [ 14560, 14565, 14625, 14790,  ] }, { 'name': 'Offer', 'data': [ 14570, 14570, 14675, 14840,  ] }]
#                 </script>
# </div>
# </div>
# </div>
# <h2>LME NICKEL OFFICIAL OPENING STOCKS IN TONNES</h2>
# <div class="table-wrapper" data-arm-module="app/widget/ScrollableTable">
# <table>
# <thead>
# <tr>
# <th>Stocks</th>
# <th>Amount</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Opening Stock</td>
# <td>66822</td>
# </tr>
# <tr>
# <td>Live Warrants</td>
# <td>44106</td>
# </tr>
# <tr>
# <td>Cancelled Warrants</td>
# <td>22716</td>
# </tr>
# </tbody>
# </table>
# </div>
# <h2>LME NICKEL SETTLEMENT EXCHANGE RATES</h2>
# <div class="table-wrapper" data-arm-module="app/widget/ScrollableTable">
# <table>
# <thead>
# <tr>
# <th>Currency</th>
# <th>Exchange rate</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>GB Pounds Sterling</td>
# <td>1.2874</td>
# </tr>
# <tr>
# <td>Japanese Yen</td>
# <td>108.88</td>
# </tr>
# <tr>
# <td>Euro</td>
# <td>1.1013</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script>
#                     tabSetTabIndex('50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-0', "0");
#                 </script>
# ...
#              selectors: {
# 					dataElement: '#b7875938-fea6-4779-9ffe-921358a565ed-chart'
# 				},
# 				chartOptions: {
# 					xAxis: {
# 						categories: [ '25-10-2019', '28-10-2019', '29-10-2019', '30-10-2019', '31-10-2019', '01-11-2019', '04-11-2019', '05-11-2019', '06-11-2019', '07-11-2019', '08-11-2019', '11-11-2019', '12-11-2019', '13-11-2019', '14-11-2019', '15-11-2019', '18-11-2019', '19-11-2019', '20-11-2019', '21-11-2019', '22-11-2019', '25-11-2019' ],
# 						title: {
# 							text: ''
# 						},
# 					},
# 					yAxis: {
# 	                    title: {
# 	                        text: ''
# 	                    },
# 	                    gridLineColor: '#E1E1E1'
# 	                },
# 					legend: {
# 						enabled: false
# 					}
#              }">
# <script id="b7875938-fea6-4779-9ffe-921358a565ed-chart" type="x">
#                     [
#                         {
#                             "name": "US$ per tonne",
#                             "data": [ 16880.00000, 16675.00000, 16670.00000, 16890.00000, 16830.00000, 16745.00000, 16585.00000, 16230.00000, 16380.00000, 16300.00000, 16180.00000, 15720.00000, 15490.00000, 15520.00000, 15350.00000, 14980.00000, 14750.00000, 14470.00000, 14305.00000, 14405.00000, 14375.00000, 14560.00000 ]
#                         }
#                     ]
#
#             </script>
# </div>
# </div>
# </div>
# <div class="form-container double-col">
# <form action="/Metals/Non-ferrous/Nickel" class="action-same-tab" method="post"><input name="__RequestVerificationToken" type="hidden" value="n95MZXJGVbIDqOPHi_MsNq6PwsgcdBLGl-CqV6KnNV6dGlXvjLvIv-o0ECss9ck9fUSIde3q-XgtRolNr1gxiYWL3lM1"/> <fieldset>
# <legend>Show historical data for</legend>
# <div class="grid-row">
# <div class="col-sm-6 col-md-6">
# <label class="form-label" for="DateRangeFrom">Date From</label>
# <div class="datePicker" data-arm-module="app/widget/DatePicker" data-arm-options="selectors:{ prev:'a.prev', next:'a.next', trigger:'a.datePickerTrigger' }, days:[ 'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat' ], months:[ 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December' ], availableDates: {from:'02-01-2007', to:'25-11-2019'}, date: '25-10-2019', format:'dd-M-yyyy'">
# <input id="DateRangeFrom" name="DateRangeFrom" type="Text" value="25/10/2019 12:00:00 AM"/>
# <a class="datePickerTrigger">Select date from current calendar year</a>
# <div class="datePickerOverlay">
# <a class="prev">Prev</a>
# <a class="next">Next</a>
# <div class="datePickerCalendar"></div>
# </div>
# </div>
# </div>
# <div class="col-sm-6 col-md-6">
# <label class="form-label" for="DateRangeTo">Date To</label>
# <div class="datePicker" data-arm-module="app/widget/DatePicker" data-arm-options="selectors:{ prev:'a.prev', next:'a.next', trigger:'a.datePickerTrigger' }, days:[ 'Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat' ], months:[ 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December' ], availableDates: {from:'02-01-2007', to:'25-11-2019'}, date: '25-11-2019', format:'dd-M-yyyy'">
# <input id="DateRangeTo" name="DateRangeTo" type="Text" value="25/11/2019 12:00:00 AM"/>
# <a class="datePickerTrigger">Select date from current calendar year</a>
# <div class="datePickerOverlay">
# <a class="prev">Prev</a>
# <a class="next">Next</a>
# <div class="datePickerCalendar"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="content-row grid-row">
# <div class="col-sm-6 col-md-6">
# <label class="form-label label-with-tooltip" for="ContractType">
#                             Contract Type<span></span>
# <div class="tooltip" data-arm-module="widget/core/Tooltip" data-arm-options="position: {horizontal: 'right'}">
# <a class="tooltipTrigger" href="#"><span class="accessible">More information</span>?</a>
# <div class="tooltipOverlay">
# <p>tooltip</p>
# </div>
# </div>
# </label>
# <div class="custom-select" data-arm-module="app/widget/SelectWithMenu" data-arm-options="selectors: {trigger: 'div.customSelectMenu'}">
# <select id="ContractType" name="ContractType"><option selected="selected" value="Cash Buyer">Cash Buyer</option>
# <option value="Cash Seller &amp; Settlement">Cash Seller &amp; Settlement</option>
# <option value="3-months Buyer">3-months Buyer</option>
# <option value="3-months Seller">3-months Seller</option>
# <option value="15-months Buyer">15-months Buyer</option>
# <option value="15-months Seller">15-months Seller</option>
# <option value="27-months Buyer">27-months Buyer</option>
# <option value="Dec 1 Buyer">Dec 1 Buyer</option>
# <option value="Dec 1 Seller">Dec 1 Seller</option>
# <option value="Dec 2 Buyer">Dec 2 Buyer</option>
# <option value="Dec 2 Seller">Dec 2 Seller</option>
# <option value="Dec 3 Buyer">Dec 3 Buyer</option>
# <option value="Dec 3 Seller">Dec 3 Seller</option>
# </select>
# </div>
# </div>
# </div>
# <div class="content-row grid-row">
# <div class="col-sm-6 col-md-12">
# <button class="btn-primary floatR" role="button" type="submit">Update</button>
# </div>
# </div>
# </fieldset>
# </form> </div>
# </div>
# </div>
# </div>
# </section>
# <script>
#                     tabSetTabIndex('50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-2', '2');
#                 </script>
# <section aria-labelledby="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-3" class="tabSection" id="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-3" role="tabpanel">
# <div class="tabContent">
# <div class="login">
# <h1></h1>
# <p>Login or register to view LME Nickel prices and monthly averages.</p>
# <div class="form-container" data-arm-module="app/widget/ActivationForm">
# <form action="/Metals/Non-ferrous/Nickel" data-arm-module="widget/form/ValidationForm" method="post"><input name="__RequestVerificationToken" type="hidden" value="wuCJV0pYzbQCn7j4fMin9_NnLAlIZ0deCa6kJEliCGJDFXW3zYvrv-LE4xEtPj6ehVq9nSICsyPX86SJe4kUKby6R681"/> <fieldset>
# <legend></legend>
# <div class="content-row grid-row" data-arm-module="widget/form/Question" data-arm-validation-rules="required, email">
# <div class="col-sm-6 col-md-5">
# <label class="form-label" for="EmailAddress">Email address</label>
# </div>
# <div class="col-sm-6 col-md-6" data-arm-module="widget/form/Textbox">
# <input id="emailAddress" name="EmailAddress" placeholder="Enter text here" type="text" value=""/>
# <p class="error-state" data-arm-validation-error="required">Field cannot be empty</p>
# <p class="error-state" data-arm-validation-error="email">Please enter a valid email address</p>
# </div>
# </div>
# <div class="content-row grid-row" data-arm-module="widget/form/Question" data-arm-validation-rules="required, minChars(8), password">
# <div class="col-sm-6 col-md-5">
# <label class="form-label" for="password">Password</label>
# </div>
# <div class="col-sm-6 col-md-6" data-arm-module="widget/form/Textbox">
# <input id="password" name="Password" placeholder="Enter text here" type="password"/>
# <p class="error-state" data-arm-validation-error="required">Field cannot be empty</p>
# <p class="error-state" data-arm-validation-error="minChars">Your new password must contain eight or more characters and at least one number</p>
# </div>
# </div>
# <div class="content-row grid-row">
# <div class="col-sm-6 col-md-5"></div>
# <div class="col-sm-6 col-md-6">
# <div class="checkboxContainer custom-checkbox" data-arm-module="widget/form/Checkbox">
# <input id="remember" name="RememberMe" type="checkbox" value="true"/><input name="RememberMe" type="hidden" value="false"/>
# <label for="remember">Remember me</label>
# </div>
# <button class="btn-primary" data-outbound-input="Login Form - Login Button" type="submit">Login</button>
# </div>
# </div>
# </fieldset>
# </form>
# <div class="grid-row">
# <div class="col-sm-6 col-md-5"></div>
# <div class="col-sm-6 col-md-6">
# <ul class="link-list">
# <li>
# <a data-outbound-link="Forgotten Password" href="/en-GB/Forgotten-Password">Forgotten password</a>
# </li>
# <li>
# <a data-outbound-link="Regiter for additional access" href="/en-GB/Registration-page">Register</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div> </div>
# </section>
# <script>
#                     tabSetTabIndex('50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-3', '3');
#                 </script>
# <section aria-labelledby="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-4" class="tabSection" id="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-4" role="tabpanel">
# <div class="tabContent">
# <div class="content-row grid-row">
# <div class="col-sm-6 col-md-12">
# <div class="rich-text">
# <h2>LME Nickel Contract specifications</h2>
# <p>Every metal traded on the LME must conform to strict specifications regarding quality, lot size and shape.</p>
# <p>Each LME tradeable contract is likewise governed by rules covering (but not limited to) prompt dates, settlement terms, traded and cleared currencies and minimum tick size. <br/>
# <br/>
# <strong>LME Nickel contract specifications </strong></p>
# <ul>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/Physical">Physical</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/Futures">Futures</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/Options">Options</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/TAPOs">TAPOs</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/Monthly-Average-Futures">Monthly Average Futures</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/Trade-at-settlement">Trade at settlement</a><br/>
# <br/>
# </li>
# </ul>
# <p>
# This is a summary of the contract specifications. For full contract specification details, please refer to the <a href="/en-GB/About/Market-Regulation/Rules/Rulebook">LME Rulebook</a> and for other information, please refer to our <a href="/en-GB/About/Legal">disclaimer</a> page. </p>
# <p style="text-align: left;">Note that all contracts are subject to the LME’s <a href="/en-GB/About/Market-Regulation/Rules">rules and regulations</a> and <a href="/en-GB/LME-Clear/Risk-management/Margin-information">LME Clear span margining</a>.</p>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script>
#                     tabSetTabIndex('50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-4', '4');
#                 </script>
# <section aria-labelledby="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-5" class="tabSection" id="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-5" role="tabpanel">
# <div class="tabContent">
# <div class="content-row grid-row">
# <div class="col-sm-6 col-md-12">
# <div class="rich-text">
# <h2>Useful links</h2>
# <ul>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/Monthly-overview">Monthly overview</a></li>
# <li><a href="/en-GB/Market-Data/Reports-and-data">Reports overview</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/Monthly-overview"></a><a href="/en-GB/Trading/Brands/Approved-brands">Approved brands</a></li>
# <li><a href="/en-GB/Trading/Brands/Approved-brands"></a><a href="/en-GB/Trading/Brands/Listing-process">Listing process</a></li>
# <li><a href="/en-GB/Trading/Brands/Listing-process"></a><a href="/en-GB/Trading/Warehousing/LME-warehouse-network">Warehouse locations</a></li>
# <li><a href="/en-GB/Trading/Warehousing/LME-warehouse-network"></a><a href="/en-GB/Trading/Warehousing/Approved-warehouses">Approved warehouses (requires additional access)</a></li>
# <li><a href="/en-GB/Trading/Warehousing/Approved-warehouses"></a><a href="/en-GB/About/Corporate-information/Committees/Nickel-Committee">Nickel Committee</a></li>
# <li><a href="/-/media/Files/Trading/New-initiatives/TAS/LME-Nickel-TAS-Factsheet.pdf?la=en-GB">LME Nickel TAS Factsheet (PDF)</a></li>
# <li><a href="/-/media/Files/Education-and-events/Online-resources/Brochures/Non-ferrous/LME-Nickel-factsheet.pdf?la=en-GB">LME Nickel Factsheet (PDF)</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script>
#                     tabSetTabIndex('50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-5', '5');
#                 </script>
# <section aria-labelledby="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-6" class="tabSection" id="50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-6" role="tabpanel">
# <div class="tabContent">
# <div class="content-row grid-row">
# <div class="col-sm-6 col-md-12">
# <div class="rich-text">
# <p>LME Nickel can be traded on LMEselect from 01.00 - 19.00 London time,  24 hours a day on the inter-office telephone market and during the below times on the Ring:</p>
# </div>
# </div>
# </div>
# <div class="content-row grid-row">
# <div class="col-sm-6 col-md-6">
# <table class="ring-times">
# <thead>
# <tr>
# <th colspan="2" scope="col">Ring trading time - First session (UK)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th scope="row">1st Ring</th>
# <td>12:15 - 12:20</td>
# </tr>
# <tr>
# <th scope="row">2nd Ring</th>
# <td>13:00 - 13:05</td>
# </tr>
# <tr>
# <th scope="row">Kerb Trading*</th>
# <td>13:25 - 13:35</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="col-sm-6 col-md-6">
# <table class="ring-times">
# <thead>
# <tr>
# <th colspan="2" scope="col">Ring trading time - Second session (UK)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th scope="row">3rd Ring</th>
# <td>15:25 - 15:30</td>
# </tr>
# <tr>
# <th scope="row">Kerb Trading**</th>
# <td>15:50 - 17:00</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div><div class="content-row grid-row">
# <div class="col-sm-6 col-md-6">
# <div class="rich-text">
# <span style="font-size: 13px;">* All metals can be traded during the 13:25 - 13:35 Kerb trading session.</span><p><br/>
# </p>
# </div>
# </div>
# <div class="col-sm-6 col-md-6">
# <div class="rich-text">
# <span style="font-size: 13px;">** Whilst Kerb trading takes place from 15:50 - 17:00 LME Nickel ceases trading at 17:00.</span>
# <p> </p>
# </div>
# </div>
# </div> </div>
# </section>
# <script>
#                     tabSetTabIndex('50d985f3-e89f-4fda-894a-cadccc5d0f28-tab-6', '6');
#                 </script>
# </div>
# </div>
# <div class="grid-row">
# <div class="col-sm-6 col-md-6">
# <div class="content-row">
# <div class="rich-text">
# <h2>Useful links</h2>
# <ul class="link-list">
# <li><a href="/-/media/Files/Education-and-events/Online-resources/Brochures/Non-ferrous/LME-Nickel-factsheet.pdf?la=en-GB">LME Nickel Factsheet (PDF)</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/Physical">Physical contract specifications</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/Futures">Futures contract specifications</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/Options">Options contract specifications</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/TAPOs">TAPOs contract specifications</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel/Monthly-Average-Futures">Monthly Average Futures contract specifications</a></li>
# <li><a href="/en-GB/About/Corporate-information/Committees/Nickel-Committee">Nickel Committee</a></li>
# <li><a href="/en-GB/Trading/Trading-venues/Trading-times">Trading times</a></li>
# <li><a href="/en-GB/Metals/Non-ferrous/Nickel">LME Nickel overview</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-sm-6 col-md-6">
# <div class="content-row">
# <div class="rich-text">
# <h2>Contact Us</h2>
# <p>For further information please <a href="/About/Contact-us">get in touch</a>.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer class="footer" role="contentinfo">
# <div class="footerContent">
# <div class="row">
# <div class="colLg-12">
# <ul class="footerNavigation" role="navigation">
# <li>
# <a href="/en-GB">Home</a>
# </li>
# <li>
# <a href="/en-GB/About/Contact-us">Contact Us</a>
# </li>
# <li>
# </li>
# <li>
# <a href="/en-GB/About/Legal">Legal</a>
# </li>
# <li>
# <a href="/en-GB/About/Legal/Privacy-statement">Privacy statement</a>
# </li>
# <li>
# <a href="/en-GB/About">About</a>
# </li>
# <li>
# <a href=""></a>
# </li>
# </ul>
# <div class="legal">
# <p>© 2019 The London Metal Exchange - an HKEX Company. All rights reserved.</p>
# </div>
# <ul class="socialLinks">
# <li>
# <a class="icon-social-linkedin" href="https://www.linkedin.com/company/london-metal-exchange" target="_blank" title="LinkedIn"> <span class="accessible">LinkedIn</span>
# </a>
# </li>
# <li>
# <a class="icon-social-twitter" href="https://twitter.com/LME_news" target="_blank" title="Twitter"> <span class="accessible">Twitter</span>
# </a>
# </li>
# <li>
# <a class="icon-social-vimeo" href="https://vimeo.com/londonmetalexchange" target="_blank" title="Vimeo"> <span class="accessible">Vimeo</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# <script src="/bundles/js?v=BNgD2MHJUNI9SUjqV0w3nuRh9I6zc11sW6DE9L5tJOg1"></script>
# </div>
# </body></html>

# %%
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome("chromedriver")
driver.implicitly_wait(20)
driver.get(url)
soup = BeautifulSoup(driver.page_source, 'lxml')
'''
driver.implicitly_wait(20)
driver.get(url)
soup = BeautifulSoup(driver.page_source, 'lxml')
if type(driver) == webdriver.chrome.webdriver.WebDriver:
    return soup, driver
else:
    return None

'''
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-17-80848054338d> in <module>
#       1 chrome_options = webdriver.ChromeOptions()
# ----> 2 driver = webdriver.Chrome("chromedriver")
#       3 driver.implicitly_wait(20)
#       4 driver.get(url)
#       5 soup = BeautifulSoup(driver.page_source, 'lxml')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 79

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    beautifulsoup object.
    """
    try:
        #with closing(get(url, stream=True)) as resp:
        chrome_options = webdriver.ChromeOptions()
        driver = webdriver.Chrome("chromedriver")
        driver.implicitly_wait(20)
        driver.get(url)
        soup = BeautifulSoup(driver.page_source, 'lxml')
        if type(driver) == webdriver.chrome.webdriver.WebDriver:
            return soup, driver
        else:
            return None

    except Exception:
        # MAIN ERROR? 
        #log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        print('Error retrieving contents at {}'.format(url))
        return None

# %%
            # Save yesterday's dataframe as a csv
            vars()[df_city_yest] = vars()[df_city]
            vars()[df_city_yest].to_csv(df_city_yest+'.csv', index=False)
            
            # Save today's updated dataframe as a csv / Replace yesterday's
            vars()[df_city] = vars()[df_city].append(df)
            vars()[df_city].to_csv(df_city+'.csv', index=False)

# %% [markdown]
# ### Testing
