# %%
import pandas as pd
from matplotlib import pyplot as plt
import re

from statsmodels.tsa.stattools import adfuller

from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

import numpy as np
import fbprophet
from fbprophet import Prophet
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
from pylab import rcParams
import datetime

import logging

from sklearn.metrics import mean_absolute_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from sklearn.linear_model import LinearRegression

from sklearn import metrics

from sklearn.model_selection import ParameterGrid
from sklearn.linear_model import Ridge


logging.getLogger().setLevel(logging.ERROR)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.Series(timeseries).rolling(window=4).mean()
    #pd.rolling_mean(timeseries, window=12)
    rolstd =  pd.Series(timeseries).rolling(window=4).std()
#Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    # dftest = adfuller(timeseries, autolag='AIC')
    dftest = adfuller(timeseries)
    
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
LME_futures = pd.read_excel('forecasting_raw_data/LME Futures Price.xlsx')
LME_futures = LME_futures.iloc[3:, 1:]
#LME_futures['Unnamed: 1'] = pd.datetime(LME_futures['Unnamed: 1'])
LME_futures.index = LME_futures['Unnamed: 1']



LME_futures = LME_futures.iloc[:, 1:]
LME_futures = LME_futures[LME_futures.index.year>=2000]
LME_futures.isnull().sum()
LME = LME_futures.iloc[:, 0]
LME = LME.astype(float)
LME = LME.resample('B').mean()

# %% [markdown]
# ### Note About Preprocessing:
#
# #### For differenced data, to unscale, must concatenate the LAST VALUE OF THE ORIGINAL Y OF THE TRAINING SET, with the new PREDICTED SERIES OF SCALED_YHAT to use CUMSUM()

# %%
def preprocess(series, window_setting):
    moving_avg =series.ewm(span=4, min_periods=4, adjust=True).mean().shift()
    moving_avg_diff = series-moving_avg
    return moving_avg_diff

# %% [markdown]
# #### Take Out Trend
#
# Pandas time series resampling options
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html

# %%
window_setting= 14

LME_stationary = preprocess(LME, window_setting)

#LME_log = np.log(LME)
LME_log = LME
rcParams['figure.figsize'] = 9, 6



plt.plot(LME_stationary)

test_stationarity(LME_stationary.dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -25.320119
# p-value                           0.000000
# #Lags Used                        4.000000
# Number of Observations Used    5147.000000
# Critical Value (1%)              -3.431621
# Critical Value (5%)              -2.862102
# Critical Value (10%)             -2.567069
# dtype: float64

# %%
LME_stationary = preprocess(LME, window_setting)

list_one = list(LME_stationary.index)
list_two = list(LME_stationary)
df = pd.DataFrame(list(zip(list_one, list_two)), columns = ['ds', 'lag0'])
                



df['lag1'] = df.lag0.shift(periods=10)
df['lag2'] = df.lag0.shift(periods=20)
df['lag3'] = df.lag0.shift(periods=30)
df['lag4'] = df.lag0.shift(periods=40)
df['lag5'] = df.lag0.shift(periods=50)

df['lag6'] = df.lag0.shift(periods=60)
df['lag7'] = df.lag0.shift(periods=70)
df['lag8'] = df.lag0.shift(periods=80)
df['lag9'] = df.lag0.shift(periods=90)
df['lag10'] = df.lag0.shift(periods=100)


'''
original_tail = train_set['A'].tail(window_setting)


for item in test_set:
    ewm_rolling_avg = original_tail.ewm(span=4, min_periods=4, adjust=True).mean()
    ewm_rolling_avg = ewm_rolling_avg.reset_index().iloc[:,1]
    ewm_rolling_avg = ewm_rolling_avg[len(original_tail)-1]
    
    # original_tail.tail(4).ewm(span=4, adjust=False).mean()[window_setting-1]
# 2000-05-31   57.378875
# 2000-06-01  -44.264758
# 2000-06-02   -8.378604
# 2000-06-05    6.293226
# 2000-06-06   92.766770
# 2000-06-07  184.579112
# 2000-06-08   90.650912
# 2000-06-09  189.362110
# 2000-06-12   62.581635
# 2000-06-13   40.541917
# 2000-06-14  -19.677595
# 2000-06-15   95.194242
# 2000-06-16  194.114225
# 2000-06-19  235.465696
# 2000-06-20  162.277351
# 2000-06-21  219.365556
# 2000-06-22  204.618641
# 2000-06-23  242.770797
# 2000-06-26  289.162202
# 2000-06-27    6.997124
# 2000-06-28  187.198271
# 2000-06-29  522.318917
# 2000-06-30  518.391273
# 2000-07-03  256.034718
# 2000-07-04   86.620817
# 2000-07-05   78.972488
# 2000-07-06  277.383491
# ...                ...
# 2019-08-27   45.360810
# 2019-08-28   49.716486
# 2019-08-29 -214.170108
# 2019-08-30  -79.752065
# 2019-09-02  -81.601239
# 2019-09-03  -88.960743
# 2019-09-04 -107.876446
# 2019-09-05 -289.725868
# 2019-09-06 -173.835521
# 2019-09-09 -104.301312
# 2019-09-10 -342.580787
# 2019-09-11 -187.048472
# 2019-09-12 -187.229083
# 2019-09-13  -10.337450
# 2019-09-16  -26.702470
# 2019-09-17 -217.521482
# 2019-09-18 -162.012889
# 2019-09-19 -122.207734
# 2019-09-20  -11.824640
# 2019-09-23   -7.094784
# 2019-09-24 -146.756870
# 2019-09-25 -177.554122
# 2019-09-26 -276.032473
# 2019-09-27  -15.619484
# 2019-09-30 -135.371690
# 2019-10-01   71.776986
# 2019-10-02  289.066191
# 2019-10-03  211.439715
# 2019-10-04  -67.136171
# 2019-10-07  -68.281703
#
# [5052 rows x 11 columns]

# %%
df['y'] = df['lag0'].shift(-261)
df = df.dropna()
df.head()
# Out:
#                    lag0        lag1        lag2        lag3        lag4  \
# ds
# 2000-05-26  -144.206151  184.435198  224.969655 -264.678687  -29.932127
# 2000-05-29    33.476310  278.661119  134.981793 -102.057212 -192.959276
# 2000-05-30 -1259.914214  387.196671   60.989076  -31.234327 -190.775566
# 2000-05-31  -820.948529  217.318003  -98.406554  -98.740596  -93.465340
# 2000-06-01  -157.569117  241.390802 -142.043933  -99.244358 -127.079204
#
#                   lag5        lag6        lag7        lag8        lag9  \
# ds
# 2000-05-26  220.031136   70.210199  101.430091  242.770797  189.362110
# 2000-05-29  212.018682  157.126119  210.858054  289.162202   62.581635
# 2000-05-30 -117.788791   39.275671  371.514832    6.997124   40.541917
# 2000-05-31  -75.673275  -16.434597  182.908898  187.198271  -19.677595
# 2000-06-01   94.596035  155.139242   -5.254661  522.318917   95.194242
#
#                  lag10           y
# ds
# 2000-05-26 -121.759191   39.934012
# 2000-05-29 -110.948994  -81.039593
# 2000-05-30 -140.397489 -118.623756
# 2000-05-31   57.378875 -151.174253
# 2000-06-01  -44.264758 -131.704552

# %%
# Sanity check
df[df.index=='2001-05-28']
# Out:
#                  lag0        lag1       lag2       lag3       lag4  \
# ds
# 2001-05-28  39.934012  224.953182  44.866161  45.971666  80.868034
#
#                   lag5       lag6        lag7       lag8      lag9      lag10  \
# ds
# 2001-05-28  110.563098 -97.114547 -226.344229 -62.247629 -6.600192  73.007052
#
#                      y
# ds
# 2001-05-28  114.811105

# %% [markdown]
# ## Linear Regression
#
# IMPORTANT NOTE TO SELF:
# For smoothing using moving average, must RESCALE output predictions using inputs!!
#
# SECOND NOTE 2 SELF:
# for training/fitting/testing set...
#
# MODEL FOR DEPLOYMENT:
# Train a model that uses values from a year ago or OLDER to predict values and rescale according to moving averages...

# %%
X = df[['lag0', 'lag1', 'lag2', 'lag3', 'lag4', 'lag5', 'lag6', 'lag7', 'lag8', 'lag9', 'lag10']]
#'lag11', 'lag12', 'lag13', 'lag14', 'lag15']]
y= df['y']

# %%
X_test = X.loc['2017-10-31':  ,:]
y_test = y['2017-10-31':]

y_train = y[:'2017-10-30']
X_train = X.loc[:'2017-10-30', :]
y_test.head()
# Out:
# ds
# 2017-10-31   -392.753241
# 2017-11-01     57.348055
# 2017-11-02    176.408833
# 2017-11-03    -79.154700
# 2017-11-06    -23.492820
# Name: y, dtype: float64

# %%
## Weekly train/test set dates

#X_train = X.loc[:'2018-10-07', :]
#y_train = y[:'2018-10-07']

## Daily training dates
#X_train = X.loc[:'2018-10-12', :]
#y_train = y[:'2018-10-12']

## Monthly training dates
#X_train = X.loc[:'2018-10-14', :]
#y_train = y[:'2018-10-14']

# %%
regressor = LinearRegression()

regressor.fit(X_train, y_train)
print(regressor.coef_)

y_pred = regressor.predict(X_test)
y_pred = pd.Series(y_pred)
y_pred.index = y_test.index
# y_pred = y_pred.reindex(X_test.index)
# Out:
# [-0.0332991  -0.00034226 -0.02077587  0.04575941 -0.03151165  0.004645
#   0.00437201 -0.00633268  0.0090019  -0.03102587 -0.00566484]

# %% [markdown]
# ## Back to Scale before Performance Analysis

# %% [markdown]
# y_train range:
# #### 2000 to 2017-10-30
#
#
# y_pred and y_test range:
# #### 2017-10-31 to 2018-10-13

# %%
# NOTE/IMPORTANT: MUST SHIFT BACK

LME_shifted = LME.shift(-261).dropna()


# Extracts last few values from the original unscaled y values

original_tail = LME_shifted.loc[:'2017-10-30']

unscaled = []

for key, item in y_pred.items():
    rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
    unscaled_result = item+rolling_avg

    original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
    unscaled.append(float(unscaled_result))

unscaled = pd.Series(unscaled)
unscaled.index = y_test.index


original_tail = LME_shifted.loc[:'2017-10-30']

original_y = []

for key, item in y_test.items():
    rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
    unscaled_y = item+rolling_avg
    original_tail = original_tail.append(pd.Series([unscaled_y]))

    original_y.append(float(unscaled_y))


original_y = pd.Series(original_y)
original_y.index = y_test.index

# %%
original_y.head()
# Out:
# ds
# 2017-10-31    11425.5
# 2017-11-01    11718.5
# 2017-11-02    11860.5
# 2017-11-03    11675.5
# 2017-11-06    11699.5
# dtype: float64

# %%
# Sanity check for unscaling! 

LME_shifted[LME_shifted.index=='2017-10-31']
# Out:
# Unnamed: 1
# 2017-10-31    11425.5
# Freq: B, Name: Cash Price ($/MT), dtype: float64

# %%
plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('EWM Linear Regression Prediction (weeks), ten lags', fontsize=15)

plt.show()

results = pd.DataFrame({'y_test': original_y, 'y_pred_unscaled': unscaled})
results['error'] = results['y_test'] - results['y_pred_unscaled']

results.head()

print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))
# Out:
# Mean Absolute Error: 1628.838427973122
# Mean Squared Error: 5870158.344933583
# Root Mean Squared Error: 2422.840965671

# %% [markdown]
# # Other Kinds of Regression
#
# Grid Search for RIDGE Regression

# %%
from sklearn import linear_model

params1= ParameterGrid({'alpha' : [ .00001 ,.0001, .001, .01, .1, 1]
                            })

cv_results = {}

unscaled = []

for params in params1:

    regressor = linear_model.Lasso(**params, random_state=1)

    print()
    print(params)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)

    original_tail = LME_shifted.loc[:'2017-10-30']

    unscaled = []

    for key, item in y_pred.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        unscaled_result = item+rolling_avg

        original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
        unscaled.append(float(unscaled_result))

    unscaled = pd.Series(unscaled)
    unscaled.index = y_test.index

    original_tail = LME_shifted.loc[:'2017-10-30']

    original_y = []

    for key, item in y_test.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        unscaled_y = item+rolling_avg
        original_tail = original_tail.append(pd.Series([unscaled_y]))

        original_y.append(float(unscaled_y))


    original_y = pd.Series(original_y)
    original_y.index = y_test.index
    
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters

    '''Calculates maximum test accuracy value and parameters'''
    #min_test_accuracy, min_parameters = 0, 0
    min_test_accuracy = 3000
    for key, value in cv_results.items():
        if value < min_test_accuracy:
            min_test_accuracy = value
            min_parameters = key
            
print()
print('Ridge CV Results')
for key, value in cv_results.items():
    print(key, value)

print()
print('Best Results:')
if min_test_accuracy==3000:
    print('error')
else:
    print('Minimum Test Accuracy: ', min_test_accuracy)
print('Best Parameters: ', min_parameters)
print()

plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('LASSO Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# {'alpha': 1e-05}
# Mean Absolute Error: 1628.8384278057374
# Mean Squared Error: 5870158.344211686
# Root Mean Squared Error: 2422.8409655220225
#
# {'alpha': 0.0001}
# Mean Absolute Error: 1628.8384262992038
# Mean Squared Error: 5870158.33771353
# Root Mean Squared Error: 2422.8409641810026
#
# {'alpha': 0.001}
# Mean Absolute Error: 1628.8384112135918
# Mean Squared Error: 5870158.272651873
# Root Mean Squared Error: 2422.8409507542738
#
# {'alpha': 0.01}
# Mean Absolute Error: 1628.8382604941394
# Mean Squared Error: 5870157.622744068
# Root Mean Squared Error: 2422.840816633249
#
# {'alpha': 0.1}
# Mean Absolute Error: 1628.836746558684
# Mean Squared Error: 5870151.096620804
# Root Mean Squared Error: 2422.839469841286
#
# {'alpha': 1}
# Mean Absolute Error: 1628.8217512274339
# Mean Squared Error: 5870086.463510745
# Root Mean Squared Error: 2422.8261315064988
#
# Ridge CV Results
# {'alpha': 1e-05} 1628.8384278057374
# {'alpha': 0.0001} 1628.8384262992038
# {'alpha': 0.001} 1628.8384112135918
# {'alpha': 0.01} 1628.8382604941394
# {'alpha': 0.1} 1628.836746558684
# {'alpha': 1} 1628.8217512274339
#
# Best Results:
# Minimum Test Accuracy:  1628.8217512274339
# Best Parameters:  {'alpha': 1}

# %%
from sklearn.ensemble import AdaBoostRegressor

params1= ParameterGrid({'n_estimators' : [50, 100, 150, 200, 250, 300, 350, 400, 450],
                            'learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3]})

cv_results = {}

for params in params1:

    regressor = AdaBoostRegressor(**params, random_state=1)

    print()
    print(params)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)


    original_tail = LME_shifted.loc[:'2017-10-30']

    unscaled = []

    for key, item in y_pred.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        unscaled_result = item+rolling_avg

        original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
        unscaled.append(float(unscaled_result))

    unscaled = pd.Series(unscaled)
    unscaled.index = y_test.index

    original_tail = LME_shifted.loc[:'2017-10-30']

    original_y = []

    for key, item in y_test.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        unscaled_y = item+rolling_avg
        original_tail = original_tail.append(pd.Series([unscaled_y]))

        original_y.append(float(unscaled_y))


    original_y = pd.Series(original_y)
    original_y.index = y_test.index
    
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters

    '''Calculates maximum test accuracy value and parameters'''
    #min_test_accuracy, min_parameters = 0, 0
    min_test_accuracy = 3000
    for key, value in cv_results.items():
        if value < min_test_accuracy:
            min_test_accuracy = value
            min_parameters = key
            
print()
print('Adaboost CV Results')
for key, value in cv_results.items():
    print(key, value)

print()
print('Best Results:')
if min_test_accuracy==3000:
    print('error')
else:
    print('Minimum Test Accuracy: ', min_test_accuracy)
print('Best Parameters: ', min_parameters)
print()

plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Adaboost Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# {'learning_rate': 0.0001, 'n_estimators': 50}
# Mean Absolute Error: 1496.8055961507691
# Mean Squared Error: 5085936.026040184
# Root Mean Squared Error: 2255.2019922925274
#
# {'learning_rate': 0.0001, 'n_estimators': 100}
# Mean Absolute Error: 1448.23508614005
# Mean Squared Error: 4757567.054542858
# Root Mean Squared Error: 2181.1847823013204
#
# {'learning_rate': 0.0001, 'n_estimators': 150}
# Mean Absolute Error: 1439.3960497285411
# Mean Squared Error: 4701644.569020631
# Root Mean Squared Error: 2168.3275972556894
#
# {'learning_rate': 0.0001, 'n_estimators': 200}
# Mean Absolute Error: 1432.8543506565334
# Mean Squared Error: 4653937.55948044
# Root Mean Squared Error: 2157.298671830222
#
# {'learning_rate': 0.0001, 'n_estimators': 250}
# Mean Absolute Error: 1428.974472567661
# Mean Squared Error: 4625787.399281858
# Root Mean Squared Error: 2150.764375584145
#
# {'learning_rate': 0.0001, 'n_estimators': 300}
# Mean Absolute Error: 1439.6423367501961
# Mean Squared Error: 4700036.568026485
# Root Mean Squared Error: 2167.9567726378873
#
# {'learning_rate': 0.0001, 'n_estimators': 350}
# Mean Absolute Error: 1437.9318618490886
# Mean Squared Error: 4686694.031451359
# Root Mean Squared Error: 2164.8773709961865
#
# {'learning_rate': 0.0001, 'n_estimators': 400}
# Mean Absolute Error: 1447.5294275911488
# Mean Squared Error: 4749734.9789911285
# Root Mean Squared Error: 2179.3886709330045
#
# {'learning_rate': 0.0001, 'n_estimators': 450}
# Mean Absolute Error: 1449.9082957034102
# Mean Squared Error: 4765025.276012342
# Root Mean Squared Error: 2182.8937848673127
#
# {'learning_rate': 0.001, 'n_estimators': 50}
# Mean Absolute Error: 1463.3293438746791
# Mean Squared Error: 4842410.721838358
# Root Mean Squared Error: 2200.5478231200427
#
# {'learning_rate': 0.001, 'n_estimators': 100}
# Mean Absolute Error: 1446.5399940024524
# Mean Squared Error: 4724596.173485237
# Root Mean Squared Error: 2173.613621020359
#
# {'learning_rate': 0.001, 'n_estimators': 150}
# Mean Absolute Error: 1459.5184551022091
# Mean Squared Error: 4821504.939070974
# Root Mean Squared Error: 2195.7925537424917
#
# {'learning_rate': 0.001, 'n_estimators': 200}
# Mean Absolute Error: 1445.0213224916608
# Mean Squared Error: 4722091.398788036
# Root Mean Squared Error: 2173.037367094279
#
# {'learning_rate': 0.001, 'n_estimators': 250}
# Mean Absolute Error: 1430.4625315747328
# Mean Squared Error: 4620399.031985877
# Root Mean Squared Error: 2149.511347256831
#
# {'learning_rate': 0.001, 'n_estimators': 300}

# %%
from sklearn.ensemble import RandomForestRegressor

params1= ParameterGrid({'n_estimators' : [50, 100, 150, 200, 250, 300, 350, 400, 450],
                            'min_samples_leaf': [ .15,  .25, .35, .45]})

cv_results = {}
unscaled = []

for params in params1:

    regressor = RandomForestRegressor(**params, random_state=1)

    print()
    print(params)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    # y_pred = y_pred.reindex(X_test.index)

    
    original_tail = LME_shifted.loc[:'2017-10-30']

    unscaled = []

    for key, item in y_pred.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        unscaled_result = item + rolling_avg

        original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
        unscaled.append(float(unscaled_result))

    unscaled = pd.Series(unscaled)
    unscaled.index = y_test.index

    original_tail = LME_shifted.loc[:'2017-10-30']

    original_y = []

    for key, item in y_test.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        unscaled_y = item + rolling_avg
        original_tail = original_tail.append(pd.Series([unscaled_y]))

        original_y.append(float(unscaled_y))


    original_y = pd.Series(original_y)
    original_y.index = y_test.index
    
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters

    '''Calculates maximum test accuracy value and parameters'''
    #min_test_accuracy, min_parameters = 0, 0
    min_test_accuracy = 3000
    for key, value in cv_results.items():
        if value < min_test_accuracy:
            min_test_accuracy = value
            min_parameters = key
            
print()
print('Random Forest CV Results')
for key, value in cv_results.items():
    print(key, value)

print()
print('Best Results:')
if min_test_accuracy==3000:
    print('error')
else:
    print('Minimum Test Accuracy: ', min_test_accuracy)
print('Best Parameters: ', min_parameters)
print()

plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Random Forest Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()

# %%
from sklearn import neighbors

cv_results = {}

for K in range(7):
    K = K+1
    regressor = neighbors.KNeighborsRegressor(n_neighbors=K)

    print()
    print('K: ', K)
    
    regressor.fit(X_train, y_train)
    #print(regressor.coef_)

    y_pred = regressor.predict(X_test)
    y_pred = pd.Series(y_pred)
    y_pred.index = y_test.index
    #print(y_pred.head())
    # y_pred = y_pred.reindex(X_test.index)

    original_tail = LME_shifted.loc[:'2017-10-30']

    unscaled = []

    for key, item in y_pred.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        unscaled_result = item+rolling_avg

        original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
        unscaled.append(float(unscaled_result))

    unscaled = pd.Series(unscaled)
    unscaled.index = y_test.index

    original_tail = LME_shifted.loc[:'2017-10-30']

    original_y = []

    for key, item in y_test.items():
        rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
        unscaled_y = item+rolling_avg
        original_tail = original_tail.append(pd.Series([unscaled_y]))

        original_y.append(float(unscaled_y))


    original_y = pd.Series(original_y)
    original_y.index = y_test.index


    
    print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
    print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))

    
    mae = metrics.mean_absolute_error(original_y, unscaled)

    #print('kfold test accuracy =', kfold_test_accuracy)
    cv_results[str(params)] = mae

    # To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('KNN Regression Prediction - weeks, 10 lags', fontsize=15)

plt.show()

print(cv_results)
# Out:
# K:  1
# Mean Absolute Error: 1070.0785310377694
# Mean Squared Error: 2034046.2926461047
# Root Mean Squared Error: 1426.1999483403808
#
# K:  2
# Mean Absolute Error: 1362.1252142325432
# Mean Squared Error: 3388040.5740666366
# Root Mean Squared Error: 1840.6630799977047
#
# K:  3
# Mean Absolute Error: 1432.5167183565363
# Mean Squared Error: 3824180.8001498887
# Root Mean Squared Error: 1955.5512778114228
#
# K:  4
# Mean Absolute Error: 1292.8133345823012
# Mean Squared Error: 2998638.67975346
# Root Mean Squared Error: 1731.6577836724725
#
# K:  5
# Mean Absolute Error: 1518.2090827143793
# Mean Squared Error: 4056313.168141293
# Root Mean Squared Error: 2014.0290882063478
#
# K:  6
# Mean Absolute Error: 1351.8985316027938
# Mean Squared Error: 3428814.196696104
# Root Mean Squared Error: 1851.7057532707793
#
# K:  7
# Mean Absolute Error: 1314.0546513557124
# Mean Squared Error: 3474180.730584478
# Root Mean Squared Error: 1863.9154301052604
# {"{'alpha': 1e-05}": 1314.0546513557124}

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=2)

X_poly = polynomial_features.fit_transform(X_train)

regressor = LinearRegression()
regressor.fit(X_poly, y_train)

X_poly_test = polynomial_features.fit_transform(X_test)
y_poly_pred = regressor.predict(X_poly_test)
y_poly_pred = pd.Series(y_poly_pred)
y_poly_pred.index = y_test.index

mae = np.sqrt(metrics.mean_absolute_error(y_test,y_poly_pred))
print('MAE for scaled results: ', mae)
print()

original_tail = LME_shifted.loc[:'2017-10-30']

unscaled = []

for key, item in y_poly_pred.items():
    rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
    unscaled_result = item + rolling_avg

    original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
    unscaled.append(float(unscaled_result))

unscaled = pd.Series(unscaled)
unscaled.index = y_test.index

original_tail = LME_shifted.loc[:'2017-10-30']

original_y = []

for key, item in y_test.items():
    rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
    unscaled_y = item + rolling_avg
    original_tail = original_tail.append(pd.Series([unscaled_y]))

    original_y.append(float(unscaled_y))


original_y = pd.Series(original_y)
original_y.index = y_test.index




print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))


mae = metrics.mean_absolute_error(original_y, unscaled)
print('Polynomial MAE of Degree = 2: ', mae)
#print('kfold test accuracy =', kfold_test_accuracy)

# To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Polynomial Regression (deg=2) Prediction - weeks, 10 lags', fontsize=15)

plt.show()

# %%
polynomial_features= PolynomialFeatures(degree=3)

X_poly = polynomial_features.fit_transform(X_train)

regressor = LinearRegression()
regressor.fit(X_poly, y_train)

X_poly_test = polynomial_features.fit_transform(X_test)
y_poly_pred = regressor.predict(X_poly_test)
y_poly_pred = pd.Series(y_poly_pred)
y_poly_pred.index = y_test.index

mae = np.sqrt(metrics.mean_absolute_error(y_test,y_poly_pred))
print('MAE for scaled results: ', mae)
print()

original_tail = LME_shifted.loc[:'2017-10-30']

unscaled = []

for key, item in y_poly_pred.items():
    rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
    unscaled_result = item+rolling_avg

    original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
    unscaled.append(float(unscaled_result))

unscaled = pd.Series(unscaled)
unscaled.index = y_test.index

original_tail = LME_shifted.loc[:'2017-10-30']

original_y = []

for key, item in y_test.items():
    rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
    unscaled_y = item+rolling_avg
    original_tail = original_tail.append(pd.Series([unscaled_y]))

    original_y.append(float(unscaled_y))


original_y = pd.Series(original_y)
original_y.index = y_test.index



print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))


mae = metrics.mean_absolute_error(original_y, unscaled)
print('Polynomial MAE of Degree = 3: ', mae)
#print('kfold test accuracy =', kfold_test_accuracy)

# To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Polynomial Regression Prediction (deg=3) - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# MAE for scaled results:  0.13073848787259856
#
# Mean Absolute Error: 1336.9695291945397
# Mean Squared Error: 3531663.2931580506
# Root Mean Squared Error: 1879.2720114869085
# Polynomial MAE of Degree = 3:  1336.9695291945397

# %%
plt.plot(y_poly_pred)
plt.plot(y_test)
plt.title('Scaled Values', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Scaled Values')

# %%
X_test
# Out:
#                    lag0         lag1         lag2        lag3        lag4  \
# ds
# 2017-10-31   620.892857  -206.107143   580.482143  587.714286  -16.410714
# 2017-11-01  1037.000000  -163.928571   568.660714  643.000000   46.482143
# 2017-11-02   745.571429  -194.928571   450.660714  772.607143   39.767857
# 2017-11-03   791.178571   -87.821429  -194.285714  345.178571  393.089286
# 2017-11-06   916.571429   373.035714   -44.392857   73.142857  378.375000
# 2017-11-07   562.178571   434.035714   144.107143  -67.642857  532.446429
# 2017-11-08   541.321429   538.071429  -511.678571  318.642857  364.696429
# 2017-11-09    68.178571   805.750000  -627.750000  238.428571  183.196429
# 2017-11-10  -164.500000  1007.107143  -720.678571  459.642857  200.196429
# 2017-11-13   193.428571  1122.142857  -536.428571  740.357143  448.410714
# 2017-11-14  -554.714286   918.392857  -596.428571  767.321429  635.625000
# 2017-11-15  -632.928571   691.500000  -323.750000  934.678571  615.589286
# 2018-09-14  -498.321429
# 2018-09-17  -161.571429
# 2018-09-18  -283.785714
# 2018-09-19  -198.642857
# 2018-09-20   -78.607143
# 2018-09-21   406.714286
# 2018-09-24   662.071429
# 2018-09-25   546.714286
# 2018-09-26   808.250000
# 2018-09-27   777.107143
# 2018-09-28   782.785714
# 2018-10-01   729.071429
# 2018-10-02   638.250000
# 2018-10-03   519.714286
# 2018-10-04   690.357143
# 2018-10-05  1000.535714
#
# [244 rows x 11 columns]

# %%
polynomial_features= PolynomialFeatures(degree=4)

X_poly = polynomial_features.fit_transform(X_train)

regressor = LinearRegression()
regressor.fit(X_poly, y_train)

X_poly_test = polynomial_features.fit_transform(X_test)
y_poly_pred = regressor.predict(X_poly_test)
y_poly_pred = pd.Series(y_poly_pred)
y_poly_pred.index = y_test.index

mae = np.sqrt(metrics.mean_absolute_error(y_test,y_poly_pred))
print('MAE for scaled results: ', mae)
print()

original_tail = LME_shifted.loc[:'2017-10-30']

unscaled = []

for key, item in y_poly_pred.items():
    rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
    unscaled_result = item + rolling_avg

    original_tail = original_tail.append(pd.Series([float(unscaled_result)]))
    unscaled.append(float(unscaled_result))

unscaled = pd.Series(unscaled)
unscaled.index = y_test.index

original_tail = LME_shifted.loc[:'2017-10-30']

original_y = []

for key, item in y_test.items():
    rolling_avg = original_tail.ewm(span=4, adjust=True).mean().iloc[len(original_tail)-1]
    unscaled_y = item + rolling_avg
    original_tail = original_tail.append(pd.Series([unscaled_y]))

    original_y.append(float(unscaled_y))


original_y = pd.Series(original_y)
original_y.index = y_test.index



print('Mean Absolute Error:', metrics.mean_absolute_error(original_y, unscaled))  
print('Mean Squared Error:', metrics.mean_squared_error(original_y, unscaled))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(original_y, unscaled)))


mae = metrics.mean_absolute_error(original_y, unscaled)
print('Polynomial MAE of Degree = 2: ', mae)
#print('kfold test accuracy =', kfold_test_accuracy)

# To find the best/optimal parameters


plt.plot(unscaled)
plt.plot(original_y)
plt.legend(['y_hat', 'y'])
plt.title('Polynomial Regression (deg = 4) Prediction - weeks, 10 lags', fontsize=15)

plt.show()
# Out:
# MAE for scaled results:  15.548454914972256
#
# Mean Absolute Error: 1502.6022693431728
# Mean Squared Error: 3027154.390167956
# Root Mean Squared Error: 1739.871946485705
# Polynomial MAE of Degree = 2:  1502.6022693431728

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true))*100

def root_mean_squared_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.sqrt(((y_pred - y_true) **2).mean())
    #return np.mean(np.abs((y_true - y_pred) / y_true))*100

# %%
print('mape', mean_absolute_percentage_error(cmp_df['y'], cmp_df['yhat']))

print('rmse', root_mean_squared_error(cmp_df['y'], cmp_df['yhat']))
# Out:
# mape 219.83967767924054
# rmse 0.05529372373011725

# %%
pd.DataFrame({'mean':tester.rolling(window=3).mean(), 'original': tester})
# Out:
#        mean  original
# 0       NaN       1.0
# 1       NaN       2.0
# 2  2.000000       3.0
# 3  3.000000       4.0
# 4  6.000000      11.0
# 5  7.000000       6.0
# 6  8.000000       7.0
# 7  7.000000       8.0
# 8  8.000000       9.0
# 9  5.833333       0.5
