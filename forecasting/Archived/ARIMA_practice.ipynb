# %% [markdown]
# ## ARMA and ARIMA Models
#
# Best for situations where outcomes of previous days can be used to help determine the outcome of the next day

# %%
import pandas as pd
from matplotlib import pyplot as plt
import re

from statsmodels.tsa.stattools import adfuller

from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

import numpy as np
#import fbprophet

# %% [markdown]
# ## Reading in the Data

# %%
df_orig = pd.read_csv('data/DashboardComm2.csv')
df_orig = df_orig.iloc[:, 0:len(df_orig.columns)-5]

df_orig.columns = df_orig.iloc[0]
df_orig.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-45e846ce948e> in <module>
# ----> 1 df_orig = pd.read_csv('data/DashboardComm2.csv')
#       2 df_orig = df_orig.iloc[:, 0:len(df_orig.columns)-5]
#       3
#       4 df_orig.columns = df_orig.iloc[0]
#       5 df_orig.head(10)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'data/DashboardComm2.csv' does not exist: b'data/DashboardComm2.csv'

# %%
df = df_orig.iloc[6: ,:]
df = df.rename(columns={"Column1": "Date"})
df.head()
# Out:
# 0     Date LME Ni cash price LME Ni inventory (total)  \
# 6   1/2/15          $14,756                   414,900
# 7   1/5/15          $15,126                   414,756
# 8   1/6/15          $15,191                   415,338
# 9   1/7/15          $15,483                   415,812
# 10  1/8/15          $15,486                   415,842
#
# 0  LME Ni inventory (briquette) LME Ni inventory (other forms)  \
# 6                       165,720                        249,180
# 7                       165,972                        248,784
# 8                       166,506                        248,832
# 9                       167,094                        248,718
# 10                      167,124                        248,718
#
# 0  Critical Inventory LME Co cash price LME Cu cash price Comex Cu future  \
# 6             100,000            31,619           $6,321            $273
# 7             100,000            31,365           $6,214            $267
# 8             100,000            31,366           $6,221            $267
# 9             100,000            31,367           $6,183            $266
# 10            100,000            31,371           $6,176            $267
#
# 0  Comex Cu future2 LME Al cash price Fastmarkets- Cobalt LOW  \
# 6           $6,006            $1,805                      NaN
# 7           $5,891            $1,787                      NaN
# 8           $5,888            $1,755                      NaN
# 9           $5,861            $1,762                      NaN
# 10          $5,888            $1,812                      NaN
#
# 0  Fastmarkets - Cobalt High Column2
# 6                         ""  1/1/15
# 7                         ""  1/1/15
# 8                         ""  1/1/15
# 9                         ""  1/1/15
# 10                        ""  1/1/15

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')

# %% [markdown]
# ## Reading and Preprocessing Data

# %%
filename = 'raw_data_finals\MetalsDashboard(Aug)LATEST.xlsx'
test_df = pd.read_excel(filename, sheet_name="Commodities Data")

# %%
test_df
# Out:
#       Unnamed: 0                   u9         Unnamed: 2  \
# 0            NaN              Column1  LME Ni cash price
# 1            NaN                  NaN               $/MT
# 2            NaN                  NaN      LMNIDY Comdty
# 3            NaN                  NaN                NaN
# 4            NaN                Dates         LAST_PRICE
# 5            NaN                  NaN              15074
# 6            NaN  2015-01-02 00:00:00              14756
# 7            NaN  2015-01-05 00:00:00              15126
# 8            NaN  2015-01-06 00:00:00              15191
# 9            NaN  2015-01-07 00:00:00              15483
# 10           NaN  2015-01-08 00:00:00              15486
# 11           NaN  2015-01-09 00:00:00            15235.5
# 12           NaN  2015-01-12 00:00:00              15029
# 13           NaN  2015-01-13 00:00:00              14585
# 14           NaN  2015-01-14 00:00:00              14241
# 15           NaN  2015-01-15 00:00:00            14413.5
# 16           NaN  2015-01-16 00:00:00              14722
# 17           NaN  2015-01-19 00:00:00              14417
# 18           NaN  2015-01-20 00:00:00              14721
# 19           NaN  2015-01-21 00:00:00            14971.5
# 20           NaN  2015-01-22 00:00:00              14792
# 21           NaN  2015-01-23 00:00:00              14293
# 22           NaN  2015-01-26 00:00:00              14692
# 23           NaN  2015-01-27 00:00:00            14730.5
# 24           NaN  2015-01-28 00:00:00              14993
# 25           NaN  2015-01-29 00:00:00              14846
# 26           NaN  2015-01-30 00:00:00              15109
# 27           NaN  2015-02-02 00:00:00              15274
# 28           NaN  2015-02-03 00:00:00            15255.5
# 29           NaN  2015-02-04 00:00:00              15070
# ...          ...                  ...                ...
# 1172         NaN  2019-06-24 00:00:00            12069.5
# 1173         NaN  2019-06-25 00:00:00              12234
# 1174         NaN  2019-06-26 00:00:00              12424
# 1175         NaN  2019-06-27 00:00:00              12658
# 1176         NaN  2019-06-28 00:00:00              12617
# 1177         NaN  2019-07-01 00:00:00              12266
# 1178         NaN  2019-07-02 00:00:00            12004.5
# 1179         NaN  2019-07-03 00:00:00            12271.5
# 1180         NaN  2019-07-04 00:00:00              12270
# 1181         NaN  2019-07-05 00:00:00              12418
# 1182         NaN  2019-07-08 00:00:00              12676
# 1183         NaN  2019-07-09 00:00:00            12646.5
# 1184         NaN  2019-07-10 00:00:00              12928
# 1185         NaN  2019-07-11 00:00:00              13073
# 1186         NaN  2019-07-12 00:00:00            13409.5
# 1187         NaN  2019-07-15 00:00:00              13595
# 1188         NaN  2019-07-16 00:00:00              14004
# 1189         NaN  2019-07-17 00:00:00              14419
# 1190         NaN  2019-07-18 00:00:00              14817
# 1191         NaN  2019-07-19 00:00:00              14680
# 1192         NaN  2019-07-22 00:00:00              14256
# 1193         NaN  2019-07-23 00:00:00              14131
# 1194         NaN  2019-07-24 00:00:00              14508
# 1195         NaN  2019-07-25 00:00:00              14032
# 1196         NaN  2019-07-26 00:00:00              14063
# 1197         NaN  2019-07-29 00:00:00              14325
# 1198         NaN  2019-07-30 00:00:00              14320
# 1199         NaN  2019-07-31 00:00:00              14452
# 1200         NaN  2019-08-01 00:00:00              14578
# 1201         NaN  2019-08-02 00:00:00              14578
#
#                     Unnamed: 3                    Unnamed: 4  \
# 0     LME Ni inventory (total)  LME Ni inventory (briquette)
# 1                           MT                            MT
# 2                   LSNI Index              NLSNI BBRI Index
# 3                          NaN                           NaN
# 4                   LAST_PRICE                    LAST_PRICE
# 5                          NaN                           NaN
# 6                       414900                        165720
# 7                       414756                        165972
# 8                       415338                        166506
# 9                       415812                        167094
# 10                      415842                        167124
# 11                      415164                        166818
# 12                      414732                        166554
# 13                      416436                        167244
# 14                      418320                        167142
# 15                      418332                        167100
# 16                      418518                        166470
# 17                      417900                        165990
# 18                      418062                        165654
# 19                      419964                        166794
# 20                      421842                        167820
# 21                      423036                        168120
# 22                      424344                        168900
# 23                      424110                        168288
# 24                      423726                        167580
# 25                      425562                        167778
# 26                      426240                        167310
# 27                      424974                        166194
# 28                      424572                        165462
# 29                      424788                        165462
# ...                        ...                           ...
# 1172                    168876                        145242
# 1173                    168252                        145176
# 1174                    164838                        144276
# 1175                    165480                        144624
# 1176                    164718                        143880
# 1177                    161658                        143280
# 1178                    161448                        143118
# 1179                    158292                        140328
# 1180                    157386                        139932
# 1181                    157464                        140208
# 1182                    154740                        139512
# 1183                    154104                        139428
# 1184                    153612                        139332
# 1185                    153420                        139692
# 1186                    150840                        139398
# 1187                    150324                        138978
# 1188                    149322                        137976
# 1189                    148374                        137028
# 1190                    148230                        136902
# 1191                    147942                        136818
# 1192                    147624                        136872
# 1193                    146670                        136332
# 1194                    145056                        136284
# 1195                    145500                        137112
# 1196                    145062                        137040
# 1197                    143988                        136080
# 1198                    143988                        136032
# 1199                    143628                        136032
# 1200                    143670                        136074
# 1201                    143670                        136074
#
#                           Unnamed: 5          Unnamed: 6         Unnamed: 7  \
# 0     LME Ni inventory (other forms)  Critical Inventory  LME Co cash price
# 1                                 MT                 NaN               $/MT
# 2                                NaN                 NaN      LMCODY Comdty
# 3                                NaN                 NaN                NaN
# 4                                NaN                 NaN         LAST_PRICE
# 5                                NaN                 NaN                NaN
# 6                             249180              100000              31619
# 7                             248784              100000              31365
# 8                             248832              100000              31366
# 9                             248718              100000              31367
# 10                            248718              100000              31371
# 11                            248346              100000              31371
# 12                            248178              100000            31367.5
# 13                            249192              100000              30769
# 14                            251178              100000            30769.5
# 15                            251232              100000            30774.5
# 16                            252048              100000            30773.5
# 17                            251910              100000              31015
# 18                            252408              100000              30615
# 19                            253170              100000              30816
# 20                            254022              100000              30620
# 21                            254916              100000              30370
# 22                            255444              100000              30368
# 23                            255822              100000              30365
# 24                            256146              100000              29616
# 25                            257784              100000              29620
# 26                            258930              100000              29421
# 27                            258780              100000            29438.5
# 28                            259110              100000              29640
# 29                            259326              100000              29642
# ...                              ...                 ...                ...
# 1172                           23634              100000              28000
# 1173                           23076              100000              28000
# 1174                           20562              100000              27860
# 1175                           20856              100000              28720
# 1176                           20838              100000              28600
# 1177                           18378              100000              28600
# 1178                           18330                 NaN              28600
# 1179                          290568              100000              28600
# 1180                           18330              100000              28600
# 1181                           17256                 NaN              28600
# 1182                           15228                 NaN              28600
# 1183                           14676                 NaN              26647
# 1184                           14280                 NaN              26650
# 1185                           13728                 NaN              26650
# 1186                           11442                 NaN              26650
# 1187                           11346                 NaN              27584
# 1188                           11346                 NaN              27583
# 1189                           11346                 NaN              27583
# 1190                           11328                 NaN              27592
# 1191                           11124                 NaN              27596
# 1192                           10752                 NaN              27583
# 1193                           10338                 NaN            27583.5
# 1194                            8772                 NaN              27584
# 1195                            8388                 NaN              27593
# 1197                        0                          0  2019-07-01 00:00:00
# 1198                        0                          0  2019-07-01 00:00:00
# 1199                   26.676                     28.109  2019-07-01 00:00:00
# 1200                        0                          0  2019-08-01 00:00:00
# 1201                  26.8964                    28.6601  2019-08-01 00:00:00
#
# [1202 rows x 15 columns]

# %% [markdown]
# ### Null Values

# %%
print(df.isnull().sum())
print()
print(df.shape)
# Out:
# 0
# LME Ni cash price                 538
# LME Ni inventory (total)          538
# LME Ni inventory (briquette)      537
# LME Ni inventory (other forms)    537
# Critical Inventory                560
# LME Co cash price                 538
# LME Cu cash price                 538
# Comex Cu future                   538
# Comex Cu future2                  537
# LME Al cash price                 538
# Fastmarkets- Cobalt LOW           995
# Fastmarkets - Cobalt High         538
# Column2                           537
# dtype: int64
#
# (1734, 13)

# %%
df = df.dropna(subset=["LME Ni cash price"])
df.isnull().sum()
# Out:
# 0
# LME Ni cash price                   0
# LME Ni inventory (total)            0
# LME Ni inventory (briquette)        0
# LME Ni inventory (other forms)      0
# Critical Inventory                 22
# LME Co cash price                   0
# LME Cu cash price                   0
# Comex Cu future                     0
# Comex Cu future2                    0
# LME Al cash price                   0
# Fastmarkets- Cobalt LOW           458
# Fastmarkets - Cobalt High           0
# Column2                             0
# dtype: int64

# %% [markdown]
# ### Conversion of Ni price from string to number

# %%
'''Converts string price to just numbers in string format'''
def convert_price(price_string):
    
    # substitutes any character that is not a numeric digit
    non_digits = re.compile(r'[^\d.]+')
    only_digits = non_digits.sub('', price_string)
    return only_digits

df['LME Ni cash price'] = df['LME Ni cash price'].apply(convert_price)
df['LME Ni cash price'] = pd.to_numeric(df['LME Ni cash price'],errors='coerce')


# Example conversion below
print(convert_price('$5,053 round trip'))
# Out:
# 5053

# %%
nickel = df.iloc[:, 0]

# %%
nickel.head()
# Out:
# Date
# 2015-01-02    14756
# 2015-01-05    15126
# 2015-01-06    15191
# 2015-01-07    15483
# 2015-01-08    15486
# Name: LME Ni cash price, dtype: int64

# %%
nickel_weekly = nickel.resample('B').sum()

# %%
nickel_weekly.plot()

# %% [markdown]
# ## Making Time Series Stationary
# As seen on:
# https://campus.datacamp.com/courses/forecasting-using-arima-models-in-python/chapter-1-arma-models?ex=5
#
# The most common test for identifying if time series data is stationary is the Dicky-Fuller Test - (Null hypothesis is that time series data is non-stationary on

# %%
results = adfuller(nickel)

print(results)
# Out:
# (-1.9711999348352705, 0.2993419051235137, 0, 1195, {'1%': -3.4358340188169882, '5%': -2.8639616494853217, '10%': -2.5680593310691338}, 15853.188858095957)

# %% [markdown]
# ### Results Analysis - Does Not Pass the Dicky Fuller Test:
#
# First number is the **test statistic**:
# - The more negative it is means the more likely it is to be stationary
#
# Second number is the p-value
# - If p-value is small, then we can reject the null hypothesis that the data is non-stationary and accept the alternative hypothesis that the data is stationary
#
# Last values (dictionary values)
# - If we wanted a p-value of 0.05 or below, we would need a test statistic of less than -2.86396

# %%
nickel.plot()
plt.style.use('seaborn')
plt.title("Hello")
plt.show()

# %% [markdown]
# ## Transforming the Data into Stationary Form Before Modeling
#
# Common way is to take it's difference (subtract the previous value)
#
#
# Other methods for reshaping into stationary are:
# - Taking the log (np.log(nickel))
# - Taking the square root (np.sqrt(nickel))
# - Taking the proportional change (nickel.shift(1)/nickel)

# %%
nickel_stationary = nickel.diff().dropna()

# %%
nickel_stationary.plot(figsize=(15,6))
plt.style.use('seaborn')
plt.title("Normalized Ni", fontsize=20)
plt.show()

# %%
nickel_stationary.hist(bins=30)
plt.show()

# %%
results = adfuller(nickel_stationary)

print(results)
# Out:
# (-35.76480686193037, 0.0, 0, 1194, {'1%': -3.4358386217286885, '5%': -2.8639636801920956, '10%': -2.5680604125597277}, 15843.385342382324)

# %% [markdown]
# ## Modeling
# AR, MA, and ARMA Models
# https://campus.datacamp.com/courses/forecasting-using-arima-models-in-python/chapter-1-arma-models?ex=9
#
# Using p lags

# %%
p = 2
q = 2


ar_model = ARMA(nickel_stationary, order = (1,0))
ma_model = ARMA(nickel_stationary, order = (0, 1))
# Out:
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)

# %%
ar_results = ar_model.fit()
print(ar_results.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:      LME Ni cash price   No. Observations:                 1195
# Model:                     ARMA(1, 0)   Log Likelihood               -8089.267
# Method:                       css-mle   S.D. of innovations            210.676
# Date:                Mon, 07 Oct 2019   AIC                          16184.534
# Time:                        20:07:35   BIC                          16199.791
# Sample:                    01-05-2015   HQIC                         16190.282
#                          - 08-02-2019
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.1562      5.894     -0.026      0.979     -11.708      11.396
# ar.L1.LME Ni cash price    -0.0340      0.029     -1.176      0.240      -0.091       0.023
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -29.3925           +0.0000j           29.3925            0.5000
# -----------------------------------------------------------------------------

# %%
residuals = ar_results.resid

results.plot_diagnostics()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-ea46c320a7da> in <module>
# ----> 1 results.plot_diagnostics
#       2 plt.show()
#
# AttributeError: 'tuple' object has no attribute 'plot_diagnostics'

# %%
ma_results = ma_model.fit()

print(ma_results.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:      LME Ni cash price   No. Observations:                 1195
# Model:                     ARMA(0, 1)   Log Likelihood               -8089.239
# Method:                       css-mle   S.D. of innovations            210.671
# Date:                Sun, 22 Sep 2019   AIC                          16184.478
# Time:                        13:53:38   BIC                          16199.736
# Sample:                    01-05-2015   HQIC                         16190.227
#                          - 08-02-2019
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.1536      5.879     -0.026      0.979     -11.676      11.369
# ma.L1.LME Ni cash price    -0.0354      0.029     -1.199      0.231      -0.093       0.022
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           28.2806           +0.0000j           28.2806            0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# ### SARIMAX models can do everything ARMA models can do
#
# https://campus.datacamp.com/courses/forecasting-using-arima-models-in-python/chapter-2-fitting-the-future?ex=5

# %%
sar_model = SARIMAX(y, order=(p,0,q), trend='c')
# Out:
# /Users/ckato/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)

# %%
# https://campus.datacamp.com/courses/forecasting-using-arima-models-in-python/chapter-3-the-best-of-the-best-models?ex=8
# Make predictions for the last 25 values
results = sar_model.fit()

# Makes in-sample prediction
# start defines how many steps back to begin the forecast 
forecast = results.get_prediction(start = -25)

# Forecast mean
mean_forecast = forecast.predicted_mean

# %%
residuals = ar_results.resid

results.plot_diagnostics()
plt.show()

# %%
mean_forecast
# Out:
# 2019-07-01    12613.287086
# 2019-07-02    12279.971012
# 2019-07-03    12022.028690
# 2019-07-04    12267.302145
# 2019-07-05    12263.006882
# 2019-07-08    12416.449900
# 2019-07-09    12661.016268
# 2019-07-10    12643.045592
# 2019-07-11    12918.605083
# 2019-07-12    13057.610140
# 2019-07-15    13394.813471
# 2019-07-16    13575.355132
# 2019-07-17    13983.288749
# 2019-07-18    14387.112634
# 2019-07-19    14788.246578
# 2019-07-22    14666.840813
# 2019-07-23    14267.791072
# 2019-07-24    14134.665922
# 2019-07-25    14487.416012
# 2019-07-26    14031.255252
# 2019-07-29    14070.108690
# 2019-07-30    14300.692502
# 2019-07-31    14309.841588
# 2019-08-01    14439.505422
# 2019-08-02    14561.194787
# Freq: B, dtype: float64

# %%
confidence_intervals = forecast.conf_int()
print(confidence_intervals)
# Out:
#             lower LME Ni cash price  upper LME Ni cash price
# 2019-07-01             12201.986708             13024.587463
# 2019-07-02             11868.670634             12691.271389
# 2019-07-03             11610.728312             12433.329067
# 2019-07-04             11856.001767             12678.602522
# 2019-07-05             11851.706504             12674.307259
# 2019-07-08             12005.149523             12827.750277
# 2019-07-09             12249.715891             13072.316646
# 2019-07-10             12231.745215             13054.345970
# 2019-07-11             12507.304705             13329.905460
# 2019-07-12             12646.309762             13468.910517
# 2019-07-15             12983.513094             13806.113848
# 2019-07-16             13164.054755             13986.655510
# 2019-07-17             13571.988372             14394.589127
# 2019-07-18             13975.812257             14798.413012
# 2019-07-19             14376.946200             15199.546955
# 2019-07-22             14255.540436             15078.141190
# 2019-07-23             13856.490695             14679.091449
# 2019-07-24             13723.365544             14545.966299
# 2019-07-25             14076.115634             14898.716389
# 2019-07-26             13619.954875             14442.555629
# 2019-07-29             13658.808313             14481.409067
# 2019-07-30             13889.392125             14711.992880
# 2019-07-31             13898.541210             14721.141965
# 2019-08-01             14028.205045             14850.805799
# 2019-08-02             14149.894409             14972.495164

# %% [markdown]
# ## Plotting Results

# %%
ax = nickel.plot()
ax.set_title("Ni Price Original")

ax.set_xlabel("Date")
ax.set_ylabel("Ni Price")

ax.axvline('2018-5-1', color='red', linestyle='--')


ax.axvspan('2017-1-1', '2018-1-1', color='pink', alpha=.5)
plt.show()

# %%
dates = mean_forecast.index
lower_limits = confidence_intervals.iloc[:,0]
upper_limits = confidence_intervals.iloc[:,1]



nickel.plot()
plt.title("Ni Price Original")

plt.figure()

# Plot prediction

plt.plot(dates, mean_forecast.values, 
        color = 'red',
        label='forecast')
plt.xticks(rotation=45)
# Share uncertainty area
plt.fill_between(dates,lower_limits, upper_limits, color='pink')

plt.show()

# %%
len(mean_forecast.values)
# Out:
# 25

# %% [markdown]
# ## Making Dynamic Predictions (ie, one or more steps ahead predictions)

# %% [markdown]
# ## Interpolation
# https://campus.datacamp.com/courses/machine-learning-for-time-series-data-in-python/predicting-time-series-data?ex=5

# %%
missing = nickel.isna()

# %%
nickel_interp = nickel.interpolate('linear')

ax = nickel_interp.plot(c='r')
nickel.plot(c='k', ax=ax, lw=2)

# %%
# Standardizing variance of data

# %%
# from https://campus.datacamp.com/courses/machine-learning-for-time-series-data-in-python/predicting-time-series-data?ex=5

def percent_change(values):
    previous_values = values[:-1]
    last_value = values[-1]
    
    percent_change = (last_value - np.mean(previous_values)) / np.mean(previous_values)
    return percent_change

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))
ax = nickel.plot(ax=axs[0])

ax = nickel.rolling(window=20).aggregate(percent_change).plot(ax=axs[1])
ax.legend_.set_visable(False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-9c0931c799fe> in <module>
#       3
#       4 ax = nickel.rolling(window=20).aggregate(percent_change).plot(ax=axs[1])
# ----> 5 ax.legend_.set_visable(False)
#       6 ax.title('Hello')
#       7 ax.show()
#
# AttributeError: 'NoneType' object has no attribute 'set_visable'

# %%
# https://campus.datacamp.com/courses/machine-learning-for-time-series-data-in-python/predicting-time-series-data?ex=5

# %%
nickel_perc_change = percent_change(nickel)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
for data, ax in zip([nickel, nickel_perc_change], axs):
    
    this_mean = data.mean()
    this_std = data.std()
    
    data.plot(ax=ax)
    ax.axhline(this_mean + this_std*3, ls='--', c='r')
    ax.axhline(this_mean - this_std*3, ls='--', c='r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-94c1c97ada44> in <module>
#       5     this_std = data.std()
#       6
# ----> 7     data.plot(ax=ax)
#       8     ax.axhline(this_mean + this_std*3, ls='--', c='r')
#       9     ax.axhline(this_mean - this_std*3, ls='--', c='r')
#
# AttributeError: 'numpy.float64' object has no attribute 'plot'

# %%
## BACK TO ARIMA MODELING: 

for p in range(3):
    for q in range(3):
        try:
            
            model = SARIMAX(nickel, order=(p, 0, q))
            results = model.fit()
            
            print(p, q, results.aic, results.bic)
        except:
            print(p, q, None, None)
# Out:
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 0 0 25773.525875394622 25778.612613329133
# 0 1 24242.326750385317 24252.50022625434
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 0 2 23087.938813038134 23103.199026841667
# 1 0 16205.859853400863 16216.033329269885
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 1 1 16206.845745659597 16222.105959463128
# 1 2 16208.437387685744 16228.784339423786
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 2 0 16206.853394723097 16222.113608526628
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 2 1 16207.783184620905 16228.130136358946
# C:\Users\ckato\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# 2 2 16209.447359754195 16234.881049426747
