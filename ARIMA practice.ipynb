# %%
import pandas as pd

# %%
df_orig = pd.read_csv('data/DashboardComm2.csv')
df_orig = df_orig.iloc[:, 0:len(df_orig.columns)-5]

df_orig.columns = df_orig.iloc[0]
df_orig.head(10)
# Out:
# 0  Column1  LME Ni cash price  LME Ni inventory (total)  \
# 0  Column1  LME Ni cash price  LME Ni inventory (total)
# 1      NaN               $/MT                        MT
# 2      NaN      LMNIDY Comdty                LSNI Index
# 3      NaN             #NAME?                    #NAME?
# 4    Dates         LAST_PRICE                LAST_PRICE
# 5   #NAME?           $15,074                     #NAME?
# 6   1/2/15           $14,756                    414,900
# 7   1/5/15           $15,126                    414,756
# 8   1/6/15           $15,191                    415,338
# 9   1/7/15           $15,483                    415,812
#
# 0  LME Ni inventory (briquette)  LME Ni inventory (other forms)  \
# 0  LME Ni inventory (briquette)  LME Ni inventory (other forms)
# 1                            MT                              MT
# 2              NLSNI BBRI Index                             NaN
# 3                        #NAME?                             NaN
# 4                    LAST_PRICE                             NaN
# 5                        #NAME?                          #NAME?
# 6                       165,720                         249,180
# 7                       165,972                         248,784
# 8                       166,506                         248,832
# 9                       167,094                         248,718
#
# 0  Critical Inventory  LME Co cash price  LME Cu cash price  Comex Cu future  \
# 0  Critical Inventory  LME Co cash price  LME Cu cash price  Comex Cu future
# 1                 NaN               $/MT               $/MT             $/lb
# 2                 NaN      LMCODY Comdty      LMCADY Comdty       HGA Comdty
# 3                 NaN             #NAME?             #NAME?           #NAME?
# 4                 NaN         LAST_PRICE         LAST_PRICE       LAST_PRICE
# 5                 NaN             #NAME?             #NAME?           #NAME?
# 6             100,000             31,619            $6,321             $273
# 7             100,000             31,365            $6,214             $267
# 8             100,000             31,366            $6,221             $267
# 9             100,000             31,367            $6,183             $266
#
# 0  Comex Cu future2  LME Al cash price  Fastmarkets- Cobalt LOW  \
# 0  Comex Cu future2  LME Al cash price  Fastmarkets- Cobalt LOW
# 1             $/MT                $/MT                      NaN
# 2               NaN      LMAHDY Comdty                      NaN
# 3               NaN             #NAME?                      NaN
# 4               NaN         LAST_PRICE                      NaN
# 5            #NAME?             #NAME?                      NaN
# 6           $6,006             $1,805                       NaN
# 7           $5,891             $1,787                       NaN
# 8           $5,888             $1,755                       NaN
# 9           $5,861             $1,762                       NaN
#
# 0  Fastmarkets - Cobalt High  Column2
# 0  Fastmarkets - Cobalt High  Column2
# 1                        NaN      NaN
# 2                        NaN      NaN
# 3                        NaN      NaN
# 4                        NaN      NaN
# 5                         ""      NaN
# 6                         ""   1/1/15
# 7                         ""   1/1/15
# 8                         ""   1/1/15
# 9                         ""   1/1/15

# %%
df = df_orig.iloc[6: ,:]

df.head()
# Out:
# 0  Column1 LME Ni cash price LME Ni inventory (total)  \
# 6   1/2/15          $14,756                   414,900
# 7   1/5/15          $15,126                   414,756
# 8   1/6/15          $15,191                   415,338
# 9   1/7/15          $15,483                   415,812
# 10  1/8/15          $15,486                   415,842
#
# 0  LME Ni inventory (briquette) LME Ni inventory (other forms)  \
# 6                       165,720                        249,180
# 7                       165,972                        248,784
# 8                       166,506                        248,832
# 9                       167,094                        248,718
# 10                      167,124                        248,718
#
# 0  Critical Inventory LME Co cash price LME Cu cash price Comex Cu future  \
# 6             100,000            31,619           $6,321            $273
# 7             100,000            31,365           $6,214            $267
# 8             100,000            31,366           $6,221            $267
# 9             100,000            31,367           $6,183            $266
# 10            100,000            31,371           $6,176            $267
#
# 0  Comex Cu future2 LME Al cash price Fastmarkets- Cobalt LOW  \
# 6           $6,006            $1,805                      NaN
# 7           $5,891            $1,787                      NaN
# 8           $5,888            $1,755                      NaN
# 9           $5,861            $1,762                      NaN
# 10          $5,888            $1,812                      NaN
#
# 0  Fastmarkets - Cobalt High Column2
# 6                         ""  1/1/15
# 7                         ""  1/1/15
# 8                         ""  1/1/15
# 9                         ""  1/1/15
# 10                        ""  1/1/15
